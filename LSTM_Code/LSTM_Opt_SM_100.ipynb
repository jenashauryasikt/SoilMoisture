# %%
# !pip install tensorflow==1.15.0
# !pip install scikit-optimize

# %%
import numpy as np
import pandas as pd
import time

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Input
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM, Dropout
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping

import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.colors as colors
import matplotlib as mpl

# %%
import skopt
from skopt import gp_minimize, forest_minimize
from skopt.space import Real, Categorical, Integer
from skopt.plots import plot_convergence
from skopt.plots import plot_objective, plot_evaluations
from skopt.plots import plot_objective
from skopt.utils import use_named_args

# %%
randomState = 42
np.random.seed(randomState)
tf.set_random_seed(randomState)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
raw10 = pd.read_csv('/content/gdrive/MyDrive/SoilMoisture/Data/c_5_data_soil_100.csv')
df10 = raw10.copy()

df10 = df10.rename(columns={'In-Situ':'InSitu'})

def replace_missing(attribute):
    return attribute.interpolate(inplace=True)

replace_missing(df10['NDVI'])
replace_missing(df10['EVI'])
replace_missing(df10['LSTDay'])
replace_missing(df10['LSTNight'])

df10 = df10.dropna()
df10.isnull().sum()
# Out:
# Precip       0
# NDVI         0
# EVI          0
# GPP          0
# LSTDay       0
# LSTNight     0
# Elevation    0
# RZSM         0
# SURFSM       0
# Clay         0
# Sand         0
# Silt         0
# BD           0
# InSitu       0
# dtype: int64

# %%
df10['group'] = df10['Sand'].ne(df10['Sand'].shift()).cumsum()
df10 = df10.groupby('group')
dfs = []
for name, data in df10:
    dfs.append(data)

# %%
train_dataset = pd.DataFrame()
val_dataset = pd.DataFrame()
test_dataset = pd.DataFrame()

for df in dfs:
    df.pop('group')
    train_size = int(len(df)*0.8)
    val_size = int(len(df)*0.9)
    train, val, test = df.iloc[:train_size], df.iloc[train_size:val_size], df.iloc[val_size:]
    train_dataset = train_dataset.append(train)
    val_dataset = val_dataset.append(val)
    test_dataset = test_dataset.append(test)

# %%
# Split X
X_train = train_dataset.drop('InSitu', axis = 1)
X_val = val_dataset.drop('InSitu', axis = 1)
X_test = test_dataset.drop('InSitu', axis = 1)

# Split y
y_train = train_dataset.loc[:,['InSitu']]
y_val = val_dataset.loc[:,['InSitu']]
y_test = test_dataset.loc[:,['InSitu']]

# %%
# Fit the scaler using available training data
input_scaler = StandardScaler().fit(X_train)

# Apply the scaler to training data
x_train = input_scaler.transform(X_train)
x_val = input_scaler.transform(X_val)
x_test = input_scaler.transform(X_test)

x_train = np.array(x_train, np.float32)
y_train = np.array(y_train, np.float32)

x_val = np.array(x_val, np.float32)
y_val = np.array(y_val, np.float32)

x_test = np.array(x_test, np.float32)
y_test = np.array(y_test, np.float32)

y_train = y_train.reshape((y_train.size, 1))
y_val = y_val.reshape((y_val.size, 1))
y_test = y_test.reshape((y_test.size, 1))

# %%
def create_dataset (X, y, time_steps = 1):
    Xs, ys= [], []
    for i in range(len(X)-time_steps):
        v = X[i:i+time_steps, :]
        Xs.append(v)
        ys.append(y[i+time_steps])        
    return np.array(Xs), np.array(ys)

TIME_STEPS = 15

x_test, y_test = create_dataset(x_test, y_test, TIME_STEPS)
x_train, y_train = create_dataset(x_train, y_train, TIME_STEPS)
x_val, y_val = create_dataset(x_val, y_val, TIME_STEPS)

# %%
dim_learning_rate = Real(low=1e-5, high=1e-2, prior='log-uniform', name='learning_rate')
dim_num_layers = Integer(low=2, high=3, name='num_layers')
dim_num_nodes = Integer(low=128, high=256, name='num_nodes')
dim_dropout_val = Real(low=0.10, high=0.25, name='dropout_val')

dimensions = [dim_learning_rate,
              dim_num_layers,
              dim_num_nodes,
              dim_dropout_val]

default_parameters = [1e-3, 2, 256, 0.2]

# %%
# To log traning progress
def log_dir_name(learning_rate, num_layers, num_nodes, dropout_val):
    # dir-name for TensorBoard log-dir.
    s = "/content/gdrive/MyDrive/SoilMoisture/LSTMlogs/lr_{0:.0e}_layers_{1}_nodes_{2}_dropout_{3}"
    log_dir = s.format(learning_rate, num_layers, num_nodes, dropout_val)

    return log_dir

# %%
#To create model with determined hyperparameters
def create_model(learning_rate, num_layers, num_nodes, dropout_val):
    model = Sequential()
    model.add(InputLayer(input_shape=(None, 13)))
    for i in range(num_layers-1):
        name = 'layer_LSTM_{0}'.format(i+1)
        model.add(LSTM(units=num_nodes, return_sequences=True, activation='tanh', name=name))
        model.add(Dropout(dropout_val))
    model.add(LSTM(units=num_nodes, activation='tanh'))
    model.add(Dropout(dropout_val))
    model.add(Dense(units=1))
    # Adam Optimizer
    optimizer = Adam(lr=learning_rate)
    model.compile(optimizer=optimizer, loss='MSE', metrics=[tf.keras.metrics.MeanSquaredError()])
    
    return model

path_best_model = '/content/gdrive/MyDrive/SoilMoisture/LSTM_Models/LSTM_100_best_model.h5'
validation_data = (x_val, y_val)
best_loss = 5.0

# %%
@use_named_args(dimensions=dimensions)
def fitness(learning_rate, num_layers, num_nodes, dropout_val):
    """
    Hyper-parameters:
    learning_rate: Learning-rate for the optimizer.
    num_layers:    Number of LSTM layers.
    num_nodes:     Number of nodes in each LSTM layer.
    dropout_val:   Dropout.
    """
    # Print the hyper-parameters
    print('learning rate: {0:.1e}'.format(learning_rate))
    print('num_LSTM_layers:', num_layers)
    print('num_LSTM_nodes:', num_nodes)
    print('dropout:', dropout_val)
    print()    
    # Create the LSTM
    model = create_model(learning_rate=learning_rate,
                         num_layers=num_layers,
                         num_nodes=num_nodes,
                         dropout_val=dropout_val)
    # Dir-name for TensorBoard log-files.
    log_dir = log_dir_name(learning_rate, num_layers, num_nodes, dropout_val)
    #callback
    callback_log = TensorBoard(log_dir=log_dir, histogram_freq=0, write_graph=True, write_grads=False, write_images=False)
    # Use Keras to train the model.
    history = model.fit(x= x_train,
                        y= y_train,
                        epochs=30,
                        batch_size=128,
                        validation_data=validation_data,
                        callbacks=[callback_log])

    loss = history.history['val_loss'][-1]

    print()
    print("MSE Loss:", loss)
    print()

    global best_loss

    if loss < best_loss:
        # Save the new model
        model.save(path_best_model)
        best_loss = loss

    del model
    
    K.clear_session()
    
    return loss

# %%
start = time.time()
search_result = gp_minimize(func=fitness,
                            dimensions=dimensions,
                            acq_func='EI',          # Expected Improvement.
                            n_calls=25,
                            x0=default_parameters)
print("Optimization Run Time: ", (time.time()-start)/60)
# Out:
# learning rate: 1.0e-03
# num_LSTM_layers: 2
# num_LSTM_nodes: 256
# dropout: 0.2
#
# Train on 33969 samples, validate on 4231 samples
# Epoch 1/30
# 33969/33969 [==============================] - 9s 262us/sample - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 2/30
# 33969/33969 [==============================] - 8s 238us/sample - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 3/30
# 33969/33969 [==============================] - 8s 237us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 4/30
# 33969/33969 [==============================] - 8s 236us/sample - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 5/30
# 33969/33969 [==============================] - 9s 250us/sample - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 6/30
# 33969/33969 [==============================] - 9s 253us/sample - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 7/30
# 33969/33969 [==============================] - 9s 251us/sample - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 8/30
# 33969/33969 [==============================] - 8s 239us/sample - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 9/30
# 33969/33969 [==============================] - 9s 251us/sample - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 10/30
# 33969/33969 [==============================] - 9s 253us/sample - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 11/30
# 33969/33969 [==============================] - 9s 253us/sample - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 12/30
# 33969/33969 [==============================] - 8s 238us/sample - loss: 8.9256e-04 - mean_squared_error: 8.9256e-04 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 13/30
# 33969/33969 [==============================] - 8s 239us/sample - loss: 8.7816e-04 - mean_squared_error: 8.7816e-04 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 14/30
# 33969/33969 [==============================] - 8s 236us/sample - loss: 7.5567e-04 - mean_squared_error: 7.5567e-04 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 15/30
# 33969/33969 [==============================] - 8s 235us/sample - loss: 7.5401e-04 - mean_squared_error: 7.5401e-04 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 16/30
# 33969/33969 [==============================] - 8s 234us/sample - loss: 6.7389e-04 - mean_squared_error: 6.7389e-04 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 17/30
# 33969/33969 [==============================] - 8s 249us/sample - loss: 6.0733e-04 - mean_squared_error: 6.0733e-04 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 18/30
# 33969/33969 [==============================] - 9s 250us/sample - loss: 5.6512e-04 - mean_squared_error: 5.6513e-04 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 19/30
# 33969/33969 [==============================] - 8s 249us/sample - loss: 5.7574e-04 - mean_squared_error: 5.7574e-04 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 20/30
# 33969/33969 [==============================] - 8s 239us/sample - loss: 5.0871e-04 - mean_squared_error: 5.0871e-04 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 21/30
# 33969/33969 [==============================] - 8s 236us/sample - loss: 4.7659e-04 - mean_squared_error: 4.7659e-04 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 22/30
# 33969/33969 [==============================] - 8s 238us/sample - loss: 4.4630e-04 - mean_squared_error: 4.4630e-04 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 23/30
# 33969/33969 [==============================] - 8s 234us/sample - loss: 4.1587e-04 - mean_squared_error: 4.1587e-04 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 24/30
# 33969/33969 [==============================] - 8s 234us/sample - loss: 4.0591e-04 - mean_squared_error: 4.0591e-04 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 25/30
# 33969/33969 [==============================] - 8s 248us/sample - loss: 3.6786e-04 - mean_squared_error: 3.6786e-04 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 26/30
# 33969/33969 [==============================] - 9s 251us/sample - loss: 3.9740e-04 - mean_squared_error: 3.9740e-04 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 27/30
# 33969/33969 [==============================] - 8s 250us/sample - loss: 3.0582e-04 - mean_squared_error: 3.0582e-04 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 28/30
# 33969/33969 [==============================] - 8s 238us/sample - loss: 3.6801e-04 - mean_squared_error: 3.6801e-04 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch
- val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 19/30
# 33969/33969 [==============================] - 13s 373us/sample - loss: 4.2818e-04 - mean_squared_error: 4.2818e-04 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 20/30
# 33969/33969 [==============================] - 13s 372us/sample - loss: 4.4074e-04 - mean_squared_error: 4.4074e-04 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 21/30
# 33969/33969 [==============================] - 12s 350us/sample - loss: 3.1430e-04 - mean_squared_error: 3.1430e-04 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 22/30
# 33969/33969 [==============================] - 12s 351us/sample - loss: 2.7180e-04 - mean_squared_error: 2.7180e-04 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 23/30
# 33969/33969 [==============================] - 12s 352us/sample - loss: 3.0143e-04 - mean_squared_error: 3.0143e-04 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 24/30
# 33969/33969 [==============================] - 12s 364us/sample - loss: 3.0641e-04 - mean_squared_error: 3.0641e-04 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 25/30
# 33969/33969 [==============================] - 13s 371us/sample - loss: 3.2237e-04 - mean_squared_error: 3.2237e-04 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 26/30
# 33969/33969 [==============================] - 12s 358us/sample - loss: 4.0867e-04 - mean_squared_error: 4.0867e-04 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 27/30
# 33969/33969 [==============================] - 12s 350us/sample - loss: 3.2497e-04 - mean_squared_error: 3.2497e-04 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 28/30
# 33969/33969 [==============================] - 12s 350us/sample - loss: 2.5264e-04 - mean_squared_error: 2.5264e-04 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 29/30
# 33969/33969 [==============================] - 12s 353us/sample - loss: 2.3949e-04 - mean_squared_error: 2.3949e-04 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 30/30
# 33969/33969 [==============================] - 13s 374us/sample - loss: 2.1061e-04 - mean_squared_error: 2.1061e-04 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
#
# MSE Loss: 0.005061707052390532
#
# learning rate: 1.1e-05
# num_LSTM_layers: 3
# num_LSTM_nodes: 152
# dropout: 0.15803695505277737
#
# Train on 33969 samples, validate on 4231 samples
# Epoch 1/30
# 33969/33969 [==============================] - 14s 402us/sample - loss: 0.0339 - mean_squared_error: 0.0339 - val_loss: 0.0128 - val_mean_squared_error: 0.0128
# Epoch 2/30
# 33969/33969 [==============================] - 12s 354us/sample - loss: 0.0107 - mean_squared_error: 0.0107 - val_loss: 0.0097 - val_mean_squared_error: 0.0097
# Epoch 3/30
# 33969/33969 [==============================] - 12s 351us/sample - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 0.0084 - val_mean_squared_error: 0.0084
# Epoch 4/30
# 33969/33969 [==============================] - 12s 355us/sample - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0075 - val_mean_squared_error: 0.0075
# Epoch 5/30
# 33969/33969 [==============================] - 13s 378us/sample - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 6/30
# 33969/33969 [==============================] - 13s 376us/sample - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 7/30
# 33969/33969 [==============================] - 12s 350us/sample - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 8/30
# 33969/33969 [==============================] - 12s 355us/sample - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 9/30
# 33969/33969 [==============================] - 12s 353us/sample - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 10/30
# 33969/33969 [==============================] - 13s 372us/sample - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 11/30
# 33969/33969 [==============================] - 13s 374us/sample - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 12/30
# 33969/33969 [==============================] - 12s 364us/sample - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 13/30
# 33969/33969 [==============================] - 13s 380us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 14/30
# 33969/33969 [==============================] - 13s 372us/sample - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 15/30
# 33969/33969 [==============================] - 12s 352us/sample - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 16/30
# 33969/33969 [==============================] - 12s 352us/sample - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 17/30
# 33969/33969 [==============================] - 12s 350us/sample - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 18/30
# 33969/33969 [==============================] - 13s 373us/sample - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 19/30
# 33969/33969 [==============================] - 13s 378us/sample - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 20/30
# 33969/33969 [==============================] - 12s 358us/sample - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 21/30
# 33969/33969 [==============================] - 12s 354us/sample - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 22/30
# 33969/33969 [==============================] - 12s 350us/sample - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 23/30
# 33969/33969 [==============================] - 12s 362us/sample - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 24/30
# 33969/33969 [==============================] - 13s 378us/sample - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 25/30
# 33969/33969 [==============================] - 13s 370us/sample - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 26/30
# 33969/33969 [==============================] - 12s 355us/sample - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 27/30
# 33969/33969 [==============================] - 12s 351us/sample - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 28/30
# 33969/33969 [==============================] - 12s 352us/sample - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 29/30
# 33969/33969 [==============================] - 13s 374us/sample - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 30/30
# 33969/33969 [==============================] - 13s 373us/sample - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
#
# MSE Loss: 0.005270078986141583
#
# learning rate: 8.4e-03
# num_LSTM_layers: 2
# num_LSTM_nodes: 212
# dropout: 0.20700938183848705
#
# Train on 33969 samples, validate on 4231 samples
# Epoch 1/30
# 33969/33969 [==============================] - 9s 265us/sample - loss: 0.0222 - mean_squared_error: 0.0222 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 2/30
# 33969/33969 [==============================] - 8s 245us/sample - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 3/30
# 33969/33969 [==============================] - 8s 241us/sample - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 4/30
# 33969/33969 [==============================] - 8s 239us/sample - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 5/30
# 33969/33969 [==============================] - 8s 249us/sample - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 6/30
# 33969/33969 [==============================] - 9s 258us/sample - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 7/30
# 33969/33969 [==============================] - 9s 253us/sample - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 8/30
# 33969/33969 [==============================] - 9s 252us/sample - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 9/30
# 33969/33969 [==============================] - 8s 249us/sample - loss: 9.1958e-04 - mean_squared_error: 9.1958e-04 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 10/30
# 33969/33969 [==============================] - 9s 257us/sample - loss: 8.8164e-04 - mean_squared_error: 8.8164e-04 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 11/30
# 33969/33969 [==============================] - 9s 255us/sample - loss: 7.9350e-04 - mean_squared_error: 7.9350e-04 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 12/30
# 33969/33969 [==============================] - 8s 246us/sample - loss: 8.5690e-04 - mean_squared_error: 8.5690e-04 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 13/30
# 33969/33969 [==============================] - 8s 239us/sample - loss: 7.1777e-04 - mean_squared_error: 7.1777e-04 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 14/30
# 33969/33969 [==============================] - 8s 240us/sample - loss: 5.8755e-04 - mean_squared_error: 5.8755e-04 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 15/30
# 33969/33969 [==============================] - 8s 238us/sample - loss: 5.8978e-04 - mean_squared_error: 5.8978e-04 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 16/30
# 33969/33969 [==============================] - 8s 239us/sample - loss: 5.6474e-04 - mean_squared_error: 5.6474e-04 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 17/30
# 33969/33969 [==============================] - 9s 252us/sample - loss: 6.0663e-04 - mean_squared_error: 6.0663e-04 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 18/30
# 33969/33969 [==============================] - 9s 256us/sample - loss: 6.8140e-04 - mean_squared_error: 6.8140e-04 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 19/30
# 33969/33969 [==============================] - 9s 253us/sample - loss: 5.0660e-04 - mean_squared_error: 5.0660e-04 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 20/30
# 33969/33969 [==============================] - 8s 247us/sample - loss: 4.3590e-04 - mean_squared_error: 4.3590e-04 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 21/30
# 33969/33969 [==============================] - 8s 240us/sample - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 22/30
# 33969/33969 [==============================] - 8s 241us/sample - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 23/30
# 33969/33969 [==============================] - 8s 239us/sample - loss: 6.5974e-04 - mean_squared_error: 6.5974e-04 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 24/30
# 33969/33969 [==============================] - 8s 239us/sample - loss: 5.5125e-04 - mean_squared_error: 5.5125e-04 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 25/30
# 33969/33969 [==============================] - 9s 254us/sample - loss: 4.6134e-04 - mean_squared_error: 4.6134e-04 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 26/30
# 33969/33969 [==============================] - 9s 255us/sample - loss: 4.8967e-04 - mean_squared_error: 4.8967e-04 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 27/30
# 33969/33969 [==============================] - 9s 256us/sample - loss: 6.3057e-04 - mean_squared_error: 6.3057e-04 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 28/30
# 33969/33969 [==============================] - 8s 245us/sample - loss: 4.7454e-04 - mean_squared_error: 4.7454e-04 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 29/30
# 33969/33969 [==============================] - 8s 240us/sample - loss: 4.2712e-04 - mean_squared_error: 4.2712e-04 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 30/30
# 33969/33969 [==============================] - 8s 241us/sample - loss: 3.5208e-04 - mean_squared_error: 3.5208e-04 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
#
# MSE Loss: 0.004627186683287594
#
# learning rate: 8.0e-05
# num_LSTM_layers: 2
# num_LSTM_nodes: 154
# dropout: 0.1181404665083873
#
# Train on 33969 samples, validate on 4231 samples
# Epoch 1/30
# 33969/33969 [==============================] - 9s 268us/sample - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 2/30
# 33969/33969 [==============================] - 8s 247us/sample - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 3/30
# 33969/33969 [==============================] - 9s 255us/sample - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 4/30
# 33969/33969 [==============================] - 9s 255us/sample - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 5/30
# 33969/33969 [==============================] - 9s 252us/sample - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 6/30
# 33969/33969 [==============================] - 8s 240us/sample - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 7/30
# 33969/33969 [==============================] - 8s 241us/sample - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 8/30
# 33969/33969 [==============================] - 8s 241us/sample - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 9/30
# 33969/33969 [==============================] - 8s 240us/sample - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 10/30
# 33969/33969 [==============================] - 8s 245us/sample - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 11/30
# 33969/33969 [==============================] - 9s 256us/sample - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 12/30
# 33969/33969 [==============================] - 9s 260us/sample - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 13/30
# 33969/33969 [==============================] - 9s 253us/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 14/30
# 33969/33969 [==============================] - 8s 243us/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 15/30
# 33969/33969 [==============================] - 8s 243us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 16/30
# 33969/33969 [==============================] - 8s 238us/sample - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 17/30
# 33969/33969 [==============================] - 8s 240us/sample - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 18/30
# 33969/33969 [==============================] - 8s 250us/sample - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 19/30
# 33969/33969 [==============================] - 9s 257us/sample - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 20/30
# 33969/33969 [==============================] - 9s 256us/sample - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 21/30
# 33969/33969 [==============================] - 8s 247us/sample - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 22/30
# 33969/33969 [==============================] - 9s 251us/sample - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 23/30
# 33969/33969 [==============================] - 9s 256us/sample - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 24/30
# 33969/33969 [==============================] - 9s 256us/sample - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 25/30
# 33969/33969 [==============================] - 8s 247us/sample - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 26/30
# 33969/33969 [==============================] - 8s 241us/sample - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 27/30
# 33969/33969 [==============================] - 8s 239us/sample - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 28/30
# 33969/33969 [==============================] - 8s 239us/sample - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 29/30
# 33969/33969 [==============================] - 8s 240us/sample - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 30/30
# 33969/33969 [==============================] - 9s 252us/sample - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
#
# MSE Loss: 0.004682221449911594
#
# learning rate: 2.8e-04
# num_LSTM_layers: 2
# num_LSTM_nodes: 254
# dropout: 0.21765970895070763
#
# Train on 33969 samples, validate on 4231 samples
# Epoch 1/30
# 33969/33969 [==============================] - 10s 282us/sample - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 2/30
# 33969/33969 [==============================] - 9s 256us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 3/30
# 33969/33969 [==============================] - 8s 242us/sample - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 4/30
# 33969/33969 [==============================] - 8s 243us/sample - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 5/30
# 33969/33969 [==============================] - 8s 240us/sample - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 6/30
# 33969/33969 [==============================] - 8s 240us/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 7/30
# 33969/33969 [==============================] - 8s 245us/sample - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 8/30
# 33969/33969 [==============================] - 9s 258us/sample - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 9/30
# 33969/33969 [==============================] - 9s 258us/sample - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 10/30
# 33969/33969 [==============================] - 9s 254us/sample - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 11/30
# 33969/33969 [==============================] - 8s 241us/sample - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 12/30
# 33969/33969 [==============================] - 8s 242us/sample - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 13/30
# 33969/33969 [==============================] - 8s 241us/sample - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 14/30
# 33969/33969 [==============================] - 8s 244us/sample - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 15/30
# 33969/33969 [==============================] - 8s 249us/sample - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 16/30
# 33969/33969 [==============================] - 9s 258us/sample - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 17/30
# 33969/33969 [==============================] - 9s 260us/sample - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 18/30
# 33969/33969 [==============================] - 9s 253us/sample - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch
- val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 17/30
# 33969/33969 [==============================] - 8s 243us/sample - loss: 4.9312e-04 - mean_squared_error: 4.9312e-04 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 18/30
# 33969/33969 [==============================] - 8s 241us/sample - loss: 4.5079e-04 - mean_squared_error: 4.5079e-04 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 19/30
# 33969/33969 [==============================] - 8s 242us/sample - loss: 5.9100e-04 - mean_squared_error: 5.9100e-04 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 20/30
# 33969/33969 [==============================] - 9s 254us/sample - loss: 4.3549e-04 - mean_squared_error: 4.3549e-04 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 21/30
# 33969/33969 [==============================] - 9s 256us/sample - loss: 3.7979e-04 - mean_squared_error: 3.7979e-04 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 22/30
# 33969/33969 [==============================] - 9s 255us/sample - loss: 3.8660e-04 - mean_squared_error: 3.8660e-04 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 23/30
# 33969/33969 [==============================] - 8s 244us/sample - loss: 4.7184e-04 - mean_squared_error: 4.7184e-04 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 24/30
# 33969/33969 [==============================] - 8s 244us/sample - loss: 3.6145e-04 - mean_squared_error: 3.6145e-04 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 25/30
# 33969/33969 [==============================] - 8s 245us/sample - loss: 5.0895e-04 - mean_squared_error: 5.0895e-04 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 26/30
# ...
# Epoch 3/30
# 33969/33969 [==============================] - 9s 265us/sample - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0081 - val_mean_squared_error: 0.0081
# Epoch 4/30
# 33969/33969 [==============================] - 9s 277us/sample - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 5/30
# 33969/33969 [==============================] - 9s 275us/sample - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 6/30
# 33969/33969 [==============================] - 9s 270us/sample - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 7/30
# 33969/33969 [==============================] - 9s 258us/sample - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 8/30
# 33969/33969 [==============================] - 9s 258us/sample - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 9/30
# 33969/33969 [==============================] - 9s 257us/sample - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 10/30
# 33969/33969 [==============================] - 9s 255us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 11/30
# 33969/33969 [==============================] - 9s 270us/sample - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 12/30
# 33969/33969 [==============================] - 9s 275us/sample - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 13/30
# 33969/33969 [==============================] - 9s 273us/sample - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 14/30
# 33969/33969 [==============================] - 9s 259us/sample - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 15/30
# 33969/33969 [==============================] - 9s 258us/sample - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 16/30
# 33969/33969 [==============================] - 9s 256us/sample - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 17/30
# 33969/33969 [==============================] - 9s 255us/sample - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 18/30
# 33969/33969 [==============================] - 9s 260us/sample - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 19/30
# 33969/33969 [==============================] - 9s 275us/sample - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 20/30
# 33969/33969 [==============================] - 9s 275us/sample - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 21/30
# 33969/33969 [==============================] - 9s 269us/sample - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 22/30
# 33969/33969 [==============================] - 9s 256us/sample - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 23/30
# 33969/33969 [==============================] - 9s 258us/sample - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 24/30
# 33969/33969 [==============================] - 9s 254us/sample - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 25/30
# 33969/33969 [==============================] - 9s 254us/sample - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 26/30
# 33969/33969 [==============================] - 9s 270us/sample - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 27/30
# 33969/33969 [==============================] - 9s 273us/sample - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 28/30
# 33969/33969 [==============================] - 9s 275us/sample - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 29/30
# 33969/33969 [==============================] - 9s 259us/sample - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 30/30
# 33969/33969 [==============================] - 9s 258us/sample - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
#
# MSE Loss: 0.005304041826244355
#
# learning rate: 4.7e-03
# num_LSTM_layers: 3
# num_LSTM_nodes: 129
# dropout: 0.10045980229590634
#
# Train on 33969 samples, validate on 4231 samples
# Epoch 1/30
# 33969/33969 [==============================] - 14s 409us/sample - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 2/30
# 33969/33969 [==============================] - 13s 390us/sample - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 3/30
# 33969/33969 [==============================] - 14s 405us/sample - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 4/30
# 33969/33969 [==============================] - 13s 393us/sample - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 5/30
# 33969/33969 [==============================] - 14s 399us/sample - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 6/30
# 33969/33969 [==============================] - 13s 393us/sample - loss: 9.6661e-04 - mean_squared_error: 9.6661e-04 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 7/30
# 33969/33969 [==============================] - 13s 373us/sample - loss: 9.3771e-04 - mean_squared_error: 9.3771e-04 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 8/30
# 33969/33969 [==============================] - 13s 378us/sample - loss: 8.2824e-04 - mean_squared_error: 8.2824e-04 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 9/30
# 33969/33969 [==============================] - 13s 370us/sample - loss: 7.0163e-04 - mean_squared_error: 7.0163e-04 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 10/30
# 33969/33969 [==============================] - 13s 397us/sample - loss: 5.6709e-04 - mean_squared_error: 5.6709e-04 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 11/30
# 33969/33969 [==============================] - 13s 395us/sample - loss: 6.0730e-04 - mean_squared_error: 6.0730e-04 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 12/30
# 33969/33969 [==============================] - 13s 385us/sample - loss: 5.6187e-04 - mean_squared_error: 5.6187e-04 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 13/30
# 33969/33969 [==============================] - 13s 374us/sample - loss: 7.6809e-04 - mean_squared_error: 7.6809e-04 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 14/30
# 33969/33969 [==============================] - 13s 370us/sample - loss: 5.1565e-04 - mean_squared_error: 5.1565e-04 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 15/30
# 33969/33969 [==============================] - 14s 402us/sample - loss: 3.8813e-04 - mean_squared_error: 3.8813e-04 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 16/30
# 33969/33969 [==============================] - 14s 403us/sample - loss: 3.6148e-04 - mean_squared_error: 3.6148e-04 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 17/30
# 33969/33969 [==============================] - 13s 383us/sample - loss: 3.0178e-04 - mean_squared_error: 3.0178e-04 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 18/30
# 33969/33969 [==============================] - 13s 380us/sample - loss: 3.8432e-04 - mean_squared_error: 3.8432e-04 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 19/30
# 33969/33969 [==============================] - 13s 379us/sample - loss: 4.3081e-04 - mean_squared_error: 4.3081e-04 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 20/30
# 33969/33969 [==============================] - 14s 412us/sample - loss: 3.3273e-04 - mean_squared_error: 3.3273e-04 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 21/30
# 33969/33969 [==============================] - 14s 399us/sample - loss: 2.9996e-04 - mean_squared_error: 2.9996e-04 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 22/30
# 33969/33969 [==============================] - 13s 373us/sample - loss: 3.7104e-04 - mean_squared_error: 3.7104e-04 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 23/30
# 33969/33969 [==============================] - 13s 369us/sample - loss: 3.2869e-04 - mean_squared_error: 3.2869e-04 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 24/30
# 33969/33969 [==============================] - 13s 371us/sample - loss: 4.2179e-04 - mean_squared_error: 4.2179e-04 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 25/30
# 33969/33969 [==============================] - 13s 397us/sample - loss: 3.4673e-04 - mean_squared_error: 3.4673e-04 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 26/30
# 33969/33969 [==============================] - 14s 406us/sample - loss: 2.9681e-04 - mean_squared_error: 2.9681e-04 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 27/30
# 33969/33969 [==============================] - 13s 375us/sample - loss: 3.1786e-04 - mean_squared_error: 3.1786e-04 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 28/30
# 33969/33969 [==============================] - 13s 373us/sample - loss: 2.1941e-04 - mean_squared_error: 2.1941e-04 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 29/30
# 33969/33969 [==============================] - 13s 375us/sample - loss: 2.6025e-04 - mean_squared_error: 2.6025e-04 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 30/30
# 33969/33969 [==============================] - 14s 406us/sample - loss: 8.8727e-04 - mean_squared_error: 8.8727e-04 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
#
# MSE Loss: 0.004662308638113747
#
# learning rate: 9.7e-03
# num_LSTM_layers: 2
# num_LSTM_nodes: 129
# dropout: 0.10646820456092246
#
# Train on 33969 samples, validate on 4231 samples
# Epoch 1/30
# 33969/33969 [==============================] - 10s 303us/sample - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 2/30
# 33969/33969 [==============================] - 9s 261us/sample - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 3/30
# 33969/33969 [==============================] - 9s 272us/sample - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 4/30
# 33969/33969 [==============================] - 9s 271us/sample - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 5/30
# 33969/33969 [==============================] - 9s 268us/sample - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 6/30
# 33969/33969 [==============================] - 9s 256us/sample - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 7/30
# 33969/33969 [==============================] - 9s 256us/sample - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 8/30
# 33969/33969 [==============================] - 9s 255us/sample - loss: 9.1919e-04 - mean_squared_error: 9.1919e-04 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 9/30
# 33969/33969 [==============================] - 9s 255us/sample - loss: 7.3748e-04 - mean_squared_error: 7.3748e-04 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 10/30
# 33969/33969 [==============================] - 9s 266us/sample - loss: 7.9814e-04 - mean_squared_error: 7.9814e-04 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 11/30
# 33969/33969 [==============================] - 9s 272us/sample - loss: 7.1722e-04 - mean_squared_error: 7.1722e-04 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 12/30
# 33969/33969 [==============================] - 9s 270us/sample - loss: 6.1201e-04 - mean_squared_error: 6.1201e-04 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 13/30
# 33969/33969 [==============================] - 9s 261us/sample - loss: 5.4515e-04 - mean_squared_error: 5.4515e-04 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 14/30
# 33969/33969 [==============================] - 9s 256us/sample - loss: 5.7107e-04 - mean_squared_error: 5.7107e-04 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 15/30
# 33969/33969 [==============================] - 9s 252us/sample - loss: 4.8770e-04 - mean_squared_error: 4.8770e-04 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 16/30
# 33969/33969 [==============================] - 9s 253us/sample - loss: 4.4812e-04 - mean_squared_error: 4.4812e-04 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 17/30
# 33969/33969 [==============================] - 9s 257us/sample - loss: 5.5218e-04 - mean_squared_error: 5.5218e-04 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 18/30
# 33969/33969 [==============================] - 9s 270us/sample - loss: 6.1749e-04 - mean_squared_error: 6.1749e-04 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 19/30
# 33969/33969 [==============================] - 9s 269us/sample - loss: 7.9013e-04 - mean_squared_error: 7.9013e-04 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 20/30
# 33969/33969 [==============================] - 9s 263us/sample - loss: 4.9834e-04 - mean_squared_error: 4.9834e-04 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 21/30
# 33969/33969 [==============================] - 9s 254us/sample - loss: 3.8639e-04 - mean_squared_error: 3.8639e-04 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 22/30
# 33969/33969 [==============================] - 9s 257us/sample - loss: 3.9622e-04 - mean_squared_error: 3.9622e-04 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 23/30
# 33969/33969 [==============================] - 9s 253us/sample - loss: 4.9541e-04 - mean_squared_error: 4.9541e-04 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 24/30
# 33969/33969 [==============================] - 9s 252us/sample - loss: 3.6448e-04 - mean_squared_error: 3.6448e-04 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 25/30
# 33969/33969 [==============================] - 9s 268us/sample - loss: 4.1083e-04 - mean_squared_error: 4.1083e-04 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 26/30
# 33969/33969 [==============================] - 9s 271us/sample - loss: 3.8171e-04 - mean_squared_error: 3.8171e-04 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 27/30
# 33969/33969 [==============================] - 9s 271us/sample - loss: 2.9158e-04 - mean_squared_error: 2.9158e-04 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 28/30
# 33969/33969 [==============================] - 9s 256us/sample - loss: 3.0341e-04 - mean_squared_error: 3.0341e-04 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 29/30
# 33969/33969 [==============================] - 9s 258us/sample - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 30/30
# 33969/33969 [==============================] - 9s 255us/sample - loss: 7.0720e-04 - mean_squared_error: 7.0720e-04 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# MSE Loss: 0.004800623074337696
#
# Optimization Run Time:  131.36213230292003

# %%
plot_convergence(search_result)

# %%
#best hyperparameters
print("Best Hyperparameters: ",search_result.x)

#corr. result
print(search_result.fun)
# Out:
# Best Hyperparameters:  [0.00027977220725186163, 2, 254, 0.21765970895070763]
# 0.004151109200101051

# %%
#All Results
sorted(zip(search_result.func_vals, search_result.x_iters))
# Out:
# [(0.004151109200101051, [0.00027977220725186163, 2, 254, 0.21765970895070763]),
#  (0.0041766081140872996, [0.0001828199490774879, 2, 217, 0.18779771047996913]),
#  (0.0043665167256201195,
#   [0.00041698289415033357, 2, 175, 0.10735375158190397]),
#  (0.004479902758806965, [0.00732479949908014, 3, 128, 0.10352851796891144]),
#  (0.004618734419253406, [0.007068984491827959, 3, 189, 0.12644443886004214]),
#  (0.004627186683287594, [0.008408557655854385, 2, 212, 0.20700938183848705]),
#  (0.004662308638113747, [0.004650362293501307, 3, 129, 0.10045980229590634]),
#  (0.004682221449911594, [8.02719062148168e-05, 2, 154, 0.1181404665083873]),
#  (0.004683035231875888, [0.004578811383975355, 2, 217, 0.21877413591793088]),
#  (0.0047671576265804335, [0.009069599713711001, 2, 129, 0.10174692132662758]),
#  (0.004800623074337696, [0.00967543148480236, 2, 129, 0.10646820456092246]),
#  (0.005032973343304386, [0.001, 2, 256, 0.2]),
#  (0.005061707052390532, [0.0013208712658894744, 3, 245, 0.14706858066960696]),
#  (0.005161682107157633, [1.2135659701202448e-05, 2, 131, 0.10027651170105237]),
#  (0.005165782660966564, [1.0381584143037392e-05, 2, 129, 0.24612060695632995]),
#  (0.0051712192753160385, [0.004145018396732054, 2, 240, 0.1276499768674319]),
#  (0.005209574040695844, [1.604242757659496e-05, 3, 128, 0.24889961321763504]),
#  (0.005270078986141583, [1.140219288298892e-05, 3, 152, 0.15803695505277737]),
#  (0.00529088238084698, [1.4836666644404804e-05, 3, 251, 0.10172968490085722]),
#  (0.005304041826244355, [1.1445091761526969e-05, 2, 251, 0.10176217331982876]),
#  (0.0054061500719017426, [0.0075766045390234, 3, 129, 0.24796624405116496]),
#  (0.0055567414616042, [1.0959292806451235e-05, 3, 256, 0.102242781023547]),
#  (0.005588051523921712, [1.212149968096512e-05, 2, 133, 0.24723430548904235]),
#  (0.0056426802887161965,
#   [1.0646315433105025e-05, 3, 252, 0.23921218601840452]),
#  (0.010972514241749803, [0.009941285021806209, 3, 255, 0.24109144275052127])]

# %%
from skopt.plots import plot_objective_2D
fig = plot_objective_2D(result=search_result,
                        dimension_identifier1='learning_rate',
                        dimension_identifier2='num_nodes',
                        levels=50)

# %%
# create a list for plotting
dim_names = ['learning_rate', 'num_layers', 'num_nodes', 'dropout' ]

fig, ax = plot_objective(result=search_result, dimensions=dim_names)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-3bbb1a2a0eee> in <module>()
#       2 dim_names = ['learning_rate', 'num_layers', 'num_nodes', 'dropout' ]
#       3
# ----> 4 fig, ax = plot_objective(result=search_result, dimensions=dim_names)
#
# ValueError: too many values to unpack (expected 2)

# %%
best_model= load_model(path_best_model)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-85d05bbce0f2> in <module>()
# ----> 1 best_model= load_model(path_best_model)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/keras/saving/save.py in load_model(filepath, custom_objects, compile)
#     141   if (h5py is not None and (
#     142       isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 143     return hdf5_format.load_model_from_hdf5(filepath, custom_objects, compile)
#     144
#     145   if isinstance(filepath, six.string_types):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/keras/saving/hdf5_format.py in load_model_from_hdf5(filepath, custom_objects, compile)
#     158     if model_config is None:
#     159       raise ValueError('No model found in config file.')
# --> 160     model_config = json.loads(model_config.decode('utf-8'))
#     161     model = model_config_lib.model_from_config(model_config,
#     162                                                custom_objects=custom_objects)
#
# AttributeError: 'str' object has no attribute 'decode'

# %%
opt_par = search_result.x
# use hyper-parameters from optimization
learning_rate = opt_par[0]
num_layers = opt_par[1]
num_nodes = opt_par[2]
dropout_value = opt_par[3]

model = Sequential()
model.add(InputLayer(input_shape=(None, 13)))
for i in range(num_layers-1):
    name = 'layer_LSTM_{0}'.format(i+1)
    model.add(LSTM(units=num_nodes, return_sequences=True, activation='tanh', name=name))
    model.add(Dropout(dropout_value))
model.add(LSTM(units=num_nodes, activation='tanh'))
model.add(Dropout(dropout_value))
model.add(Dense(units=1))
# Adam Optimizer
optimizer = Adam(lr=learning_rate)
model.summary()
model.compile(optimizer=optimizer, loss='MSE', metrics=[tf.keras.metrics.MeanSquaredError()])

monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=20, verbose=1, mode='auto', restore_best_weights=True)

histories = model.fit(x_train, y_train, validation_data=(x_val,y_val), callbacks=[monitor],verbose=2,epochs=100)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_LSTM_1 (LSTM)          (None, None, 254)         272288
# _________________________________________________________________
# dropout (Dropout)            (None, None, 254)         0
# _________________________________________________________________
# lstm (LSTM)                  (None, 254)               517144
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 254)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 255
# =================================================================
# Total params: 789,687
# Trainable params: 789,687
# Non-trainable params: 0
# _________________________________________________________________
# Train on 33969 samples, validate on 4231 samples
# Epoch 1/100
# 33969/33969 - 33s - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 2/100
# 33969/33969 - 31s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 3/100
# 33969/33969 - 31s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 4/100
# 33969/33969 - 31s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 5/100
# 33969/33969 - 31s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 6/100
# 33969/33969 - 32s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 7/100
# 33969/33969 - 31s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 8/100
# 33969/33969 - 32s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 9/100
# 33969/33969 - 31s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 10/100
# 33969/33969 - 32s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 11/100
# 33969/33969 - 32s - loss: 9.0255e-04 - mean_squared_error: 9.0255e-04 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 12/100
# 33969/33969 - 30s - loss: 8.3905e-04 - mean_squared_error: 8.3905e-04 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 13/100
# 33969/33969 - 32s - loss: 7.5698e-04 - mean_squared_error: 7.5698e-04 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 14/100
# 33969/33969 - 30s - loss: 7.1764e-04 - mean_squared_error: 7.1764e-04 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 15/100
# 33969/33969 - 32s - loss: 6.4658e-04 - mean_squared_error: 6.4658e-04 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 16/100
# 33969/33969 - 31s - loss: 5.8789e-04 - mean_squared_error: 5.8789e-04 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 17/100
# 33969/33969 - 31s - loss: 5.3025e-04 - mean_squared_error: 5.3025e-04 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 18/100
# 33969/33969 - 31s - loss: 5.2174e-04 - mean_squared_error: 5.2174e-04 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 19/100
# 33969/33969 - 31s - loss: 4.6881e-04 - mean_squared_error: 4.6881e-04 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 20/100
# 33969/33969 - 32s - loss: 4.3907e-04 - mean_squared_error: 4.3907e-04 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 21/100
# 33969/33969 - 31s - loss: 4.0089e-04 - mean_squared_error: 4.0089e-04 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 22/100
# 33969/33969 - 31s - loss: 3.8447e-04 - mean_squared_error: 3.8447e-04 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 23/100
# 33969/33969 - 31s - loss: 3.7387e-04 - mean_squared_error: 3.7387e-04 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 24/100
# 33969/33969 - 31s - loss: 3.3698e-04 - mean_squared_error: 3.3698e-04 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 25/100
# 33969/33969 - 31s - loss: 3.3282e-04 - mean_squared_error: 3.3282e-04 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 26/100
# Restoring model weights from the end of the best epoch.
# 33969/33969 - 31s - loss: 3.2483e-04 - mean_squared_error: 3.2483e-04 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 00026: early stopping

# %%
plt.plot(histories.history['loss'], 'b')
plt.plot(histories.history['val_loss'],'r' )
plt.title('Training and Validation')
plt.ylabel('MSE Loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.savefig('/content/gdrive/MyDrive/SoilMoisture/LSTM_Images/MSE_c5_100.png', dpi=400)
plt.show()
