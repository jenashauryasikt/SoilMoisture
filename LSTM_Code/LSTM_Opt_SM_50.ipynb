# %%
# !pip install tensorflow==1.15.0
# !pip install scikit-optimize

# %%
import numpy as np
import pandas as pd
import time

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Input
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM, Dropout
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping

import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.colors as colors
import matplotlib as mpl

# %%
import skopt
from skopt import gp_minimize, forest_minimize
from skopt.space import Real, Categorical, Integer
from skopt.plots import plot_convergence
from skopt.plots import plot_objective, plot_evaluations
from skopt.plots import plot_objective
from skopt.utils import use_named_args

# %%
randomState = 42
np.random.seed(randomState)
tf.set_random_seed(randomState)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
raw10 = pd.read_csv('/content/gdrive/MyDrive/SoilMoisture/Data/c_5_data_soil_50.csv')
df10 = raw10.copy()

df10 = df10.rename(columns={'In-Situ':'InSitu'})

def replace_missing(attribute):
    return attribute.interpolate(inplace=True)

replace_missing(df10['NDVI'])
replace_missing(df10['EVI'])
replace_missing(df10['LSTDay'])
replace_missing(df10['LSTNight'])

df10 = df10.dropna()
df10.isnull().sum()
# Out:
# Precip       0
# NDVI         0
# EVI          0
# GPP          0
# LSTDay       0
# LSTNight     0
# Elevation    0
# RZSM         0
# SURFSM       0
# Clay         0
# Sand         0
# Silt         0
# BD           0
# InSitu       0
# dtype: int64

# %%
df10['group'] = df10['Sand'].ne(df10['Sand'].shift()).cumsum()
df10 = df10.groupby('group')
dfs = []
for name, data in df10:
    dfs.append(data)

# %%
train_dataset = pd.DataFrame()
val_dataset = pd.DataFrame()
test_dataset = pd.DataFrame()

for df in dfs:
    df.pop('group')
    train_size = int(len(df)*0.8)
    val_size = int(len(df)*0.9)
    train, val, test = df.iloc[:train_size], df.iloc[train_size:val_size], df.iloc[val_size:]
    train_dataset = train_dataset.append(train)
    val_dataset = val_dataset.append(val)
    test_dataset = test_dataset.append(test)

# %%
# Split X
X_train = train_dataset.drop('InSitu', axis = 1)
X_val = val_dataset.drop('InSitu', axis = 1)
X_test = test_dataset.drop('InSitu', axis = 1)

# Split y
y_train = train_dataset.loc[:,['InSitu']]
y_val = val_dataset.loc[:,['InSitu']]
y_test = test_dataset.loc[:,['InSitu']]

# %%
# Fit the scaler using available training data
input_scaler = StandardScaler().fit(X_train)

# Apply the scaler to training data
x_train = input_scaler.transform(X_train)
x_val = input_scaler.transform(X_val)
x_test = input_scaler.transform(X_test)

x_train = np.array(x_train, np.float32)
y_train = np.array(y_train, np.float32)

x_val = np.array(x_val, np.float32)
y_val = np.array(y_val, np.float32)

x_test = np.array(x_test, np.float32)
y_test = np.array(y_test, np.float32)

y_train = y_train.reshape((y_train.size, 1))
y_val = y_val.reshape((y_val.size, 1))
y_test = y_test.reshape((y_test.size, 1))

# %%
def create_dataset (X, y, time_steps = 1):
    Xs, ys= [], []
    for i in range(len(X)-time_steps):
        v = X[i:i+time_steps, :]
        Xs.append(v)
        ys.append(y[i+time_steps])        
    return np.array(Xs), np.array(ys)

TIME_STEPS = 15

x_test, y_test = create_dataset(x_test, y_test, TIME_STEPS)
x_train, y_train = create_dataset(x_train, y_train, TIME_STEPS)
x_val, y_val = create_dataset(x_val, y_val, TIME_STEPS)

# %%
dim_learning_rate = Real(low=1e-5, high=1e-2, prior='log-uniform', name='learning_rate')
dim_num_layers = Integer(low=2, high=3, name='num_layers')
dim_num_nodes = Integer(low=128, high=256, name='num_nodes')
dim_dropout_val = Real(low=0.10, high=0.25, name='dropout_val')

dimensions = [dim_learning_rate,
              dim_num_layers,
              dim_num_nodes,
              dim_dropout_val]

default_parameters = [1e-3, 2, 256, 0.2]

# %%
# To log traning progress
def log_dir_name(learning_rate, num_layers, num_nodes, dropout_val):
    # dir-name for TensorBoard log-dir.
    s = "/content/gdrive/MyDrive/SoilMoisture/LSTMlogs/lr_{0:.0e}_layers_{1}_nodes_{2}_dropout_{3}"
    log_dir = s.format(learning_rate, num_layers, num_nodes, dropout_val)

    return log_dir

# %%
#To create model with determined hyperparameters
def create_model(learning_rate, num_layers, num_nodes, dropout_val):
    model = Sequential()
    model.add(InputLayer(input_shape=(None, 13)))
    for i in range(num_layers-1):
        name = 'layer_LSTM_{0}'.format(i+1)
        model.add(LSTM(units=num_nodes, return_sequences=True, activation='tanh', name=name))
        model.add(Dropout(dropout_val))
    model.add(LSTM(units=num_nodes, activation='tanh'))
    model.add(Dropout(dropout_val))
    model.add(Dense(units=1))
    # Adam Optimizer
    optimizer = Adam(lr=learning_rate)
    model.compile(optimizer=optimizer, loss='MSE', metrics=[tf.keras.metrics.MeanSquaredError()])
    
    return model

path_best_model = '/content/gdrive/MyDrive/SoilMoisture/LSTM_Models/LSTM_50_best_model.h5'
validation_data = (x_val, y_val)
best_loss = 5.0

# %%
@use_named_args(dimensions=dimensions)
def fitness(learning_rate, num_layers, num_nodes, dropout_val):
    """
    Hyper-parameters:
    learning_rate: Learning-rate for the optimizer.
    num_layers:    Number of LSTM layers.
    num_nodes:     Number of nodes in each LSTM layer.
    dropout_val:   Dropout.
    """
    # Print the hyper-parameters
    print('learning rate: {0:.1e}'.format(learning_rate))
    print('num_LSTM_layers:', num_layers)
    print('num_LSTM_nodes:', num_nodes)
    print('dropout:', dropout_val)
    print()    
    # Create the LSTM
    model = create_model(learning_rate=learning_rate,
                         num_layers=num_layers,
                         num_nodes=num_nodes,
                         dropout_val=dropout_val)
    # Dir-name for TensorBoard log-files.
    log_dir = log_dir_name(learning_rate, num_layers, num_nodes, dropout_val)
    #callback
    callback_log = TensorBoard(log_dir=log_dir, histogram_freq=0, write_graph=True, write_grads=False, write_images=False)
    # Use Keras to train the model.
    history = model.fit(x= x_train,
                        y= y_train,
                        epochs=30,
                        batch_size=128,
                        validation_data=validation_data,
                        callbacks=[callback_log])

    loss = history.history['val_loss'][-1]

    print()
    print("MSE Loss:", loss)
    print()

    global best_loss

    if loss < best_loss:
        # Save the new model
        model.save(path_best_model)
        best_loss = loss

    del model
    
    K.clear_session()
    
    return loss

# %%
start = time.time()
search_result = gp_minimize(func=fitness,
                            dimensions=dimensions,
                            acq_func='EI',          # Expected Improvement.
                            n_calls=25,
                            x0=default_parameters)
print("Optimization Run Time: ", (time.time()-start)/60)
# Out:
# learning rate: 1.0e-03
# num_LSTM_layers: 2
# num_LSTM_nodes: 256
# dropout: 0.2
#
# Train on 36602 samples, validate on 4562 samples
# Epoch 1/30
# 36602/36602 [==============================] - 10s 264us/sample - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 2/30
# 36602/36602 [==============================] - 9s 236us/sample - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 3/30
# 36602/36602 [==============================] - 9s 249us/sample - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 4/30
# 36602/36602 [==============================] - 9s 252us/sample - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 5/30
# 36602/36602 [==============================] - 9s 253us/sample - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 6/30
# 36602/36602 [==============================] - 9s 245us/sample - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 7/30
# 36602/36602 [==============================] - 9s 239us/sample - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 8/30
# 36602/36602 [==============================] - 9s 239us/sample - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 9/30
# 36602/36602 [==============================] - 9s 235us/sample - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 10/30
# 36602/36602 [==============================] - 9s 242us/sample - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 11/30
# 36602/36602 [==============================] - 9s 251us/sample - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 12/30
# 36602/36602 [==============================] - 9s 251us/sample - loss: 9.6899e-04 - mean_squared_error: 9.6899e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 13/30
# 36602/36602 [==============================] - 9s 243us/sample - loss: 8.9593e-04 - mean_squared_error: 8.9593e-04 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 14/30
# 36602/36602 [==============================] - 9s 241us/sample - loss: 8.3698e-04 - mean_squared_error: 8.3698e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 15/30
# 36602/36602 [==============================] - 9s 241us/sample - loss: 7.9552e-04 - mean_squared_error: 7.9552e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 16/30
# 36602/36602 [==============================] - 9s 236us/sample - loss: 7.0964e-04 - mean_squared_error: 7.0964e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 17/30
# 36602/36602 [==============================] - 9s 239us/sample - loss: 6.5140e-04 - mean_squared_error: 6.5140e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 18/30
# 36602/36602 [==============================] - 9s 252us/sample - loss: 6.1768e-04 - mean_squared_error: 6.1768e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 19/30
# 36602/36602 [==============================] - 9s 254us/sample - loss: 6.2157e-04 - mean_squared_error: 6.2157e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 20/30
# 36602/36602 [==============================] - 9s 253us/sample - loss: 5.1080e-04 - mean_squared_error: 5.1080e-04 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 21/30
# 36602/36602 [==============================] - 9s 242us/sample - loss: 5.1567e-04 - mean_squared_error: 5.1567e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 22/30
# 36602/36602 [==============================] - 9s 238us/sample - loss: 5.0359e-04 - mean_squared_error: 5.0359e-04 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 23/30
# 36602/36602 [==============================] - 9s 236us/sample - loss: 4.3543e-04 - mean_squared_error: 4.3543e-04 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 24/30
# 36602/36602 [==============================] - 9s 236us/sample - loss: 4.1609e-04 - mean_squared_error: 4.1609e-04 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 25/30
# 36602/36602 [==============================] - 9s 244us/sample - loss: 4.8065e-04 - mean_squared_error: 4.8065e-04 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch
loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 28/30
# 36602/36602 [==============================] - 9s 250us/sample - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 29/30
# 36602/36602 [==============================] - 9s 248us/sample - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 30/30
# 36602/36602 [==============================] - 9s 252us/sample - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
#
# MSE Loss: 0.003689338878251968
#
# learning rate: 1.2e-05
# num_LSTM_layers: 2
# num_LSTM_nodes: 199
# dropout: 0.20336248028318915
#
# Train on 36602 samples, validate on 4562 samples
# Epoch 1/30
# 36602/36602 [==============================] - 10s 285us/sample - loss: 0.0283 - mean_squared_error: 0.0283 - val_loss: 0.0105 - val_mean_squared_error: 0.0105
# Epoch 2/30
# 36602/36602 [==============================] - 10s 271us/sample - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0076 - val_mean_squared_error: 0.0076
# Epoch 3/30
# 36602/36602 [==============================] - 10s 268us/sample - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 4/30
# 36602/36602 [==============================] - 9s 259us/sample - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 5/30
# 36602/36602 [==============================] - 9s 249us/sample - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 6/30
# 36602/36602 [==============================] - 9s 247us/sample - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 7/30
# 36602/36602 [==============================] - 9s 245us/sample - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 8/30
# 36602/36602 [==============================] - 9s 254us/sample - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 9/30
# 36602/36602 [==============================] - 10s 263us/sample - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 10/30
# 36602/36602 [==============================] - 10s 262us/sample - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 11/30
# 36602/36602 [==============================] - 9s 251us/sample - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 12/30
# 36602/36602 [==============================] - 9s 253us/sample - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 13/30
# 36602/36602 [==============================] - 9s 249us/sample - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 14/30
# 36602/36602 [==============================] - 9s 245us/sample - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 15/30
# 36602/36602 [==============================] - 9s 251us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 16/30
# 36602/36602 [==============================] - 10s 265us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 17/30
# 36602/36602 [==============================] - 10s 262us/sample - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 18/30
# 36602/36602 [==============================] - 9s 258us/sample - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 19/30
# 36602/36602 [==============================] - 9s 259us/sample - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 20/30
# 36602/36602 [==============================] - 10s 266us/sample - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 21/30
# 36602/36602 [==============================] - 10s 260us/sample - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 22/30
# 36602/36602 [==============================] - 9s 249us/sample - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 23/30
# 36602/36602 [==============================] - 9s 247us/sample - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 24/30
# 36602/36602 [==============================] - 9s 246us/sample - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 25/30
# 36602/36602 [==============================] - 9s 244us/sample - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 26/30
# 36602/36602 [==============================] - 9s 258us/sample - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 27/30
# 36602/36602 [==============================] - 10s 261us/sample - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 28/30
# 36602/36602 [==============================] - 10s 265us/sample - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 29/30
# 36602/36602 [==============================] - 9s 248us/sample - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 30/30
# 36602/36602 [==============================] - 9s 251us/sample - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
#
# MSE Loss: 0.0038759780603476075
#
# learning rate: 3.8e-03
# num_LSTM_layers: 3
# num_LSTM_nodes: 232
# dropout: 0.1871654366983168
#
# Train on 36602 samples, validate on 4562 samples
# Epoch 1/30
# 36602/36602 [==============================] - 14s 392us/sample - loss: 0.0081 - mean_squared_error: 0.0081 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch
- val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 29/30
# 36602/36602 [==============================] - 13s 367us/sample - loss: 3.8122e-04 - mean_squared_error: 3.8122e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 30/30
# 36602/36602 [==============================] - 14s 373us/sample - loss: 3.0743e-04 - mean_squared_error: 3.0743e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
#
# MSE Loss: 0.003254933791571525
#
# learning rate: 1.1e-04
# num_LSTM_layers: 2
# num_LSTM_nodes: 238
# dropout: 0.22302366719587016
#
# Train on 36602 samples, validate on 4562 samples
# Epoch 1/30
# 36602/36602 [==============================] - 10s 271us/sample - loss: 0.0097 - mean_squared_error: 0.0097 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 2/30
# 36602/36602 [==============================] - 9s 246us/sample - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 3/30
# 36602/36602 [==============================] - 9s 243us/sample - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 4/30
# 36602/36602 [==============================] - 9s 247us/sample - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 5/30
# 36602/36602 [==============================] - 9s 253us/sample - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 6/30
# 36602/36602 [==============================] - 10s 264us/sample - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 7/30
# 36602/36602 [==============================] - 10s 261us/sample - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 8/30
# 36602/36602 [==============================] - 9s 253us/sample - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 9/30
# 36602/36602 [==============================] - 9s 250us/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 10/30
# 36602/36602 [==============================] - 9s 245us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 11/30
# 36602/36602 [==============================] - 9s 244us/sample - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 12/30
# 36602/36602 [==============================] - 9s 252us/sample - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 13/30
# 36602/36602 [==============================] - 10s 267us/sample - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 14/30
# 36602/36602 [==============================] - 10s 260us/sample - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 15/30
# 36602/36602 [==============================] - 9s 253us/sample - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 16/30
# 36602/36602 [==============================] - 10s 262us/sample - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 17/30
# 36602/36602 [==============================] - 10s 261us/sample - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 18/30
# 36602/36602 [==============================] - 10s 260us/sample - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 19/30
# 36602/36602 [==============================] - 9s 247us/sample - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 20/30
# 36602/36602 [==============================] - 9s 247us/sample - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 21/30
# 36602/36602 [==============================] - 9s 247us/sample - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 22/30
# 36602/36602 [==============================] - 9s 246us/sample - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 23/30
# 36602/36602 [==============================] - 9s 259us/sample - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 24/30
# 36602/36602 [==============================] - 10s 260us/sample - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 25/30
# 36602/36602 [==============================] - 9s 259us/sample - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 26/30
# 36602/36602 [==============================] - 9s 245us/sample - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 27/30
# 36602/36602 [==============================] - 9s 251us/sample - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 28/30
# 36602/36602 [==============================] - 9s 245us/sample - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 29/30
# 36602/36602 [==============================] - 9s 249us/sample - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 30/30
# 36602/36602 [==============================] - 9s 256us/sample - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
#
# MSE Loss: 0.0031608468927451193
#
# learning rate: 1.0e-05
# num_LSTM_layers: 3
# num_LSTM_nodes: 158
# dropout: 0.21700056681060376
#
# Train on 36602 samples, validate on 4562 samples
# Epoch 1/30
# 36602/36602 [==============================] - 16s 425us/sample - loss: 0.0292 - mean_squared_error: 0.0292 - val_loss: 0.0096 - val_mean_squared_error: 0.0096
# Epoch 2/30
# 36602/36602 [==============================] - 13s 363us/sample - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0073 - val_mean_squared_error: 0.0073
# Epoch 3/30
# 36602/36602 [==============================] - 13s 359us/sample - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 4/30
# 36602/36602 [==============================] - 13s 356us/sample - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 5/30
# 36602/36602 [==============================] - 14s 377us/sample - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 6/30
# 36602/36602 [==============================] - 14s 381us/sample - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 7/30
# 36602/36602 [==============================] - 13s 365us/sample - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 8/30
# 36602/36602 [==============================] - 13s 357us/sample - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 9/30
# 36602/36602 [==============================] - 13s 361us/sample - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 10/30
# 36602/36602 [==============================] - 14s 382us/sample - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 11/30
# 36602/36602 [==============================] - 14s 390us/sample - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 12/30
# 36602/36602 [==============================] - 13s 363us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 13/30
# 36602/36602 [==============================] - 13s 355us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 14/30
# 36602/36602 [==============================] - 13s 356us/sample - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 15/30
# 36602/36602 [==============================] - 14s 380us/sample - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 16/30
# 36602/36602 [==============================] - 14s 376us/sample - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 17/30
# 36602/36602 [==============================] - 14s 372us/sample - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 18/30
# 36602/36602 [==============================] - 14s 380us/sample - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 19/30
# 36602/36602 [==============================] - 13s 369us/sample - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 20/30
# 36602/36602 [==============================] - 13s 368us/sample - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 21/30
# 36602/36602 [==============================] - 13s 361us/sample - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 22/30
# 36602/36602 [==============================] - 14s 379us/sample - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 23/30
# 36602/36602 [==============================] - 14s 380us/sample - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 24/30
# 36602/36602 [==============================] - 13s 361us/sample - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 25/30
# 36602/36602 [==============================] - 13s 365us/sample - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 26/30
# 36602/36602 [==============================] - 13s 356us/sample - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 27/30
# 36602/36602 [==============================] - 14s 382us/sample - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 28/30
# 36602/36602 [==============================] - 14s 385us/sample - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 29/30
# 36602/36602 [==============================] - 13s 365us/sample - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 30/30
# 36602/36602 [==============================] - 13s 360us/sample - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
#
# MSE Loss: 0.004083029607964981
#
# learning rate: 1.4e-03
# num_LSTM_layers: 2
# num_LSTM_nodes: 216
# dropout: 0.23735056180067413
#
# Train on 36602 samples, validate on 4562 samples
# Epoch 1/30
# 36602/36602 [==============================] - 10s 271us/sample - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 2/30
# 36602/36602 [==============================] - 10s 262us/sample - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 3/30
# 36602/36602 [==============================] - 10s 263us/sample - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 4/30
# 36602/36602 [==============================] - 10s 268us/sample - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 5/30
# 36602/36602 [==============================] - 9s 252us/sample - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 6/30
# 36602/36602 [==============================] - 9s 251us/sample - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 7/30
# 36602/36602 [==============================] - 9s 251us/sample - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 8/30
# 36602/36602 [==============================] - 9s 250us/sample - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 9/30
# 36602/36602 [==============================] - 10s 265us/sample - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch
- val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 15/30
# 36602/36602 [==============================] - 10s 271us/sample - loss: 5.3979e-04 - mean_squared_error: 5.3979e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 16/30
# 36602/36602 [==============================] - 10s 271us/sample - loss: 4.8971e-04 - mean_squared_error: 4.8971e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 17/30
# 36602/36602 [==============================] - 10s 267us/sample - loss: 8.7537e-04 - mean_squared_error: 8.7537e-04 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 18/30
# 36602/36602 [==============================] - 9s 257us/sample - loss: 7.3033e-04 - mean_squared_error: 7.3033e-04 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 19/30
# 36602/36602 [==============================] - 9s 253us/sample - loss: 9.1102e-04 - mean_squared_error: 9.1102e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 20/30
# 36602/36602 [==============================] - 9s 255us/sample - loss: 6.5239e-04 - mean_squared_error: 6.5239e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 21/30
# 36602/36602 [==============================] - 10s 263us/sample - loss: 5.2355e-04 - mean_squared_error: 5.2355e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 22/30
# 36602/36602 [==============================] - 10s 270us/sample - loss: 4.7015e-04 - mean_squared_error: 4.7015e-04 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 23/30
# 36602/36602 [==============================] - 10s 271us/sample - loss: 4.9769e-04 - mean_squared_error: 4.9769e-04 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 24/30
# 36602/36602 [==============================] - 10s 263us/sample - loss: 6.5822e-04 - mean_squared_error: 6.5822e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 25/30
# 36602/36602 [==============================] - 9s 257us/sample - loss: 4.8571e-04 - mean_squared_error: 4.8571e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 26/30
# 36602/36602 [==============================] - 9s 252us/sample - loss: 4.2600e-04 - mean_squared_error: 4.2600e-04 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 27/30
# 36602/36602 [==============================] - 9s 254us/sample - loss: 4.7318e-04 - mean_squared_error: 4.7318e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 28/30
# 36602/36602 [==============================] - 9s 259us/sample - loss: 5.4155e-04 - mean_squared_error: 5.4155e-04 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 29/30
# 36602/36602 [==============================] - 10s 272us/sample - loss: 8.3504e-04 - mean_squared_error: 8.3504e-04 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 30/30
# 36602/36602 [==============================] - 10s 270us/sample - loss: 5.3443e-04 - mean_squared_error: 5.3443e-04 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
#
# MSE Loss: 0.002907943128484045
#
# Optimization Run Time:  147.2018651763598

# %%
plot_convergence(search_result)

# %%
#best hyperparameters
print("Best Hyperparameters: ",search_result.x)

#corr. result
print(search_result.fun)
# Out:
# Best Hyperparameters:  [0.009228133959978865, 3, 128, 0.10489239387725063]
# 0.0029024899620170826

# %%
#All Results
sorted(zip(search_result.func_vals, search_result.x_iters))
# Out:
# [(0.0029024899620170826, [0.009228133959978865, 3, 128, 0.10489239387725063]),
#  (0.002907943128484045, [0.007930136976879887, 2, 250, 0.10235001231699849]),
#  (0.003004001307144846, [0.008849498060893659, 3, 252, 0.24840857134608807]),
#  (0.003018225722646946, [0.003941276332782655, 2, 131, 0.10052591516495878]),
#  (0.0031346330208502178, [0.006970623265646179, 2, 181, 0.24352680599481372]),
#  (0.0031608468927451193, [0.0001089320139598303, 2, 238, 0.22302366719587016]),
#  (0.003254933791571525, [0.0037906410778965533, 3, 232, 0.1871654366983168]),
#  (0.0032759857825781368, [0.007913261545086127, 3, 130, 0.24917526396040582]),
#  (0.003286936142653756, [0.008033728025236562, 3, 250, 0.10076922372655711]),
#  (0.003327360903110938, [0.0004548771687792184, 2, 233, 0.13406091846892354]),
#  (0.003377215320049266, [0.00047739434271488736, 2, 129, 0.1505569321417842]),
#  (0.00349513294521502, [0.001411090641855285, 2, 216, 0.23735056180067413]),
#  (0.0035275137178511643, [0.0005322281748309001, 2, 173, 0.10022991064937967]),
#  (0.00358982256071455, [0.001, 2, 256, 0.2]),
#  (0.00367468610325896, [1.0249403982998481e-05, 3, 254, 0.10148409924722862]),
#  (0.003689338878251968, [1.3956680399133395e-05, 2, 200, 0.2026638574223557]),
#  (0.0036942030166196996, [0.008700571915003867, 3, 128, 0.2473362854175141]),
#  (0.0037049695474603156, [0.009521534336313473, 3, 254, 0.10134631165283342]),
#  (0.0037524859175569443, [1.402835920946676e-05, 2, 129, 0.1068893938258275]),
#  (0.003783672554389864, [1.1164001830299264e-05, 3, 255, 0.10677809991815279]),
#  (0.0037957945224493805, [1.4597469676205752e-05, 3, 128, 0.2495952351061629]),
#  (0.0038759780603476075,
#   [1.2249080295044326e-05, 2, 199, 0.20336248028318915]),
#  (0.003896668423514312, [1.0603861153988164e-05, 3, 130, 0.10166884341855964]),
#  (0.003916999232371006, [1.1228725939766416e-05, 3, 255, 0.24815396521695446]),
#  (0.004083029607964981, [1.0406228273430555e-05, 3, 158, 0.21700056681060376])]

# %%
from skopt.plots import plot_objective_2D
fig = plot_objective_2D(result=search_result,
                        dimension_identifier1='learning_rate',
                        dimension_identifier2='num_nodes',
                        levels=50)

# %%
# create a list for plotting
dim_names = ['learning_rate', 'num_layers', 'num_nodes', 'dropout' ]

fig, ax = plot_objective(result=search_result, dimensions=dim_names)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-3bbb1a2a0eee> in <module>()
#       2 dim_names = ['learning_rate', 'num_layers', 'num_nodes', 'dropout' ]
#       3
# ----> 4 fig, ax = plot_objective(result=search_result, dimensions=dim_names)
#
# ValueError: too many values to unpack (expected 2)

# %%
best_model= load_model(path_best_model)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-85d05bbce0f2> in <module>()
# ----> 1 best_model= load_model(path_best_model)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/keras/saving/save.py in load_model(filepath, custom_objects, compile)
#     141   if (h5py is not None and (
#     142       isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 143     return hdf5_format.load_model_from_hdf5(filepath, custom_objects, compile)
#     144
#     145   if isinstance(filepath, six.string_types):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/keras/saving/hdf5_format.py in load_model_from_hdf5(filepath, custom_objects, compile)
#     158     if model_config is None:
#     159       raise ValueError('No model found in config file.')
# --> 160     model_config = json.loads(model_config.decode('utf-8'))
#     161     model = model_config_lib.model_from_config(model_config,
#     162                                                custom_objects=custom_objects)
#
# AttributeError: 'str' object has no attribute 'decode'

# %%
opt_par = [0.007930136976879887, 2, 250, 0.10235001231699849]
# use hyper-parameters from optimization
learning_rate = opt_par[0]
num_layers = opt_par[1]
num_nodes = opt_par[2]
dropout_value = opt_par[3]

model = Sequential()
model.add(InputLayer(input_shape=(None, 13)))
for i in range(num_layers-1):
    name = 'layer_LSTM_{0}'.format(i+1)
    model.add(LSTM(units=num_nodes, return_sequences=True, activation='tanh', name=name))
    model.add(Dropout(dropout_value))
model.add(LSTM(units=num_nodes, activation='tanh'))
model.add(Dropout(dropout_value))
model.add(Dense(units=1))
# Adam Optimizer
optimizer = Adam(lr=learning_rate)
model.summary()
model.compile(optimizer=optimizer, loss='MSE', metrics=[tf.keras.metrics.MeanSquaredError()])

monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=20, verbose=1, mode='auto', restore_best_weights=True)

histories = model.fit(x_train, y_train, validation_data=(x_val,y_val), callbacks=[monitor],verbose=2,epochs=100)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_LSTM_1 (LSTM)          (None, None, 250)         264000
# _________________________________________________________________
# dropout_11 (Dropout)         (None, None, 250)         0
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 250)               501000
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 250)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 251
# =================================================================
# Total params: 765,251
# Trainable params: 765,251
# Non-trainable params: 0
# _________________________________________________________________
# Train on 36602 samples, validate on 4562 samples
# Epoch 1/100
# 36602/36602 - 37s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 2/100
# 36602/36602 - 34s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 3/100
# 36602/36602 - 35s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 4/100
# 36602/36602 - 34s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 5/100
# 36602/36602 - 35s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 6/100
# 36602/36602 - 35s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 7/100
# 36602/36602 - 35s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 8/100
# 36602/36602 - 35s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 9/100
# 36602/36602 - 34s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 10/100
# 36602/36602 - 34s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 11/100
# 36602/36602 - 35s - loss: 9.8874e-04 - mean_squared_error: 9.8874e-04 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 12/100
# 36602/36602 - 34s - loss: 8.4037e-04 - mean_squared_error: 8.4037e-04 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 13/100
# 36602/36602 - 35s - loss: 9.0826e-04 - mean_squared_error: 9.0826e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 14/100
# 36602/36602 - 34s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 15/100
# 36602/36602 - 35s - loss: 7.7923e-04 - mean_squared_error: 7.7923e-04 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 16/100
# 36602/36602 - 35s - loss: 8.7389e-04 - mean_squared_error: 8.7389e-04 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 17/100
# 36602/36602 - 34s - loss: 7.4494e-04 - mean_squared_error: 7.4494e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 18/100
# 36602/36602 - 35s - loss: 7.7690e-04 - mean_squared_error: 7.7690e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 19/100
# 36602/36602 - 34s - loss: 7.7870e-04 - mean_squared_error: 7.7870e-04 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 20/100
# 36602/36602 - 35s - loss: 7.0233e-04 - mean_squared_error: 7.0233e-04 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 21/100
# Restoring model weights from the end of the best epoch.
# 36602/36602 - 34s - loss: 6.5694e-04 - mean_squared_error: 6.5694e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 00021: early stopping

# %%
plt.plot(histories.history['loss'], 'b')
plt.plot(histories.history['val_loss'],'r' )
plt.title('Training and Validation')
plt.ylabel('MSE Loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.savefig('/content/gdrive/MyDrive/SoilMoisture/LSTM_Images/MSE_c5_50.png', dpi=400)
plt.show()
