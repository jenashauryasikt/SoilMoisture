# %%
# !pip install tensorflow==1.15.0
# !pip install scikit-optimize

# %%
import numpy as np
import pandas as pd
import time

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Input
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM, Dropout, GRU
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping

import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.colors as colors
import matplotlib as mpl

# %%
import skopt
from skopt import gp_minimize, forest_minimize
from skopt.space import Real, Categorical, Integer
from skopt.plots import plot_convergence
from skopt.plots import plot_objective, plot_evaluations
from skopt.plots import plot_objective
from skopt.utils import use_named_args

# %%
randomState = 42
np.random.seed(randomState)
tf.set_random_seed(randomState)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
raw10 = pd.read_csv('/content/gdrive/MyDrive/SoilMoisture/Data/c_5_data_soil_10.csv')
df10 = raw10.copy()

df10 = df10.rename(columns={'In-Situ':'InSitu'})

def replace_missing(attribute):
    return attribute.interpolate(inplace=True)

replace_missing(df10['NDVI'])
replace_missing(df10['EVI'])
replace_missing(df10['LSTDay'])
replace_missing(df10['LSTNight'])

df10 = df10.dropna()
df10.isnull().sum()
# Out:
# Precip       0
# NDVI         0
# EVI          0
# GPP          0
# LSTDay       0
# LSTNight     0
# Elevation    0
# RZSM         0
# SURFSM       0
# Clay         0
# Sand         0
# Silt         0
# BD           0
# InSitu       0
# dtype: int64

# %%
df10['group'] = df10['Sand'].ne(df10['Sand'].shift()).cumsum()
df10 = df10.groupby('group')
dfs = []
for name, data in df10:
    dfs.append(data)

# %%
train_dataset = pd.DataFrame()
val_dataset = pd.DataFrame()
test_dataset = pd.DataFrame()

for df in dfs:
    df.pop('group')
    train_size = int(len(df)*0.8)
    val_size = int(len(df)*0.9)
    train, val, test = df.iloc[:train_size], df.iloc[train_size:val_size], df.iloc[val_size:]
    train_dataset = train_dataset.append(train)
    val_dataset = val_dataset.append(val)
    test_dataset = test_dataset.append(test)

# %%
# Split X
X_train = train_dataset.drop('InSitu', axis = 1)
X_val = val_dataset.drop('InSitu', axis = 1)
X_test = test_dataset.drop('InSitu', axis = 1)

# Split y
y_train = train_dataset.loc[:,['InSitu']]
y_val = val_dataset.loc[:,['InSitu']]
y_test = test_dataset.loc[:,['InSitu']]

# %%
# Fit the scaler using available training data
input_scaler = StandardScaler().fit(X_train)

# Apply the scaler to training data
x_train = input_scaler.transform(X_train)
x_val = input_scaler.transform(X_val)
x_test = input_scaler.transform(X_test)

x_train = np.array(x_train, np.float32)
y_train = np.array(y_train, np.float32)

x_val = np.array(x_val, np.float32)
y_val = np.array(y_val, np.float32)

x_test = np.array(x_test, np.float32)
y_test = np.array(y_test, np.float32)

y_train = y_train.reshape((y_train.size, 1))
y_val = y_val.reshape((y_val.size, 1))
y_test = y_test.reshape((y_test.size, 1))

# %%
def create_dataset (X, y, time_steps = 1):
    Xs, ys= [], []
    for i in range(len(X)-time_steps):
        v = X[i:i+time_steps, :]
        Xs.append(v)
        ys.append(y[i+time_steps])        
    return np.array(Xs), np.array(ys)

TIME_STEPS = 15

x_test, y_test = create_dataset(x_test, y_test, TIME_STEPS)
x_train, y_train = create_dataset(x_train, y_train, TIME_STEPS)
x_val, y_val = create_dataset(x_val, y_val, TIME_STEPS)

# %%
dim_learning_rate = Real(low=1e-5, high=1e-2, prior='log-uniform', name='learning_rate')
dim_num_layers = Integer(low=2, high=3, name='num_layers')
dim_num_nodes = Integer(low=128, high=256, name='num_nodes')
dim_dropout_val = Real(low=0.10, high=0.25, name='dropout_val')

dimensions = [dim_learning_rate,
              dim_num_layers,
              dim_num_nodes,
              dim_dropout_val]

default_parameters = [1e-3, 2, 256, 0.2]

# %%
# To log traning progress
def log_dir_name(learning_rate, num_layers, num_nodes, dropout_val):
    # dir-name for TensorBoard log-dir.
    s = "/content/gdrive/MyDrive/SoilMoisture/GRUlogs/lr_{0:.0e}_layers_{1}_nodes_{2}_dropout_{3}"
    log_dir = s.format(learning_rate, num_layers, num_nodes, dropout_val)

    return log_dir

# %%
#To create model with determined hyperparameters
def create_model(learning_rate, num_layers, num_nodes, dropout_val):
    model = Sequential()
    model.add(InputLayer(input_shape=(None, 13)))
    for i in range(num_layers-1):
        name = 'layer_GRU_{0}'.format(i+1)
        model.add(GRU(units=num_nodes, return_sequences=True, activation='tanh', name=name))
        model.add(Dropout(dropout_val))
    model.add(GRU(units=num_nodes, activation='tanh'))
    model.add(Dropout(dropout_val))
    model.add(Dense(units=1))
    # Adam Optimizer
    optimizer = Adam(lr=learning_rate)
    model.compile(optimizer=optimizer, loss='MSE', metrics=[tf.keras.metrics.MeanSquaredError()])
    
    return model

path_best_model = '/content/gdrive/MyDrive/SoilMoisture/GRU_Models/GRU_10_best_model.h5'
validation_data = (x_val, y_val)
best_loss = 5.0

# %%
@use_named_args(dimensions=dimensions)
def fitness(learning_rate, num_layers, num_nodes, dropout_val):
    """
    Hyper-parameters:
    learning_rate: Learning-rate for the optimizer.
    num_layers:    Number of GRU layers.
    num_nodes:     Number of nodes in each GRU layer.
    dropout_val:   Dropout.
    """
    # Print the hyper-parameters
    print('learning rate: {0:.1e}'.format(learning_rate))
    print('num_GRU_layers:', num_layers)
    print('num_GRU_nodes:', num_nodes)
    print('dropout:', dropout_val)
    print()    
    # Create the GRU
    model = create_model(learning_rate=learning_rate,
                         num_layers=num_layers,
                         num_nodes=num_nodes,
                         dropout_val=dropout_val)
    # Dir-name for TensorBoard log-files.
    log_dir = log_dir_name(learning_rate, num_layers, num_nodes, dropout_val)
    #callback
    callback_log = TensorBoard(log_dir=log_dir, histogram_freq=0, write_graph=True, write_grads=False, write_images=False)
    # Use Keras to train the model.
    history = model.fit(x= x_train,
                        y= y_train,
                        epochs=30,
                        batch_size=128,
                        validation_data=validation_data,
                        callbacks=[callback_log])

    loss = history.history['val_loss'][-1]

    print()
    print("MSE Loss:", loss)
    print()

    global best_loss

    if loss < best_loss:
        # Save the new model
        model.save(path_best_model)
        best_loss = loss

    del model
    
    K.clear_session()
    
    return loss

# %%
start = time.time()
search_result = gp_minimize(func=fitness,
                            dimensions=dimensions,
                            acq_func='EI',          # Expected Improvement.
                            n_calls=25,
                            x0=default_parameters)
print("Optimization Run Time: ", (time.time()-start)/60)
# Out:
# learning rate: 1.0e-03
# num_GRU_layers: 2
# num_GRU_nodes: 256
# dropout: 0.2
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on
- val_loss: 0.0044 - val_mean_squared_error: 0.0044
#
# MSE Loss: 0.004393523692912609
#
# learning rate: 3.0e-04
# num_GRU_layers: 3
# num_GRU_nodes: 216
# dropout: 0.1702891410195242
#
# Train on 43082 samples, validate on 5368 samples
# Epoch 1/30
# 43082/43082 [==============================] - 14s 326us/sample - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 2/30
# 43082/43082 [==============================] - 13s 299us/sample - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 3/30
# 43082/43082 [==============================] - 13s 304us/sample - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 4/30
# 43082/43082 [==============================] - 13s 299us/sample - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 5/30
# 43082/43082 [==============================] - 13s 301us/sample - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 6/30
# 43082/43082 [==============================] - 13s 299us/sample - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 7/30
# 43082/43082 [==============================] - 13s 300us/sample - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 8/30
# 43082/43082 [==============================] - 13s 301us/sample - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 9/30
# 43082/43082 [==============================] - 13s 297us/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 10/30
# 43082/43082 [==============================] - 13s 298us/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 11/30
# 43082/43082 [==============================] - 13s 300us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 12/30
# 43082/43082 [==============================] - 13s 299us/sample - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 13/30
# 43082/43082 [==============================] - 13s 303us/sample - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 14/30
# 43082/43082 [==============================] - 13s 298us/sample - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 15/30
# 43082/43082 [==============================] - 13s 298us/sample - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 16/30
# 43082/43082 [==============================] - 13s 301us/sample - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 17/30
# 43082/43082 [==============================] - 13s 299us/sample - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 18/30
# 43082/43082 [==============================] - 13s 300us/sample - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 19/30
# 43082/43082 [==============================] - 13s 298us/sample - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 20/30
# 43082/43082 [==============================] - 13s 298us/sample - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 21/30
# 43082/43082 [==============================] - 13s 299us/sample - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 22/30
# 43082/43082 [==============================] - 13s 299us/sample - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 23/30
# 43082/43082 [==============================] - 13s 300us/sample - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 24/30
# 43082/43082 [==============================] - 13s 300us/sample - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 25/30
# 43082/43082 [==============================] - 13s 298us/sample - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 26/30
# 43082/43082 [==============================] - 13s 306us/sample - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 27/30
# 43082/43082 [==============================] - 13s 303us/sample - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 28/30
# 43082/43082 [==============================] - 13s 299us/sample - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 29/30
# 43082/43082 [==============================] - 13s 299us/sample - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 30/30
# 43082/43082 [==============================] - 13s 303us/sample - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
#
# MSE Loss: 0.0038079998758517417
#
# learning rate: 1.1e-04
# num_GRU_layers: 3
# num_GRU_nodes: 161
# dropout: 0.1796937072257201
#
# Train on 43082 samples, validate on 5368 samples
# Epoch 1/30
# 43082/43082 [==============================] - 14s 326us/sample - loss: 0.0095 - mean_squared_error: 0.0095 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 2/30
# 43082/43082 [==============================] - 13s 296us/sample - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 3/30
# 43082/43082 [==============================] - 13s 302us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 4/30
# 43082/43082 [==============================] - 13s 295us/sample - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 5/30
# 43082/43082 [==============================] - 13s 301us/sample - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 6/30
# 43082/43082 [==============================] - 13s 299us/sample - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 7/30
# 43082/43082 [==============================] - 13s 295us/sample - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch
loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 13/30
# 43082/43082 [==============================] - 9s 206us/sample - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 14/30
# 43082/43082 [==============================] - 9s 204us/sample - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 15/30
# 43082/43082 [==============================] - 9s 203us/sample - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 16/30
# 43082/43082 [==============================] - 9s 205us/sample - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 17/30
# 43082/43082 [==============================] - 9s 205us/sample - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 18/30
# 43082/43082 [==============================] - 9s 208us/sample - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 19/30
# 43082/43082 [==============================] - 9s 208us/sample - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 20/30
# 43082/43082 [==============================] - 9s 209us/sample - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 21/30
# 43082/43082 [==============================] - 9s 206us/sample - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 22/30
# 43082/43082 [==============================] - 9s 206us/sample - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 23/30
# 43082/43082 [==============================] - 9s 205us/sample - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 24/30
# 43082/43082 [==============================] - 9s 210us/sample - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 25/30
# ...
#
# learning rate: 1.2e-05
# num_GRU_layers: 2
# num_GRU_nodes: 134
# dropout: 0.2484123844831873
#
# Train on 43082 samples, validate on 5368 samples
# Epoch 1/30
# 43082/43082 [==============================] - 10s 231us/sample - loss: 0.0489 - mean_squared_error: 0.0489 - val_loss: 0.0138 - val_mean_squared_error: 0.0138
# Epoch 2/30
# 43082/43082 [==============================] - 9s 212us/sample - loss: 0.0246 - mean_squared_error: 0.0246 - val_loss: 0.0072 - val_mean_squared_error: 0.0072
# Epoch 3/30
# 43082/43082 [==============================] - 9s 213us/sample - loss: 0.0198 - mean_squared_error: 0.0198 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 4/30
# 43082/43082 [==============================] - 9s 214us/sample - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 5/30
# 43082/43082 [==============================] - 9s 211us/sample - loss: 0.0154 - mean_squared_error: 0.0154 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 6/30
# 43082/43082 [==============================] - 9s 210us/sample - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 7/30
# 43082/43082 [==============================] - 9s 211us/sample - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 8/30
# 43082/43082 [==============================] - 9s 215us/sample - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 9/30
# 43082/43082 [==============================] - 9s 213us/sample - loss: 0.0105 - mean_squared_error: 0.0105 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 10/30
# 43082/43082 [==============================] - 9s 212us/sample - loss: 0.0100 - mean_squared_error: 0.0100 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 11/30
# 43082/43082 [==============================] - 9s 212us/sample - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 12/30
# 43082/43082 [==============================] - 9s 212us/sample - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 13/30
# 43082/43082 [==============================] - 9s 211us/sample - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 14/30
# 43082/43082 [==============================] - 9s 210us/sample - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 15/30
# 43082/43082 [==============================] - 9s 212us/sample - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 16/30
# 43082/43082 [==============================] - 9s 213us/sample - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 17/30
# 43082/43082 [==============================] - 9s 210us/sample - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 18/30
# 43082/43082 [==============================] - 9s 216us/sample - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 19/30
# 43082/43082 [==============================] - 9s 210us/sample - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 20/30
# 43082/43082 [==============================] - 9s 214us/sample - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 21/30
# 43082/43082 [==============================] - 9s 214us/sample - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 22/30
# 43082/43082 [==============================] - 9s 216us/sample - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 23/30
# 43082/43082 [==============================] - 9s 214us/sample - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 24/30
# 43082/43082 [==============================] - 9s 211us/sample - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 25/30
# 43082/43082 [==============================] - 9s 211us/sample - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 26/30
# 43082/43082 [==============================] - 9s 214us/sample - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 27/30
# 43082/43082 [==============================] - 9s 210us/sample - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 28/30
# 43082/43082 [==============================] - 9s 211us/sample - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 29/30
# 43082/43082 [==============================] - 9s 213us/sample - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 30/30
# 43082/43082 [==============================] - 9s 212us/sample - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
#
# MSE Loss: 0.004963196455272006
#
# learning rate: 1.0e-05
# num_GRU_layers: 3
# num_GRU_nodes: 254
# dropout: 0.10039943248803135
#
# Train on 43082 samples, validate on 5368 samples
# Epoch 1/30
# 43082/43082 [==============================] - 14s 329us/sample - loss: 0.0166 - mean_squared_error: 0.0166 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 2/30
# 43082/43082 [==============================] - 13s 309us/sample - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 3/30
# 43082/43082 [==============================] - 13s 301us/sample - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 4/30
# 43082/43082 [==============================] - 13s 309us/sample - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 5/30
# 43082/43082 [==============================] - 13s 303us/sample - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 6/30
# 43082/43082 [==============================] - 13s 304us/sample - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 7/30
# 43082/43082 [==============================] - 13s 307us/sample - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 8/30
# 43082/43082 [==============================] - 13s 304us/sample - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 9/30
# 43082/43082 [==============================] - 13s 306us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 10/30
# 43082/43082 [==============================] - 13s 302us/sample - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 11/30
# 43082/43082 [==============================] - 13s 305us/sample - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 12/30
# 43082/43082 [==============================] - 13s 304us/sample - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 13/30
# 43082/43082 [==============================] - 13s 306us/sample - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 14/30
# 43082/43082 [==============================] - 13s 308us/sample - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 15/30
# 43082/43082 [==============================] - 13s 302us/sample - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 16/30
# 43082/43082 [==============================] - 13s 303us/sample - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch
loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 28/30
# 43082/43082 [==============================] - 9s 212us/sample - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 29/30
# 43082/43082 [==============================] - 9s 209us/sample - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 30/30
# 43082/43082 [==============================] - 9s 208us/sample - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
#
# MSE Loss: 0.00419450693745749
#
# Optimization Run Time:  137.69769858121873

# %%
plot_convergence(search_result)

# %%
#best hyperparameters
print("Best Hyperparameters: ",search_result.x)

#corr. result
print(search_result.fun)
# Out:
# Best Hyperparameters:  [0.0003034817580684375, 3, 216, 0.1702891410195242]
# 0.0038079998758517417

# %%
#All Results
sorted(zip(search_result.func_vals, search_result.x_iters))
# Out:
# [(0.0038079998758517417, [0.0003034817580684375, 3, 216, 0.1702891410195242]),
#  (0.0039043997111834375, [0.008509587411809783, 2, 130, 0.10639620180851107]),
#  (0.003951886004661439, [0.001, 2, 256, 0.2]),
#  (0.004090479139277459, [0.006739785644704531, 3, 129, 0.2488497275574841]),
#  (0.004101056194046704, [0.006128579897980079, 3, 159, 0.1940168343281198]),
#  (0.0041707255270320995, [0.001526098423429937, 2, 183, 0.2448672338184362]),
#  (0.004188571392104651, [0.002051879305820228, 2, 174, 0.23663504848962558]),
#  (0.00419450693745749, [0.007116623780915842, 2, 253, 0.24946898532768946]),
#  (0.004212852157985489, [0.009949205897276435, 3, 251, 0.24479185255005845]),
#  (0.004289248443296077, [0.002953493640253192, 2, 193, 0.22794152975808044]),
#  (0.004293364004944014, [0.0009799579487643013, 3, 168, 0.11486206615446815]),
#  (0.004393523692912609, [0.0008149611716055347, 3, 209, 0.14046559148152127]),
#  (0.004419692747930589, [0.00010807369623756937, 3, 161, 0.1796937072257201]),
#  (0.004422069912715281, [1.0239492325329972e-05, 3, 254, 0.10039943248803135]),
#  (0.004459598410497079, [4.7889870101177694e-05, 2, 213, 0.16365584941648176]),
#  (0.004504962892989154, [1.067391345366019e-05, 2, 252, 0.10308170660911899]),
#  (0.004547060037034546, [0.008638904912081516, 2, 251, 0.10062910416637472]),
#  (0.004623820268217302, [1.222592706972119e-05, 3, 130, 0.10162551243115914]),
#  (0.004662514242986231, [1.1647135969714338e-05, 2, 132, 0.10743419233494578]),
#  (0.004757162214752326, [1.0296217564552565e-05, 3, 253, 0.24911451362122047]),
#  (0.004784081225601288, [1.042786609914373e-05, 2, 220, 0.23790936721965508]),
#  (0.004841338885440068, [0.009283901808074337, 2, 129, 0.1024729866184717]),
#  (0.004963196455272006, [1.2167095240021662e-05, 2, 134, 0.2484123844831873]),
#  (0.005098358181828491, [0.008742383661568131, 3, 253, 0.10282531231176154]),
#  (0.005120498802090943, [1.0821974234990954e-05, 3, 142, 0.24940100601724502])]

# %%
from skopt.plots import plot_objective_2D
fig = plot_objective_2D(result=search_result,
                        dimension_identifier1='learning_rate',
                        dimension_identifier2='num_nodes',
                        levels=50)

# %%
# create a list for plotting
dim_names = ['learning_rate', 'num_layers', 'num_nodes', 'dropout' ]

try:
  fig, ax = plot_objective(result=search_result, dimensions=dim_names)
except:
  print("ok")
# Out:
# ok

# %%
try:
  best_model= load_model(path_best_model)
except:
  print("ok")
# Out:
# ok

# %%
opt_par = search_result.x
# use hyper-parameters from optimization
learning_rate = opt_par[0]
num_layers = opt_par[1]
num_nodes = opt_par[2]
dropout_value = opt_par[3]

model = Sequential()
model.add(InputLayer(input_shape=(None, 13)))
for i in range(num_layers-1):
    name = 'layer_GRU_{0}'.format(i+1)
    model.add(GRU(units=num_nodes, return_sequences=True, activation='tanh', name=name))
    model.add(Dropout(dropout_value))
model.add(GRU(units=num_nodes, activation='tanh'))
model.add(Dropout(dropout_value))
model.add(Dense(units=1))
# Adam Optimizer
optimizer = Adam(lr=learning_rate)
model.summary()
model.compile(optimizer=optimizer, loss='MSE', metrics=[tf.keras.metrics.MeanSquaredError()])

monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=20, verbose=1, mode='auto', restore_best_weights=True)

histories = model.fit(x_train, y_train, validation_data=(x_val,y_val), callbacks=[monitor],verbose=2,epochs=100)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_GRU_1 (GRU)            (None, None, 216)         149040
# _________________________________________________________________
# dropout (Dropout)            (None, None, 216)         0
# _________________________________________________________________
# layer_GRU_2 (GRU)            (None, None, 216)         280584
# _________________________________________________________________
# dropout_1 (Dropout)          (None, None, 216)         0
# _________________________________________________________________
# gru (GRU)                    (None, 216)               280584
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 216)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 217
# =================================================================
# Total params: 710,425
# Trainable params: 710,425
# Non-trainable params: 0
# _________________________________________________________________
# Train on 43082 samples, validate on 5368 samples
# Epoch 1/100
# 43082/43082 - 50s - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 2/100
# 43082/43082 - 48s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 3/100
# 43082/43082 - 48s - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 4/100
# 43082/43082 - 49s - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 5/100
# 43082/43082 - 49s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 6/100
# 43082/43082 - 49s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 7/100
# 43082/43082 - 49s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 8/100
# 43082/43082 - 48s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 9/100
# 43082/43082 - 48s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 10/100
# 43082/43082 - 49s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 11/100
# 43082/43082 - 50s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 12/100
# 43082/43082 - 49s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 13/100
# 43082/43082 - 49s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 14/100
# 43082/43082 - 48s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 15/100
# 43082/43082 - 49s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 16/100
# 43082/43082 - 48s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 17/100
# 43082/43082 - 49s - loss: 9.8468e-04 - mean_squared_error: 9.8468e-04 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 18/100
# 43082/43082 - 48s - loss: 9.2759e-04 - mean_squared_error: 9.2759e-04 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 19/100
# 43082/43082 - 48s - loss: 8.7599e-04 - mean_squared_error: 8.7599e-04 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 20/100
# 43082/43082 - 48s - loss: 8.2346e-04 - mean_squared_error: 8.2346e-04 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 21/100
# Restoring model weights from the end of the best epoch.
# 43082/43082 - 49s - loss: 7.8065e-04 - mean_squared_error: 7.8065e-04 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 00021: early stopping

# %%
plt.plot(histories.history['loss'], 'b')
plt.plot(histories.history['val_loss'],'r' )
plt.title('Training and Validation')
plt.ylabel('MSE Loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.savefig('/content/gdrive/MyDrive/SoilMoisture/GRU_Images/MSE_c5_10.png', dpi=400)
plt.show()
