# %%
# !pip install tensorflow==1.15.0
# !pip install scikit-optimize

# %%
import numpy as np
import pandas as pd
import time

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Input
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM, Dropout, GRU
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping

import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.colors as colors
import matplotlib as mpl

# %%
import skopt
from skopt import gp_minimize, forest_minimize
from skopt.space import Real, Categorical, Integer
from skopt.plots import plot_convergence
from skopt.plots import plot_objective, plot_evaluations
from skopt.plots import plot_objective
from skopt.utils import use_named_args

# %%
randomState = 42
np.random.seed(randomState)
tf.set_random_seed(randomState)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
raw10 = pd.read_csv('/content/gdrive/MyDrive/SoilMoisture/Data/c_5_data_soil_5.csv')
df10 = raw10.copy()

df10 = df10.rename(columns={'In-Situ':'InSitu'})

def replace_missing(attribute):
    return attribute.interpolate(inplace=True)

replace_missing(df10['NDVI'])
replace_missing(df10['EVI'])
replace_missing(df10['LSTDay'])
replace_missing(df10['LSTNight'])

df10 = df10.dropna()
df10.isnull().sum()
# Out:
# Precip       0
# NDVI         0
# EVI          0
# GPP          0
# LSTDay       0
# LSTNight     0
# Elevation    0
# RZSM         0
# SURFSM       0
# Clay         0
# Sand         0
# Silt         0
# BD           0
# InSitu       0
# dtype: int64

# %%
df10['group'] = df10['Sand'].ne(df10['Sand'].shift()).cumsum()
df10 = df10.groupby('group')
dfs = []
for name, data in df10:
    dfs.append(data)

# %%
train_dataset = pd.DataFrame()
val_dataset = pd.DataFrame()
test_dataset = pd.DataFrame()

for df in dfs:
    df.pop('group')
    train_size = int(len(df)*0.8)
    val_size = int(len(df)*0.9)
    train, val, test = df.iloc[:train_size], df.iloc[train_size:val_size], df.iloc[val_size:]
    train_dataset = train_dataset.append(train)
    val_dataset = val_dataset.append(val)
    test_dataset = test_dataset.append(test)

# %%
# Split X
X_train = train_dataset.drop('InSitu', axis = 1)
X_val = val_dataset.drop('InSitu', axis = 1)
X_test = test_dataset.drop('InSitu', axis = 1)

# Split y
y_train = train_dataset.loc[:,['InSitu']]
y_val = val_dataset.loc[:,['InSitu']]
y_test = test_dataset.loc[:,['InSitu']]

# %%
# Fit the scaler using available training data
input_scaler = StandardScaler().fit(X_train)

# Apply the scaler to training data
x_train = input_scaler.transform(X_train)
x_val = input_scaler.transform(X_val)
x_test = input_scaler.transform(X_test)

x_train = np.array(x_train, np.float32)
y_train = np.array(y_train, np.float32)

x_val = np.array(x_val, np.float32)
y_val = np.array(y_val, np.float32)

x_test = np.array(x_test, np.float32)
y_test = np.array(y_test, np.float32)

y_train = y_train.reshape((y_train.size, 1))
y_val = y_val.reshape((y_val.size, 1))
y_test = y_test.reshape((y_test.size, 1))

# %%
def create_dataset (X, y, time_steps = 1):
    Xs, ys= [], []
    for i in range(len(X)-time_steps):
        v = X[i:i+time_steps, :]
        Xs.append(v)
        ys.append(y[i+time_steps])        
    return np.array(Xs), np.array(ys)

TIME_STEPS = 15

x_test, y_test = create_dataset(x_test, y_test, TIME_STEPS)
x_train, y_train = create_dataset(x_train, y_train, TIME_STEPS)
x_val, y_val = create_dataset(x_val, y_val, TIME_STEPS)

# %%
dim_learning_rate = Real(low=1e-5, high=1e-2, prior='log-uniform', name='learning_rate')
dim_num_layers = Integer(low=2, high=3, name='num_layers')
dim_num_nodes = Integer(low=128, high=256, name='num_nodes')
dim_dropout_val = Real(low=0.10, high=0.25, name='dropout_val')

dimensions = [dim_learning_rate,
              dim_num_layers,
              dim_num_nodes,
              dim_dropout_val]

default_parameters = [1e-3, 2, 256, 0.2]

# %%
# To log traning progress
def log_dir_name(learning_rate, num_layers, num_nodes, dropout_val):
    # dir-name for TensorBoard log-dir.
    s = "/content/gdrive/MyDrive/SoilMoisture/GRUlogs/lr_{0:.0e}_layers_{1}_nodes_{2}_dropout_{3}"
    log_dir = s.format(learning_rate, num_layers, num_nodes, dropout_val)

    return log_dir

# %%
#To create model with determined hyperparameters
def create_model(learning_rate, num_layers, num_nodes, dropout_val):
    model = Sequential()
    model.add(InputLayer(input_shape=(None, 13)))
    for i in range(num_layers-1):
        name = 'layer_GRU_{0}'.format(i+1)
        model.add(GRU(units=num_nodes, return_sequences=True, activation='tanh', name=name))
        model.add(Dropout(dropout_val))
    model.add(GRU(units=num_nodes, activation='tanh'))
    model.add(Dropout(dropout_val))
    model.add(Dense(units=1))
    # Adam Optimizer
    optimizer = Adam(lr=learning_rate)
    model.compile(optimizer=optimizer, loss='MSE', metrics=[tf.keras.metrics.MeanSquaredError()])
    
    return model

path_best_model = '/content/gdrive/MyDrive/SoilMoisture/GRU_Models/GRU_5_best_model.h5'
validation_data = (x_val, y_val)
best_loss = 5.0

# %%
@use_named_args(dimensions=dimensions)
def fitness(learning_rate, num_layers, num_nodes, dropout_val):
    """
    Hyper-parameters:
    learning_rate: Learning-rate for the optimizer.
    num_layers:    Number of GRU layers.
    num_nodes:     Number of nodes in each GRU layer.
    dropout_val:   Dropout.
    """
    # Print the hyper-parameters
    print('learning rate: {0:.1e}'.format(learning_rate))
    print('num_GRU_layers:', num_layers)
    print('num_GRU_nodes:', num_nodes)
    print('dropout:', dropout_val)
    print()    
    # Create the GRU
    model = create_model(learning_rate=learning_rate,
                         num_layers=num_layers,
                         num_nodes=num_nodes,
                         dropout_val=dropout_val)
    # Dir-name for TensorBoard log-files.
    log_dir = log_dir_name(learning_rate, num_layers, num_nodes, dropout_val)
    #callback
    callback_log = TensorBoard(log_dir=log_dir, histogram_freq=0, write_graph=True, write_grads=False, write_images=False)
    # Use Keras to train the model.
    history = model.fit(x= x_train,
                        y= y_train,
                        epochs=30,
                        batch_size=128,
                        validation_data=validation_data,
                        callbacks=[callback_log])

    loss = history.history['val_loss'][-1]

    print()
    print("MSE Loss:", loss)
    print()

    global best_loss

    if loss < best_loss:
        # Save the new model
        model.save(path_best_model)
        best_loss = loss

    del model
    
    K.clear_session()
    
    return loss

# %%
start = time.time()
search_result = gp_minimize(func=fitness,
                            dimensions=dimensions,
                            acq_func='EI',          # Expected Improvement.
                            n_calls=25,
                            x0=default_parameters)
print("Optimization Run Time: ", (time.time()-start)/60)
# Out:
# learning rate: 1.0e-03
# num_GRU_layers: 2
# num_GRU_nodes: 256
# dropout: 0.2
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on
#
# MSE Loss: 0.010651322680695971
#
# learning rate: 3.4e-05
# num_GRU_layers: 2
# num_GRU_nodes: 250
# dropout: 0.1434212127970233
#
# Train on 43960 samples, validate on 5479 samples
# Epoch 1/30
# 43960/43960 [==============================] - 11s 242us/sample - loss: 0.0167 - mean_squared_error: 0.0167 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 2/30
# 43960/43960 [==============================] - 10s 224us/sample - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 3/30
# 43960/43960 [==============================] - 10s 224us/sample - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 4/30
# 43960/43960 [==============================] - 10s 223us/sample - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 5/30
# 43960/43960 [==============================] - 10s 224us/sample - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 6/30
# 43960/43960 [==============================] - 10s 224us/sample - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 7/30
# 43960/43960 [==============================] - 10s 226us/sample - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 8/30
# 43960/43960 [==============================] - 10s 224us/sample - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 9/30
# 43960/43960 [==============================] - 10s 224us/sample - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 10/30
# 43960/43960 [==============================] - 10s 222us/sample - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 11/30
# 43960/43960 [==============================] - 10s 220us/sample - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 12/30
# 43960/43960 [==============================] - 10s 224us/sample - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 13/30
# 43960/43960 [==============================] - 10s 222us/sample - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 14/30
# 43960/43960 [==============================] - 10s 220us/sample - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 15/30
# 43960/43960 [==============================] - 10s 224us/sample - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 16/30
# 43960/43960 [==============================] - 10s 225us/sample - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 17/30
# 43960/43960 [==============================] - 10s 222us/sample - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 18/30
# 43960/43960 [==============================] - 10s 224us/sample - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 19/30
# 43960/43960 [==============================] - 10s 224us/sample - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 20/30
# 43960/43960 [==============================] - 10s 220us/sample - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 21/30
# 43960/43960 [==============================] - 10s 222us/sample - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 22/30
# 43960/43960 [==============================] - 10s 222us/sample - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 23/30
# 43960/43960 [==============================] - 10s 222us/sample - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 24/30
# 43960/43960 [==============================] - 10s 221us/sample - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 25/30
# 43960/43960 [==============================] - 10s 221us/sample - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 26/30
# 43960/43960 [==============================] - 10s 225us/sample - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 27/30
# 43960/43960 [==============================] - 10s 223us/sample - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 28/30
# 43960/43960 [==============================] - 10s 219us/sample - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 29/30
# 43960/43960 [==============================] - 10s 224us/sample - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 30/30
# 43960/43960 [==============================] - 10s 222us/sample - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
#
# MSE Loss: 0.004467943024932576
#
# learning rate: 1.8e-05
# num_GRU_layers: 3
# num_GRU_nodes: 186
# dropout: 0.13336971202655118
#
# Train on 43960 samples, validate on 5479 samples
# Epoch 1/30
# 43960/43960 [==============================] - 16s 353us/sample - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 2/30
# 43960/43960 [==============================] - 14s 330us/sample - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 3/30
# 43960/43960 [==============================] - 14s 324us/sample - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 4/30
# 43960/43960 [==============================] - 14s 328us/sample - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 5/30
# 43960/43960 [==============================] - 14s 324us/sample - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 6/30
# 43960/43960 [==============================] - 14s 328us/sample - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 7/30
# 43960/43960 [==============================] - 14s 324us/sample - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 8/30
# 43960/43960 [==============================] - 14s 328us/sample - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 9/30
# 43960/43960 [==============================] - 14s 330us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 10/30
# 43960/43960 [==============================] - 14s 327us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 11/30
# 43960/43960 [==============================] - 14s 328us/sample - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 12/30
# 43960/43960 [==============================] - 14s 328us/sample - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 13/30
# 43960/43960 [==============================] - 15s 332us/sample - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 14/30
# 43960/43960 [==============================] - 14s 328us/sample - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 15/30
# 43960/43960 [==============================] - 14s 329us/sample - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 16/30
# 43960/43960 [==============================] - 15s 331us/sample - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 17/30
# 43960/43960 [==============================] - 14s 327us/sample - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 18/30
# 43960/43960 [==============================] - 15s 333us/sample - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 19/30
# 43960/43960 [==============================] - 15s 335us/sample - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 20/30
# 43960/43960 [==============================] - 15s 335us/sample - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 21/30
# 43960/43960 [==============================] - 14s 329us/sample - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 22/30
# 43960/43960 [==============================] - 15s 333us/sample - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 23/30
# 43960/43960 [==============================] - 15s 330us/sample - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 24/30
# 43960/43960 [==============================] - 14s 330us/sample - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 25/30
# 43960/43960 [==============================] - 14s 328us/sample - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 26/30
# ...
# num_GRU_layers: 2
# num_GRU_nodes: 251
# dropout: 0.10028648738048043
#
# Train on 43960 samples, validate on 5479 samples
# Epoch 1/30
# 43960/43960 [==============================] - 11s 260us/sample - loss: 0.0220 - mean_squared_error: 0.0220 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
# Epoch 2/30
# 43960/43960 [==============================] - 10s 228us/sample - loss: 0.0096 - mean_squared_error: 0.0096 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 3/30
# 43960/43960 [==============================] - 10s 225us/sample - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 4/30
# 43960/43960 [==============================] - 10s 224us/sample - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 5/30
# 43960/43960 [==============================] - 10s 228us/sample - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 6/30
# 43960/43960 [==============================] - 10s 224us/sample - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 7/30
# 43960/43960 [==============================] - 10s 222us/sample - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 8/30
# 43960/43960 [==============================] - 10s 224us/sample - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 9/30
# 43960/43960 [==============================] - 10s 224us/sample - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 10/30
# 43960/43960 [==============================] - 10s 222us/sample - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 11/30
# 43960/43960 [==============================] - 10s 223us/sample - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 12/30
# 43960/43960 [==============================] - 10s 224us/sample - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 13/30
# 43960/43960 [==============================] - 10s 225us/sample - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch
loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0084 - val_mean_squared_error: 0.0084
# Epoch 29/30
# 43960/43960 [==============================] - 10s 226us/sample - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 30/30
# 43960/43960 [==============================] - 10s 225us/sample - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
#
# MSE Loss: 0.006510322521637692
#
# learning rate: 1.1e-05
# num_GRU_layers: 2
# num_GRU_nodes: 250
# dropout: 0.24922047776810308
#
# Train on 43960 samples, validate on 5479 samples
# Epoch 1/30
# 43960/43960 [==============================] - 11s 248us/sample - loss: 0.0310 - mean_squared_error: 0.0310 - val_loss: 0.0081 - val_mean_squared_error: 0.0081
# Epoch 2/30
# 43960/43960 [==============================] - 10s 233us/sample - loss: 0.0177 - mean_squared_error: 0.0177 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 3/30
# 43960/43960 [==============================] - 10s 230us/sample - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 4/30
# 43960/43960 [==============================] - 10s 228us/sample - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 5/30
# 43960/43960 [==============================] - 10s 231us/sample - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 6/30
# 43960/43960 [==============================] - 10s 230us/sample - loss: 0.0105 - mean_squared_error: 0.0105 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 7/30
# 43960/43960 [==============================] - 10s 229us/sample - loss: 0.0097 - mean_squared_error: 0.0097 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 8/30
# 43960/43960 [==============================] - 10s 229us/sample - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 9/30
# 43960/43960 [==============================] - 10s 231us/sample - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 10/30
# 43960/43960 [==============================] - 10s 231us/sample - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 11/30
# 43960/43960 [==============================] - 10s 230us/sample - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 12/30
# 43960/43960 [==============================] - 10s 233us/sample - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 13/30
# 43960/43960 [==============================] - 10s 230us/sample - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 14/30
# 43960/43960 [==============================] - 10s 232us/sample - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 15/30
# 43960/43960 [==============================] - 10s 231us/sample - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 16/30
# 43960/43960 [==============================] - 10s 230us/sample - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 17/30
# 43960/43960 [==============================] - 10s 230us/sample - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 18/30
# 43960/43960 [==============================] - 10s 232us/sample - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 19/30
# 43960/43960 [==============================] - 10s 231us/sample - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 20/30
# 43960/43960 [==============================] - 10s 229us/sample - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 21/30
# 43960/43960 [==============================] - 10s 229us/sample - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 22/30
# 43960/43960 [==============================] - 10s 230us/sample - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 23/30
# 43960/43960 [==============================] - 10s 228us/sample - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 24/30
# 43960/43960 [==============================] - 10s 228us/sample - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 25/30
# 43960/43960 [==============================] - 10s 232us/sample - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 26/30
# 43960/43960 [==============================] - 10s 231us/sample - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 27/30
# 43960/43960 [==============================] - 10s 229us/sample - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 28/30
# 43960/43960 [==============================] - 10s 231us/sample - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 29/30
# 43960/43960 [==============================] - 10s 229us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 30/30
# 43960/43960 [==============================] - 10s 233us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
#
# MSE Loss: 0.004489304705554061
#
# Optimization Run Time:  148.98675839900972

# %%
plot_convergence(search_result)

# %%
#best hyperparameters
print("Best Hyperparameters: ",search_result.x)

#corr. result
print(search_result.fun)
# Out:
# Best Hyperparameters:  [0.0002441335354532112, 2, 168, 0.17500779759373675]
# 0.003345361661441661

# %%
#All Results
sorted(zip(search_result.func_vals, search_result.x_iters))
# Out:
# [(0.003345361661441661, [0.0002441335354532112, 2, 168, 0.17500779759373675]),
#  (0.0034564351492163137, [0.0006860403837588142, 2, 161, 0.19403279095757603]),
#  (0.0037585842749248387, [0.001, 2, 256, 0.2]),
#  (0.0038281863344196507, [0.004031913209255682, 2, 183, 0.212606016719457]),
#  (0.0038364546601770185, [0.00016457315411446354, 2, 165, 0.1459455524114208]),
#  (0.003948908564462091, [0.0012896825362872357, 3, 244, 0.22214875302378606]),
#  (0.004284654872857074, [1.5976406824186305e-05, 2, 172, 0.13731053188698905]),
#  (0.004347589584563807, [1.4671695221753673e-05, 2, 254, 0.2494310007281786]),
#  (0.004350698775190096, [1.475120977693648e-05, 3, 255, 0.10256512371342574]),
#  (0.004365365637194683, [1.8021561736662112e-05, 3, 186, 0.13336971202655118]),
#  (0.004467943024932576, [3.391358641812358e-05, 2, 250, 0.1434212127970233]),
#  (0.004471012545152234, [1.0996317768754394e-05, 2, 251, 0.10028648738048043]),
#  (0.0044865838271895666, [1.4851825632578876e-05, 2, 129, 0.1502168300615005]),
#  (0.004489304705554061, [1.0573961824727362e-05, 2, 250, 0.24922047776810308]),
#  (0.0045002850432011455, [0.006698262482297647, 3, 246, 0.10006771382087809]),
#  (0.004632186036567838, [1.0388094658450877e-05, 3, 131, 0.10066584231317896]),
#  (0.004704623840420182, [1.155573377913286e-05, 3, 253, 0.24460508725180372]),
#  (0.004859153626493118, [1.4804363048218271e-05, 3, 129, 0.24828070831987478]),
#  (0.0050541597751138706, [0.009977908955513067, 2, 252, 0.10219581603763638]),
#  (0.005090050950549852, [1.109802260807537e-05, 3, 131, 0.24806381858827325]),
#  (0.00607863053690345, [0.008089322318329057, 3, 129, 0.24914686940480757]),
#  (0.0064141606695461845, [0.006535348287222442, 3, 253, 0.10219975829618763]),
#  (0.006441905684558378, [0.008874562000456079, 3, 132, 0.10565796378018996]),
#  (0.006510322521637692, [0.009657206327646708, 2, 128, 0.1095879607326992]),
#  (0.010651322680695971, [0.009668770923348525, 2, 198, 0.23049743031479708])]

# %%
from skopt.plots import plot_objective_2D
fig = plot_objective_2D(result=search_result,
                        dimension_identifier1='learning_rate',
                        dimension_identifier2='num_nodes',
                        levels=50)

# %%
# create a list for plotting
dim_names = ['learning_rate', 'num_layers', 'num_nodes', 'dropout' ]

try:
  fig, ax = plot_objective(result=search_result, dimensions=dim_names)
except:
  print("ok")
# Out:
# ok

# %%
try:
  best_model= load_model(path_best_model)
except:
  print("ok")
# Out:
# ok

# %%
opt_par = search_result.x
# use hyper-parameters from optimization
learning_rate = opt_par[0]
num_layers = opt_par[1]
num_nodes = opt_par[2]
dropout_value = opt_par[3]

model = Sequential()
model.add(InputLayer(input_shape=(None, 13)))
for i in range(num_layers-1):
    name = 'layer_GRU_{0}'.format(i+1)
    model.add(GRU(units=num_nodes, return_sequences=True, activation='tanh', name=name))
    model.add(Dropout(dropout_value))
model.add(GRU(units=num_nodes, activation='tanh'))
model.add(Dropout(dropout_value))
model.add(Dense(units=1))
# Adam Optimizer
optimizer = Adam(lr=learning_rate)
model.summary()
model.compile(optimizer=optimizer, loss='MSE', metrics=[tf.keras.metrics.MeanSquaredError()])

monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=20, verbose=1, mode='auto', restore_best_weights=True)

histories = model.fit(x_train, y_train, validation_data=(x_val,y_val), callbacks=[monitor],verbose=2,epochs=100)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_GRU_1 (GRU)            (None, None, 168)         91728
# _________________________________________________________________
# dropout (Dropout)            (None, None, 168)         0
# _________________________________________________________________
# gru (GRU)                    (None, 168)               169848
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 168)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 169
# =================================================================
# Total params: 261,745
# Trainable params: 261,745
# Non-trainable params: 0
# _________________________________________________________________
# Train on 43960 samples, validate on 5479 samples
# Epoch 1/100
# 43960/43960 - 39s - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 2/100
# 43960/43960 - 38s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 3/100
# 43960/43960 - 37s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 4/100
# 43960/43960 - 37s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 5/100
# 43960/43960 - 37s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 6/100
# 43960/43960 - 37s - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 7/100
# 43960/43960 - 37s - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 8/100
# 43960/43960 - 38s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 9/100
# 43960/43960 - 38s - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 10/100
# 43960/43960 - 38s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 11/100
# 43960/43960 - 37s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 12/100
# 43960/43960 - 38s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 13/100
# 43960/43960 - 38s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 14/100
# 43960/43960 - 37s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 15/100
# 43960/43960 - 37s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 16/100
# 43960/43960 - 37s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 17/100
# 43960/43960 - 37s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 18/100
# 43960/43960 - 37s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 19/100
# 43960/43960 - 37s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 20/100
# 43960/43960 - 37s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 21/100
# 43960/43960 - 37s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 22/100
# 43960/43960 - 37s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 23/100
# 43960/43960 - 37s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 24/100
# 43960/43960 - 37s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 25/100
# 43960/43960 - 37s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 26/100
# 43960/43960 - 36s - loss: 9.8980e-04 - mean_squared_error: 9.8981e-04 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 27/100
# Restoring model weights from the end of the best epoch.
# 43960/43960 - 37s - loss: 9.4823e-04 - mean_squared_error: 9.4823e-04 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 00027: early stopping

# %%
plt.plot(histories.history['loss'], 'b')
plt.plot(histories.history['val_loss'],'r' )
plt.title('Training and Validation')
plt.ylabel('MSE Loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.savefig('/content/gdrive/MyDrive/SoilMoisture/GRU_Images/MSE_c5_5.png', dpi=400)
plt.show()
