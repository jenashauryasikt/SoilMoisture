# %%
# !pip install tensorflow==1.15.0
# !pip install scikit-optimize

# %%
import numpy as np
import pandas as pd
import time

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Input
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM, Dropout, GRU
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping

import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.colors as colors
import matplotlib as mpl

# %%
import skopt
from skopt import gp_minimize, forest_minimize
from skopt.space import Real, Categorical, Integer
from skopt.plots import plot_convergence
from skopt.plots import plot_objective, plot_evaluations
from skopt.plots import plot_objective
from skopt.utils import use_named_args

# %%
randomState = 42
np.random.seed(randomState)
tf.set_random_seed(randomState)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
raw10 = pd.read_csv('/content/gdrive/MyDrive/SoilMoisture/Data/c_5_data_soil_20.csv')
df10 = raw10.copy()

df10 = df10.rename(columns={'In-Situ':'InSitu'})

def replace_missing(attribute):
    return attribute.interpolate(inplace=True)

replace_missing(df10['NDVI'])
replace_missing(df10['EVI'])
replace_missing(df10['LSTDay'])
replace_missing(df10['LSTNight'])

df10 = df10.dropna()
df10.isnull().sum()
# Out:
# Precip       0
# NDVI         0
# EVI          0
# GPP          0
# LSTDay       0
# LSTNight     0
# Elevation    0
# RZSM         0
# SURFSM       0
# Clay         0
# Sand         0
# Silt         0
# BD           0
# InSitu       0
# dtype: int64

# %%
df10['group'] = df10['Sand'].ne(df10['Sand'].shift()).cumsum()
df10 = df10.groupby('group')
dfs = []
for name, data in df10:
    dfs.append(data)

# %%
train_dataset = pd.DataFrame()
val_dataset = pd.DataFrame()
test_dataset = pd.DataFrame()

for df in dfs:
    df.pop('group')
    train_size = int(len(df)*0.8)
    val_size = int(len(df)*0.9)
    train, val, test = df.iloc[:train_size], df.iloc[train_size:val_size], df.iloc[val_size:]
    train_dataset = train_dataset.append(train)
    val_dataset = val_dataset.append(val)
    test_dataset = test_dataset.append(test)

# %%
# Split X
X_train = train_dataset.drop('InSitu', axis = 1)
X_val = val_dataset.drop('InSitu', axis = 1)
X_test = test_dataset.drop('InSitu', axis = 1)

# Split y
y_train = train_dataset.loc[:,['InSitu']]
y_val = val_dataset.loc[:,['InSitu']]
y_test = test_dataset.loc[:,['InSitu']]

# %%
# Fit the scaler using available training data
input_scaler = StandardScaler().fit(X_train)

# Apply the scaler to training data
x_train = input_scaler.transform(X_train)
x_val = input_scaler.transform(X_val)
x_test = input_scaler.transform(X_test)

x_train = np.array(x_train, np.float32)
y_train = np.array(y_train, np.float32)

x_val = np.array(x_val, np.float32)
y_val = np.array(y_val, np.float32)

x_test = np.array(x_test, np.float32)
y_test = np.array(y_test, np.float32)

y_train = y_train.reshape((y_train.size, 1))
y_val = y_val.reshape((y_val.size, 1))
y_test = y_test.reshape((y_test.size, 1))

# %%
def create_dataset (X, y, time_steps = 1):
    Xs, ys= [], []
    for i in range(len(X)-time_steps):
        v = X[i:i+time_steps, :]
        Xs.append(v)
        ys.append(y[i+time_steps])        
    return np.array(Xs), np.array(ys)

TIME_STEPS = 15

x_test, y_test = create_dataset(x_test, y_test, TIME_STEPS)
x_train, y_train = create_dataset(x_train, y_train, TIME_STEPS)
x_val, y_val = create_dataset(x_val, y_val, TIME_STEPS)

# %%
dim_learning_rate = Real(low=1e-5, high=1e-2, prior='log-uniform', name='learning_rate')
dim_num_layers = Integer(low=2, high=3, name='num_layers')
dim_num_nodes = Integer(low=128, high=256, name='num_nodes')
dim_dropout_val = Real(low=0.10, high=0.25, name='dropout_val')

dimensions = [dim_learning_rate,
              dim_num_layers,
              dim_num_nodes,
              dim_dropout_val]

default_parameters = [1e-3, 2, 256, 0.2]

# %%
# To log traning progress
def log_dir_name(learning_rate, num_layers, num_nodes, dropout_val):
    # dir-name for TensorBoard log-dir.
    s = "/content/gdrive/MyDrive/SoilMoisture/GRUlogs/lr_{0:.0e}_layers_{1}_nodes_{2}_dropout_{3}"
    log_dir = s.format(learning_rate, num_layers, num_nodes, dropout_val)

    return log_dir

# %%
#To create model with determined hyperparameters
def create_model(learning_rate, num_layers, num_nodes, dropout_val):
    model = Sequential()
    model.add(InputLayer(input_shape=(None, 13)))
    for i in range(num_layers-1):
        name = 'layer_GRU_{0}'.format(i+1)
        model.add(GRU(units=num_nodes, return_sequences=True, activation='tanh', name=name))
        model.add(Dropout(dropout_val))
    model.add(GRU(units=num_nodes, activation='tanh'))
    model.add(Dropout(dropout_val))
    model.add(Dense(units=1))
    # Adam Optimizer
    optimizer = Adam(lr=learning_rate)
    model.compile(optimizer=optimizer, loss='MSE', metrics=[tf.keras.metrics.MeanSquaredError()])
    
    return model

path_best_model = '/content/gdrive/MyDrive/SoilMoisture/GRU_Models/GRU_20_best_model.h5'
validation_data = (x_val, y_val)
best_loss = 5.0

# %%
@use_named_args(dimensions=dimensions)
def fitness(learning_rate, num_layers, num_nodes, dropout_val):
    """
    Hyper-parameters:
    learning_rate: Learning-rate for the optimizer.
    num_layers:    Number of GRU layers.
    num_nodes:     Number of nodes in each GRU layer.
    dropout_val:   Dropout.
    """
    # Print the hyper-parameters
    print('learning rate: {0:.1e}'.format(learning_rate))
    print('num_GRU_layers:', num_layers)
    print('num_GRU_nodes:', num_nodes)
    print('dropout:', dropout_val)
    print()    
    # Create the GRU
    model = create_model(learning_rate=learning_rate,
                         num_layers=num_layers,
                         num_nodes=num_nodes,
                         dropout_val=dropout_val)
    # Dir-name for TensorBoard log-files.
    log_dir = log_dir_name(learning_rate, num_layers, num_nodes, dropout_val)
    #callback
    callback_log = TensorBoard(log_dir=log_dir, histogram_freq=0, write_graph=True, write_grads=False, write_images=False)
    # Use Keras to train the model.
    history = model.fit(x= x_train,
                        y= y_train,
                        epochs=30,
                        batch_size=128,
                        validation_data=validation_data,
                        callbacks=[callback_log])

    loss = history.history['val_loss'][-1]

    print()
    print("MSE Loss:", loss)
    print()

    global best_loss

    if loss < best_loss:
        # Save the new model
        model.save(path_best_model)
        best_loss = loss

    del model
    
    K.clear_session()
    
    return loss

# %%
start = time.time()
search_result = gp_minimize(func=fitness,
                            dimensions=dimensions,
                            acq_func='EI',          # Expected Improvement.
                            n_calls=25,
                            x0=default_parameters)
print("Optimization Run Time: ", (time.time()-start)/60)
# Out:
# learning rate: 1.0e-03
# num_GRU_layers: 2
# num_GRU_nodes: 256
# dropout: 0.2
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on
# Epoch 4/30
# 39338/39338 [==============================] - 18s 468us/sample - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 5/30
# 39338/39338 [==============================] - 18s 456us/sample - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 6/30
# 39338/39338 [==============================] - 18s 454us/sample - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 7/30
# 39338/39338 [==============================] - 18s 461us/sample - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 8/30
# 39338/39338 [==============================] - 18s 461us/sample - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 9/30
# 39338/39338 [==============================] - 18s 463us/sample - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 10/30
# 39338/39338 [==============================] - 18s 458us/sample - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 11/30
# 39338/39338 [==============================] - 18s 463us/sample - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 12/30
# 39338/39338 [==============================] - 18s 457us/sample - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 13/30
# 39338/39338 [==============================] - 18s 457us/sample - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 14/30
# 39338/39338 [==============================] - 18s 459us/sample - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 15/30
# 39338/39338 [==============================] - 18s 463us/sample - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 16/30
# 39338/39338 [==============================] - 18s 456us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 17/30
# 39338/39338 [==============================] - 18s 454us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 18/30
# 39338/39338 [==============================] - 18s 458us/sample - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 19/30
# 39338/39338 [==============================] - 18s 460us/sample - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 20/30
# 39338/39338 [==============================] - 18s 462us/sample - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 21/30
# 39338/39338 [==============================] - 18s 463us/sample - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 22/30
# 39338/39338 [==============================] - 18s 461us/sample - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 23/30
# 39338/39338 [==============================] - 18s 467us/sample - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 24/30
# 39338/39338 [==============================] - 19s 472us/sample - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 25/30
# 39338/39338 [==============================] - 18s 465us/sample - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 26/30
# 39338/39338 [==============================] - 19s 474us/sample - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 27/30
# 39338/39338 [==============================] - 18s 469us/sample - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 28/30
# 39338/39338 [==============================] - 19s 477us/sample - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 29/30
# 39338/39338 [==============================] - 18s 468us/sample - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 30/30
# 39338/39338 [==============================] - 18s 453us/sample - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
#
# MSE Loss: 0.0051224767419450895
#
# learning rate: 9.5e-03
# num_GRU_layers: 3
# num_GRU_nodes: 131
# dropout: 0.2453406832345494
#
# Train on 39338 samples, validate on 4903 samples
# Epoch 1/30
# 39338/39338 [==============================] - 20s 500us/sample - loss: 0.0339 - mean_squared_error: 0.0339 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch
# [(0.003010792092395657, [0.0004731671323714552, 2, 225, 0.1083746287016896]),
#  (0.0030737012989111297, [0.0008274267546900543, 3, 227, 0.19112799943278586]),
#  (0.0031135592892858692, [0.000348567715938133, 2, 153, 0.20267121242405728]),
#  (0.003377240838309362, [0.000799948364227819, 3, 164, 0.2323670929352739]),
#  (0.003485985244346041, [0.00024897791567629574, 3, 225, 0.17669611790037748]),
#  (0.0034871285489881717, [0.007051322533149556, 2, 130, 0.24817362560201958]),
#  (0.003495965826444977, [0.007603224808572846, 2, 132, 0.10345236017442629]),
#  (0.0035118487092151373, [0.009486537523940462, 2, 136, 0.10341429642865219]),
#  (0.003559284128344426, [0.006847683366858037, 2, 128, 0.24860989188314175]),
#  (0.003630663090142931, [0.00012443016037623424, 2, 211, 0.1939784431404062]),
#  (0.0036436234835049777, [0.009073848884154995, 3, 250, 0.10133159275370791]),
#  (0.0036684261801531613, [0.008392719636538284, 3, 221, 0.21465820254914464]),
#  (0.0037921045764569552, [0.001, 2, 256, 0.2]),
#  (0.00387858174948883, [0.0009484415819482024, 3, 251, 0.14149579958284295]),
#  (0.004024828744848213, [0.008155182327476352, 2, 255, 0.10417823605971477]),
#  (0.0040487293984555585, [0.0073347091231710845, 3, 153, 0.24482678483834702]),
#  (0.00474103970845199, [2.6631204145965974e-05, 3, 188, 0.16709098610929923]),
#  (0.00481999232860173, [1.4835136542108433e-05, 3, 255, 0.1044384638842659]),
#  (0.004951812893195165, [1.59941217062964e-05, 3, 130, 0.10192534749157406]),
#  (0.005016676178374887, [1.4048937082427222e-05, 2, 255, 0.24678956493040097]),
#  (0.0051224767419450895,
#   [1.1714030137254717e-05, 3, 130, 0.10333706415777849]),
#  (0.005199582345233616, [1.1357622075751501e-05, 2, 251, 0.2482946179074836]),
#  (0.005380039694167213, [1.0594113662303494e-05, 2, 130, 0.10239177324469947]),
#  (0.0056192047137811904, [1.0320196762105208e-05, 3, 133, 0.2433027157534364]),
#  (0.00740385436257847, [0.009461110736678387, 3, 131, 0.2453406832345494])]

# %%
from skopt.plots import plot_objective_2D
fig = plot_objective_2D(result=search_result,
                        dimension_identifier1='learning_rate',
                        dimension_identifier2='num_nodes',
                        levels=50)

# %%
# create a list for plotting
dim_names = ['learning_rate', 'num_layers', 'num_nodes', 'dropout' ]

try:
  fig, ax = plot_objective(result=search_result, dimensions=dim_names)
except:
  print("ok")
# Out:
# ok

# %%
try:
  best_model= load_model(path_best_model)
except:
  print("ok")
# Out:
# ok

# %%
opt_par = search_result.x
# use hyper-parameters from optimization
learning_rate = opt_par[0]
num_layers = opt_par[1]
num_nodes = opt_par[2]
dropout_value = opt_par[3]

model = Sequential()
model.add(InputLayer(input_shape=(None, 13)))
for i in range(num_layers-1):
    name = 'layer_GRU_{0}'.format(i+1)
    model.add(GRU(units=num_nodes, return_sequences=True, activation='tanh', name=name))
    model.add(Dropout(dropout_value))
model.add(GRU(units=num_nodes, activation='tanh'))
model.add(Dropout(dropout_value))
model.add(Dense(units=1))
# Adam Optimizer
optimizer = Adam(lr=learning_rate)
model.summary()
model.compile(optimizer=optimizer, loss='MSE', metrics=[tf.keras.metrics.MeanSquaredError()])

monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=20, verbose=1, mode='auto', restore_best_weights=True)

histories = model.fit(x_train, y_train, validation_data=(x_val,y_val), callbacks=[monitor],verbose=2,epochs=100)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_GRU_1 (GRU)            (None, None, 225)         161325
# _________________________________________________________________
# dropout (Dropout)            (None, None, 225)         0
# _________________________________________________________________
# gru (GRU)                    (None, 225)               304425
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 225)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 226
# =================================================================
# Total params: 465,976
# Trainable params: 465,976
# Non-trainable params: 0
# _________________________________________________________________
# Train on 39338 samples, validate on 4903 samples
# Epoch 1/100
# 39338/39338 - 44s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 2/100
# 39338/39338 - 43s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 3/100
# 39338/39338 - 43s - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 4/100
# 39338/39338 - 42s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 5/100
# 39338/39338 - 43s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 6/100
# 39338/39338 - 42s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 7/100
# 39338/39338 - 42s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 8/100
# 39338/39338 - 42s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 9/100
# 39338/39338 - 42s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 10/100
# 39338/39338 - 42s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 11/100
# 39338/39338 - 42s - loss: 9.7623e-04 - mean_squared_error: 9.7623e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 12/100
# 39338/39338 - 43s - loss: 8.9350e-04 - mean_squared_error: 8.9350e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 13/100
# 39338/39338 - 42s - loss: 8.3592e-04 - mean_squared_error: 8.3592e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 14/100
# 39338/39338 - 42s - loss: 7.5799e-04 - mean_squared_error: 7.5799e-04 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 15/100
# 39338/39338 - 42s - loss: 7.0282e-04 - mean_squared_error: 7.0282e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 16/100
# 39338/39338 - 42s - loss: 6.3310e-04 - mean_squared_error: 6.3310e-04 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 17/100
# 39338/39338 - 42s - loss: 5.9803e-04 - mean_squared_error: 5.9803e-04 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 18/100
# 39338/39338 - 41s - loss: 5.5102e-04 - mean_squared_error: 5.5102e-04 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 19/100
# 39338/39338 - 42s - loss: 5.0509e-04 - mean_squared_error: 5.0509e-04 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 20/100
# 39338/39338 - 42s - loss: 4.6669e-04 - mean_squared_error: 4.6669e-04 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 21/100
# 39338/39338 - 42s - loss: 4.5612e-04 - mean_squared_error: 4.5612e-04 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 22/100
# 39338/39338 - 42s - loss: 4.1323e-04 - mean_squared_error: 4.1323e-04 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 23/100
# 39338/39338 - 42s - loss: 3.8579e-04 - mean_squared_error: 3.8579e-04 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 24/100
# 39338/39338 - 42s - loss: 3.6573e-04 - mean_squared_error: 3.6573e-04 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 25/100
# 39338/39338 - 41s - loss: 3.4644e-04 - mean_squared_error: 3.4644e-04 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 26/100
# 39338/39338 - 42s - loss: 3.4049e-04 - mean_squared_error: 3.4049e-04 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 27/100
# Restoring model weights from the end of the best epoch.
# 39338/39338 - 42s - loss: 3.0272e-04 - mean_squared_error: 3.0272e-04 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 00027: early stopping

# %%
plt.plot(histories.history['loss'], 'b')
plt.plot(histories.history['val_loss'],'r' )
plt.title('Training and Validation')
plt.ylabel('MSE Loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.savefig('/content/gdrive/MyDrive/SoilMoisture/GRU_Images/MSE_c5_20.png', dpi=400)
plt.show()
