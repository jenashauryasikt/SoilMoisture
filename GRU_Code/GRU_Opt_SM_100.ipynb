# %%
# !pip install tensorflow==1.15.0
# !pip install scikit-optimize

# %%
import numpy as np
import pandas as pd
import time

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Input
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM, Dropout, GRU
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping

import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.colors as colors
import matplotlib as mpl

# %%
import skopt
from skopt import gp_minimize, forest_minimize
from skopt.space import Real, Categorical, Integer
from skopt.plots import plot_convergence
from skopt.plots import plot_objective, plot_evaluations
from skopt.plots import plot_objective
from skopt.utils import use_named_args

# %%
randomState = 42
np.random.seed(randomState)
tf.set_random_seed(randomState)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
raw10 = pd.read_csv('/content/gdrive/MyDrive/SoilMoisture/Data/c_5_data_soil_100.csv')
df10 = raw10.copy()

df10 = df10.rename(columns={'In-Situ':'InSitu'})

def replace_missing(attribute):
    return attribute.interpolate(inplace=True)

replace_missing(df10['NDVI'])
replace_missing(df10['EVI'])
replace_missing(df10['LSTDay'])
replace_missing(df10['LSTNight'])

df10 = df10.dropna()
df10.isnull().sum()
# Out:
# Precip       0
# NDVI         0
# EVI          0
# GPP          0
# LSTDay       0
# LSTNight     0
# Elevation    0
# RZSM         0
# SURFSM       0
# Clay         0
# Sand         0
# Silt         0
# BD           0
# InSitu       0
# dtype: int64

# %%
df10['group'] = df10['Sand'].ne(df10['Sand'].shift()).cumsum()
df10 = df10.groupby('group')
dfs = []
for name, data in df10:
    dfs.append(data)

# %%
train_dataset = pd.DataFrame()
val_dataset = pd.DataFrame()
test_dataset = pd.DataFrame()

for df in dfs:
    df.pop('group')
    train_size = int(len(df)*0.8)
    val_size = int(len(df)*0.9)
    train, val, test = df.iloc[:train_size], df.iloc[train_size:val_size], df.iloc[val_size:]
    train_dataset = train_dataset.append(train)
    val_dataset = val_dataset.append(val)
    test_dataset = test_dataset.append(test)

# %%
# Split X
X_train = train_dataset.drop('InSitu', axis = 1)
X_val = val_dataset.drop('InSitu', axis = 1)
X_test = test_dataset.drop('InSitu', axis = 1)

# Split y
y_train = train_dataset.loc[:,['InSitu']]
y_val = val_dataset.loc[:,['InSitu']]
y_test = test_dataset.loc[:,['InSitu']]

# %%
# Fit the scaler using available training data
input_scaler = StandardScaler().fit(X_train)

# Apply the scaler to training data
x_train = input_scaler.transform(X_train)
x_val = input_scaler.transform(X_val)
x_test = input_scaler.transform(X_test)

x_train = np.array(x_train, np.float32)
y_train = np.array(y_train, np.float32)

x_val = np.array(x_val, np.float32)
y_val = np.array(y_val, np.float32)

x_test = np.array(x_test, np.float32)
y_test = np.array(y_test, np.float32)

y_train = y_train.reshape((y_train.size, 1))
y_val = y_val.reshape((y_val.size, 1))
y_test = y_test.reshape((y_test.size, 1))

# %%
def create_dataset (X, y, time_steps = 1):
    Xs, ys= [], []
    for i in range(len(X)-time_steps):
        v = X[i:i+time_steps, :]
        Xs.append(v)
        ys.append(y[i+time_steps])        
    return np.array(Xs), np.array(ys)

TIME_STEPS = 15

x_test, y_test = create_dataset(x_test, y_test, TIME_STEPS)
x_train, y_train = create_dataset(x_train, y_train, TIME_STEPS)
x_val, y_val = create_dataset(x_val, y_val, TIME_STEPS)

# %%
dim_learning_rate = Real(low=1e-5, high=1e-2, prior='log-uniform', name='learning_rate')
dim_num_layers = Integer(low=2, high=3, name='num_layers')
dim_num_nodes = Integer(low=128, high=256, name='num_nodes')
dim_dropout_val = Real(low=0.10, high=0.25, name='dropout_val')

dimensions = [dim_learning_rate,
              dim_num_layers,
              dim_num_nodes,
              dim_dropout_val]

default_parameters = [1e-3, 2, 256, 0.2]

# %%
# To log traning progress
def log_dir_name(learning_rate, num_layers, num_nodes, dropout_val):
    # dir-name for TensorBoard log-dir.
    s = "/content/gdrive/MyDrive/SoilMoisture/GRUlogs/lr_{0:.0e}_layers_{1}_nodes_{2}_dropout_{3}"
    log_dir = s.format(learning_rate, num_layers, num_nodes, dropout_val)

    return log_dir

# %%
#To create model with determined hyperparameters
def create_model(learning_rate, num_layers, num_nodes, dropout_val):
    model = Sequential()
    model.add(InputLayer(input_shape=(None, 13)))
    for i in range(num_layers-1):
        name = 'layer_GRU_{0}'.format(i+1)
        model.add(GRU(units=num_nodes, return_sequences=True, activation='tanh', name=name))
        model.add(Dropout(dropout_val))
    model.add(GRU(units=num_nodes, activation='tanh'))
    model.add(Dropout(dropout_val))
    model.add(Dense(units=1))
    # Adam Optimizer
    optimizer = Adam(lr=learning_rate)
    model.compile(optimizer=optimizer, loss='MSE', metrics=[tf.keras.metrics.MeanSquaredError()])
    
    return model

path_best_model = '/content/gdrive/MyDrive/SoilMoisture/GRU_Models/GRU_100_best_model.h5'
validation_data = (x_val, y_val)
best_loss = 5.0

# %%
@use_named_args(dimensions=dimensions)
def fitness(learning_rate, num_layers, num_nodes, dropout_val):
    """
    Hyper-parameters:
    learning_rate: Learning-rate for the optimizer.
    num_layers:    Number of GRU layers.
    num_nodes:     Number of nodes in each GRU layer.
    dropout_val:   Dropout.
    """
    # Print the hyper-parameters
    print('learning rate: {0:.1e}'.format(learning_rate))
    print('num_GRU_layers:', num_layers)
    print('num_GRU_nodes:', num_nodes)
    print('dropout:', dropout_val)
    print()    
    # Create the GRU
    model = create_model(learning_rate=learning_rate,
                         num_layers=num_layers,
                         num_nodes=num_nodes,
                         dropout_val=dropout_val)
    # Dir-name for TensorBoard log-files.
    log_dir = log_dir_name(learning_rate, num_layers, num_nodes, dropout_val)
    #callback
    callback_log = TensorBoard(log_dir=log_dir, histogram_freq=0, write_graph=True, write_grads=False, write_images=False)
    # Use Keras to train the model.
    history = model.fit(x= x_train,
                        y= y_train,
                        epochs=30,
                        batch_size=128,
                        validation_data=validation_data,
                        callbacks=[callback_log])

    loss = history.history['val_loss'][-1]

    print()
    print("MSE Loss:", loss)
    print()

    global best_loss

    if loss < best_loss:
        # Save the new model
        model.save(path_best_model)
        best_loss = loss

    del model
    
    K.clear_session()
    
    return loss

# %%
start = time.time()
search_result = gp_minimize(func=fitness,
                            dimensions=dimensions,
                            acq_func='EI',          # Expected Improvement.
                            n_calls=25,
                            x0=default_parameters)
print("Optimization Run Time: ", (time.time()-start)/60)
# Out:
# learning rate: 1.0e-03
# num_GRU_layers: 2
# num_GRU_nodes: 256
# dropout: 0.2
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on
- val_loss: 0.0042 - val_mean_squared_error: 0.0042
#
# MSE Loss: 0.004242197385091265
#
# learning rate: 1.1e-05
# num_GRU_layers: 2
# num_GRU_nodes: 164
# dropout: 0.10401443707273234
#
# Train on 33969 samples, validate on 4231 samples
# Epoch 1/30
# 33969/33969 [==============================] - 9s 277us/sample - loss: 0.0598 - mean_squared_error: 0.0598 - val_loss: 0.0289 - val_mean_squared_error: 0.0289
# Epoch 2/30
# 33969/33969 [==============================] - 9s 251us/sample - loss: 0.0253 - mean_squared_error: 0.0253 - val_loss: 0.0122 - val_mean_squared_error: 0.0122
# Epoch 3/30
# 33969/33969 [==============================] - 8s 250us/sample - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0104 - val_mean_squared_error: 0.0104
# Epoch 4/30
# 33969/33969 [==============================] - 8s 249us/sample - loss: 0.0146 - mean_squared_error: 0.0146 - val_loss: 0.0098 - val_mean_squared_error: 0.0098
# Epoch 5/30
# 33969/33969 [==============================] - 8s 250us/sample - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0093 - val_mean_squared_error: 0.0093
# Epoch 6/30
# 33969/33969 [==============================] - 8s 249us/sample - loss: 0.0125 - mean_squared_error: 0.0125 - val_loss: 0.0083 - val_mean_squared_error: 0.0083
# Epoch 7/30
# 33969/33969 [==============================] - 8s 248us/sample - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0081 - val_mean_squared_error: 0.0081
# Epoch 8/30
# 33969/33969 [==============================] - 8s 245us/sample - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0076 - val_mean_squared_error: 0.0076
# Epoch 9/30
# 33969/33969 [==============================] - 8s 248us/sample - loss: 0.0105 - mean_squared_error: 0.0105 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
# Epoch 10/30
# 33969/33969 [==============================] - 8s 250us/sample - loss: 0.0100 - mean_squared_error: 0.0100 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
# Epoch 11/30
# 33969/33969 [==============================] - 8s 249us/sample - loss: 0.0096 - mean_squared_error: 0.0096 - val_loss: 0.0069 - val_mean_squared_error: 0.0069
# Epoch 12/30
# 33969/33969 [==============================] - 8s 248us/sample - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0068 - val_mean_squared_error: 0.0068
# Epoch 13/30
# 33969/33969 [==============================] - 8s 250us/sample - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0066 - val_mean_squared_error: 0.0066
# Epoch 14/30
# 33969/33969 [==============================] - 9s 251us/sample - loss: 0.0085 - mean_squared_error: 0.0085 - val_loss: 0.0066 - val_mean_squared_error: 0.0066
# Epoch 15/30
# 33969/33969 [==============================] - 8s 246us/sample - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 16/30
# 33969/33969 [==============================] - 8s 244us/sample - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 17/30
# 33969/33969 [==============================] - 8s 245us/sample - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 18/30
# 33969/33969 [==============================] - 8s 245us/sample - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 19/30
# 33969/33969 [==============================] - 8s 246us/sample - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 20/30
# 33969/33969 [==============================] - 8s 247us/sample - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 21/30
# 33969/33969 [==============================] - 8s 248us/sample - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 22/30
# 33969/33969 [==============================] - 8s 248us/sample - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 23/30
# 33969/33969 [==============================] - 8s 247us/sample - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 24/30
# 33969/33969 [==============================] - 8s 246us/sample - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 25/30
# 33969/33969 [==============================] - 8s 247us/sample - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 26/30
# 33969/33969 [==============================] - 8s 247us/sample - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 27/30
# 33969/33969 [==============================] - 8s 247us/sample - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 28/30
# 33969/33969 [==============================] - 8s 247us/sample - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 29/30
# 33969/33969 [==============================] - 8s 247us/sample - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 30/30
# 33969/33969 [==============================] - 8s 247us/sample - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
#
# MSE Loss: 0.005477125957190878
#
# learning rate: 1.3e-05
# num_GRU_layers: 3
# num_GRU_nodes: 141
# dropout: 0.1273475683473201
#
# Train on 33969 samples, validate on 4231 samples
# Epoch 1/30
# 33969/33969 [==============================] - 14s 403us/sample - loss: 0.0481 - mean_squared_error: 0.0481 - val_loss: 0.0176 - val_mean_squared_error: 0.0176
# Epoch 2/30
# 33969/33969 [==============================] - 13s 369us/sample - loss: 0.0169 - mean_squared_error: 0.0169 - val_loss: 0.0104 - val_mean_squared_error: 0.0104
# Epoch 3/30
# 33969/33969 [==============================] - 13s 371us/sample - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.0095 - val_mean_squared_error: 0.0095
# Epoch 4/30
# 33969/33969 [==============================] - 12s 365us/sample - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0090 - val_mean_squared_error: 0.0090
# Epoch 5/30
# 33969/33969 [==============================] - 12s 361us/sample - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0082 - val_mean_squared_error: 0.0082
# Epoch 6/30
# 33969/33969 [==============================] - 12s 363us/sample - loss: 0.0104 - mean_squared_error: 0.0104 - val_loss: 0.0077 - val_mean_squared_error: 0.0077
# Epoch 7/30
# 33969/33969 [==============================] - 13s 369us/sample - loss: 0.0097 - mean_squared_error: 0.0097 - val_loss: 0.0077 - val_mean_squared_error: 0.0077
# Epoch 8/30
# 33969/33969 [==============================] - 12s 362us/sample - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
# Epoch 9/30
# 33969/33969 [==============================] - 12s 366us/sample - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 0.0071 - val_mean_squared_error: 0.0071
# Epoch 10/30
# 33969/33969 [==============================] - 12s 366us/sample - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 11/30
# 33969/33969 [==============================] - 12s 366us/sample - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0068 - val_mean_squared_error: 0.0068
# Epoch 12/30
# 33969/33969 [==============================] - 12s 365us/sample - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0066 - val_mean_squared_error: 0.0066
# Epoch 13/30
# 33969/33969 [==============================] - 12s 363us/sample - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 14/30
# 33969/33969 [==============================] - 12s 360us/sample - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 15/30
# 33969/33969 [==============================] - 12s 359us/sample - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 16/30
# 33969/33969 [==============================] - 12s 360us/sample - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 17/30
# 33969/33969 [==============================] - 12s 359us/sample - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 18/30
# 33969/33969 [==============================] - 12s 361us/sample - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 19/30
# 33969/33969 [==============================] - 12s 360us/sample - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 20/30
# 33969/33969 [==============================] - 12s 359us/sample - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 21/30
# 33969/33969 [==============================] - 12s 365us/sample - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 22/30
# 33969/33969 [==============================] - 12s 366us/sample - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 23/30
# 33969/33969 [==============================] - 12s 363us/sample - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 24/30
# 33969/33969 [==============================] - 12s 362us/sample - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 26/30
# 33969/33969 [==============================] - 12s 366us/sample - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 27/30
# 33969/33969 [==============================] - 12s 367us/sample - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 28/30
# 33969/33969 [==============================] - 13s 369us/sample - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 29/30
# 33969/33969 [==============================] - 12s 363us/sample - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 30/30
# 33969/33969 [==============================] - 12s 365us/sample - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.
- val_loss: 0.0046 - val_mean_squared_error: 0.0046
#
# MSE Loss: 0.004577082120861856
#
# Optimization Run Time:  132.00073697566987

# %%
plot_convergence(search_result)

# %%
#best hyperparameters
print("Best Hyperparameters: ",search_result.x)

#corr. result
print(search_result.fun)
# Out:
# Best Hyperparameters:  [0.008131212599658114, 3, 253, 0.24911334540212293]
# 0.004045867306318753

# %%
#All Results
sorted(zip(search_result.func_vals, search_result.x_iters))
# Out:
# [(0.004045867306318753, [0.008131212599658114, 3, 253, 0.24911334540212293]),
#  (0.004091504610107722, [0.0007881449546787835, 2, 129, 0.18962175598604525]),
#  (0.004108435270451124, [0.009495481888801723, 2, 133, 0.10554594894157908]),
#  (0.004242197385091265, [0.001, 2, 256, 0.2]),
#  (0.004289267667968956, [0.0029877492460439097, 2, 221, 0.2117918815229321]),
#  (0.004295918517320102, [0.004563003207717123, 3, 225, 0.14456212888266814]),
#  (0.004364009606693784, [0.009826026057472946, 2, 131, 0.24426475040435444]),
#  (0.0043829827522594835, [0.009280262724930233, 3, 254, 0.10348128198914767]),
#  (0.004399256584397644, [0.00019731447368612513, 2, 168, 0.13563455085493945]),
#  (0.004442279253051977, [0.0038612762928462952, 3, 138, 0.19379117813639596]),
#  (0.004491592937295927, [0.008527241253102497, 3, 128, 0.2481696957762866]),
#  (0.004534262859931026, [0.00026736658082816264, 3, 202, 0.20581244884390937]),
#  (0.004571506260938042, [0.0025045920226481515, 3, 232, 0.24409215205222762]),
#  (0.004577082120861856, [0.008832032557406175, 2, 253, 0.24997180016427106]),
#  (0.00463723124928739, [0.000553539473205766, 2, 199, 0.17336739827656805]),
#  (0.004735778170853282, [0.0090659459275008, 2, 254, 0.10205646902525518]),
#  (0.004983543646555985, [0.009516089192423124, 3, 130, 0.10359829506848821]),
#  (0.005262280760145401, [1.2975862850495828e-05, 3, 256, 0.11315968910284945]),
#  (0.005347755567285802, [1.3438534954303808e-05, 2, 256, 0.24848141239487467]),
#  (0.00545091919308866, [1.3391613684887644e-05, 3, 141, 0.1273475683473201]),
#  (0.005477125957190878, [1.0549910601899887e-05, 2, 164, 0.10401443707273234]),
#  (0.005557478922786848, [1.4077562435368262e-05, 3, 130, 0.10452846363203945]),
#  (0.005734810650604442, [1.0272038266997997e-05, 2, 256, 0.10646328739385134]),
#  (0.005872968440616551, [1.1050965741651748e-05, 3, 250, 0.24845873523527578]),
#  (0.006494679750568233, [1.0586381346159596e-05, 2, 131, 0.247116328357498])]

# %%
from skopt.plots import plot_objective_2D
fig = plot_objective_2D(result=search_result,
                        dimension_identifier1='learning_rate',
                        dimension_identifier2='num_nodes',
                        levels=50)

# %%
# create a list for plotting
dim_names = ['learning_rate', 'num_layers', 'num_nodes', 'dropout' ]

try:
  fig, ax = plot_objective(result=search_result, dimensions=dim_names)
except:
  print("ok")
# Out:
# ok

# %%
try:
  best_model= load_model(path_best_model)
except:
  print("ok")
# Out:
# ok

# %%
opt_par = search_result.x
# use hyper-parameters from optimization
learning_rate = opt_par[0]
num_layers = opt_par[1]
num_nodes = opt_par[2]
dropout_value = opt_par[3]

model = Sequential()
model.add(InputLayer(input_shape=(None, 13)))
for i in range(num_layers-1):
    name = 'layer_GRU_{0}'.format(i+1)
    model.add(GRU(units=num_nodes, return_sequences=True, activation='tanh', name=name))
    model.add(Dropout(dropout_value))
model.add(GRU(units=num_nodes, activation='tanh'))
model.add(Dropout(dropout_value))
model.add(Dense(units=1))
# Adam Optimizer
optimizer = Adam(lr=learning_rate)
model.summary()
model.compile(optimizer=optimizer, loss='MSE', metrics=[tf.keras.metrics.MeanSquaredError()])

monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=20, verbose=1, mode='auto', restore_best_weights=True)

histories = model.fit(x_train, y_train, validation_data=(x_val,y_val), callbacks=[monitor],verbose=2,epochs=100)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_GRU_1 (GRU)            (None, None, 253)         202653
# _________________________________________________________________
# dropout (Dropout)            (None, None, 253)         0
# _________________________________________________________________
# layer_GRU_2 (GRU)            (None, None, 253)         384813
# _________________________________________________________________
# dropout_1 (Dropout)          (None, None, 253)         0
# _________________________________________________________________
# gru (GRU)                    (None, 253)               384813
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 253)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 254
# =================================================================
# Total params: 972,533
# Trainable params: 972,533
# Non-trainable params: 0
# _________________________________________________________________
# Train on 33969 samples, validate on 4231 samples
# Epoch 1/100
# 33969/33969 - 47s - loss: 0.0311 - mean_squared_error: 0.0311 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 2/100
# 33969/33969 - 46s - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 3/100
# 33969/33969 - 45s - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 4/100
# 33969/33969 - 45s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 5/100
# 33969/33969 - 45s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 6/100
# 33969/33969 - 45s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 7/100
# 33969/33969 - 46s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 8/100
# 33969/33969 - 45s - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 9/100
# 33969/33969 - 45s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 10/100
# 33969/33969 - 45s - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 11/100
# 33969/33969 - 45s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 12/100
# 33969/33969 - 45s - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 13/100
# 33969/33969 - 45s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 14/100
# 33969/33969 - 46s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 15/100
# 33969/33969 - 45s - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0072 - val_mean_squared_error: 0.0072
# Epoch 16/100
# 33969/33969 - 45s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 17/100
# 33969/33969 - 45s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 18/100
# 33969/33969 - 45s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 19/100
# 33969/33969 - 45s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0066 - val_mean_squared_error: 0.0066
# Epoch 20/100
# 33969/33969 - 47s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 21/100
# 33969/33969 - 46s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0077 - val_mean_squared_error: 0.0077
# Epoch 22/100
# 33969/33969 - 45s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 23/100
# Restoring model weights from the end of the best epoch.
# 33969/33969 - 45s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0066 - val_mean_squared_error: 0.0066
# Epoch 00023: early stopping

# %%
bplt.plot(histories.history['loss'], 'b')
plt.plot(histories.history['val_loss'],'r' )
plt.title('Training and Validation')
plt.ylabel('MSE Loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.savefig('/content/gdrive/MyDrive/SoilMoisture/GRU_Images/MSE_c5_100.png', dpi=400)
plt.show()
