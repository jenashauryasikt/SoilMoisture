# %%
# !pip install tensorflow==1.15.0
# !pip install scikit-optimize

# %%
import numpy as np
import pandas as pd
import time

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Input
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM, Dropout, GRU
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping

import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.colors as colors
import matplotlib as mpl

# %%
import skopt
from skopt import gp_minimize, forest_minimize
from skopt.space import Real, Categorical, Integer
from skopt.plots import plot_convergence
from skopt.plots import plot_objective, plot_evaluations
from skopt.plots import plot_objective
from skopt.utils import use_named_args

# %%
randomState = 42
np.random.seed(randomState)
tf.set_random_seed(randomState)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
raw10 = pd.read_csv('/content/gdrive/MyDrive/SoilMoisture/Data/c_5_data_soil_50.csv')
df10 = raw10.copy()

df10 = df10.rename(columns={'In-Situ':'InSitu'})

def replace_missing(attribute):
    return attribute.interpolate(inplace=True)

replace_missing(df10['NDVI'])
replace_missing(df10['EVI'])
replace_missing(df10['LSTDay'])
replace_missing(df10['LSTNight'])

df10 = df10.dropna()
df10.isnull().sum()
# Out:
# Precip       0
# NDVI         0
# EVI          0
# GPP          0
# LSTDay       0
# LSTNight     0
# Elevation    0
# RZSM         0
# SURFSM       0
# Clay         0
# Sand         0
# Silt         0
# BD           0
# InSitu       0
# dtype: int64

# %%
df10['group'] = df10['Sand'].ne(df10['Sand'].shift()).cumsum()
df10 = df10.groupby('group')
dfs = []
for name, data in df10:
    dfs.append(data)

# %%
train_dataset = pd.DataFrame()
val_dataset = pd.DataFrame()
test_dataset = pd.DataFrame()

for df in dfs:
    df.pop('group')
    train_size = int(len(df)*0.8)
    val_size = int(len(df)*0.9)
    train, val, test = df.iloc[:train_size], df.iloc[train_size:val_size], df.iloc[val_size:]
    train_dataset = train_dataset.append(train)
    val_dataset = val_dataset.append(val)
    test_dataset = test_dataset.append(test)

# %%
# Split X
X_train = train_dataset.drop('InSitu', axis = 1)
X_val = val_dataset.drop('InSitu', axis = 1)
X_test = test_dataset.drop('InSitu', axis = 1)

# Split y
y_train = train_dataset.loc[:,['InSitu']]
y_val = val_dataset.loc[:,['InSitu']]
y_test = test_dataset.loc[:,['InSitu']]

# %%
# Fit the scaler using available training data
input_scaler = StandardScaler().fit(X_train)

# Apply the scaler to training data
x_train = input_scaler.transform(X_train)
x_val = input_scaler.transform(X_val)
x_test = input_scaler.transform(X_test)

x_train = np.array(x_train, np.float32)
y_train = np.array(y_train, np.float32)

x_val = np.array(x_val, np.float32)
y_val = np.array(y_val, np.float32)

x_test = np.array(x_test, np.float32)
y_test = np.array(y_test, np.float32)

y_train = y_train.reshape((y_train.size, 1))
y_val = y_val.reshape((y_val.size, 1))
y_test = y_test.reshape((y_test.size, 1))

# %%
def create_dataset (X, y, time_steps = 1):
    Xs, ys= [], []
    for i in range(len(X)-time_steps):
        v = X[i:i+time_steps, :]
        Xs.append(v)
        ys.append(y[i+time_steps])        
    return np.array(Xs), np.array(ys)

TIME_STEPS = 15

x_test, y_test = create_dataset(x_test, y_test, TIME_STEPS)
x_train, y_train = create_dataset(x_train, y_train, TIME_STEPS)
x_val, y_val = create_dataset(x_val, y_val, TIME_STEPS)

# %%
dim_learning_rate = Real(low=1e-5, high=1e-2, prior='log-uniform', name='learning_rate')
dim_num_layers = Integer(low=2, high=3, name='num_layers')
dim_num_nodes = Integer(low=128, high=256, name='num_nodes')
dim_dropout_val = Real(low=0.10, high=0.25, name='dropout_val')

dimensions = [dim_learning_rate,
              dim_num_layers,
              dim_num_nodes,
              dim_dropout_val]

default_parameters = [1e-3, 2, 256, 0.2]

# %%
# To log traning progress
def log_dir_name(learning_rate, num_layers, num_nodes, dropout_val):
    # dir-name for TensorBoard log-dir.
    s = "/content/gdrive/MyDrive/SoilMoisture/GRUlogs/lr_{0:.0e}_layers_{1}_nodes_{2}_dropout_{3}"
    log_dir = s.format(learning_rate, num_layers, num_nodes, dropout_val)

    return log_dir

# %%
#To create model with determined hyperparameters
def create_model(learning_rate, num_layers, num_nodes, dropout_val):
    model = Sequential()
    model.add(InputLayer(input_shape=(None, 13)))
    for i in range(num_layers-1):
        name = 'layer_GRU_{0}'.format(i+1)
        model.add(GRU(units=num_nodes, return_sequences=True, activation='tanh', name=name))
        model.add(Dropout(dropout_val))
    model.add(GRU(units=num_nodes, activation='tanh'))
    model.add(Dropout(dropout_val))
    model.add(Dense(units=1))
    # Adam Optimizer
    optimizer = Adam(lr=learning_rate)
    model.compile(optimizer=optimizer, loss='MSE', metrics=[tf.keras.metrics.MeanSquaredError()])
    
    return model

path_best_model = '/content/gdrive/MyDrive/SoilMoisture/GRU_Models/GRU_50_best_model.h5'
validation_data = (x_val, y_val)
best_loss = 5.0

# %%
@use_named_args(dimensions=dimensions)
def fitness(learning_rate, num_layers, num_nodes, dropout_val):
    """
    Hyper-parameters:
    learning_rate: Learning-rate for the optimizer.
    num_layers:    Number of GRU layers.
    num_nodes:     Number of nodes in each GRU layer.
    dropout_val:   Dropout.
    """
    # Print the hyper-parameters
    print('learning rate: {0:.1e}'.format(learning_rate))
    print('num_GRU_layers:', num_layers)
    print('num_GRU_nodes:', num_nodes)
    print('dropout:', dropout_val)
    print()    
    # Create the GRU
    model = create_model(learning_rate=learning_rate,
                         num_layers=num_layers,
                         num_nodes=num_nodes,
                         dropout_val=dropout_val)
    # Dir-name for TensorBoard log-files.
    log_dir = log_dir_name(learning_rate, num_layers, num_nodes, dropout_val)
    #callback
    callback_log = TensorBoard(log_dir=log_dir, histogram_freq=0, write_graph=True, write_grads=False, write_images=False)
    # Use Keras to train the model.
    history = model.fit(x= x_train,
                        y= y_train,
                        epochs=30,
                        batch_size=128,
                        validation_data=validation_data,
                        callbacks=[callback_log])

    loss = history.history['val_loss'][-1]

    print()
    print("MSE Loss:", loss)
    print()

    global best_loss

    if loss < best_loss:
        # Save the new model
        model.save(path_best_model)
        best_loss = loss

    del model
    
    K.clear_session()
    
    return loss

# %%
start = time.time()
search_result = gp_minimize(func=fitness,
                            dimensions=dimensions,
                            acq_func='EI',          # Expected Improvement.
                            n_calls=25,
                            x0=default_parameters)
print("Optimization Run Time: ", (time.time()-start)/60)
# Out:
# learning rate: 1.0e-03
# num_GRU_layers: 2
# num_GRU_nodes: 256
# dropout: 0.2
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on
loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 28/30
# 36602/36602 [==============================] - 10s 282us/sample - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 29/30
# 36602/36602 [==============================] - 11s 287us/sample - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 30/30
# 36602/36602 [==============================] - 10s 283us/sample - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
#
# MSE Loss: 0.003715969239766205
#
# learning rate: 2.0e-05
# num_GRU_layers: 3
# num_GRU_nodes: 215
# dropout: 0.10922861728707717
#
# Train on 36602 samples, validate on 4562 samples
# Epoch 1/30
# 36602/36602 [==============================] - 17s 460us/sample - loss: 0.0233 - mean_squared_error: 0.0233 - val_loss: 0.0072 - val_mean_squared_error: 0.0072
# Epoch 2/30
# 36602/36602 [==============================] - 16s 426us/sample - loss: 0.0096 - mean_squared_error: 0.0096 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 3/30
# 36602/36602 [==============================] - 16s 425us/sample - loss: 0.0083 - mean_squared_error: 0.0083 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 4/30
# 36602/36602 [==============================] - 16s 424us/sample - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 5/30
# 36602/36602 [==============================] - 15s 421us/sample - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 6/30
# 36602/36602 [==============================] - 15s 421us/sample - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 7/30
# 36602/36602 [==============================] - 16s 424us/sample - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 8/30
# 36602/36602 [==============================] - 15s 421us/sample - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 9/30
# 36602/36602 [==============================] - 16s 425us/sample - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 10/30
# 36602/36602 [==============================] - 15s 422us/sample - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 11/30
# 36602/36602 [==============================] - 15s 421us/sample - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 12/30
# 36602/36602 [==============================] - 15s 421us/sample - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 13/30
# 36602/36602 [==============================] - 15s 421us/sample - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 14/30
# 36602/36602 [==============================] - 15s 421us/sample - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 15/30
# 36602/36602 [==============================] - 16s 426us/sample - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 16/30
# 36602/36602 [==============================] - 15s 419us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 17/30
# 36602/36602 [==============================] - 16s 435us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 18/30
# 36602/36602 [==============================] - 16s 425us/sample - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 19/30
# 36602/36602 [==============================] - 16s 431us/sample - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 20/30
# 36602/36602 [==============================] - 15s 420us/sample - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 21/30
# 36602/36602 [==============================] - 16s 427us/sample - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 22/30
# 36602/36602 [==============================] - 16s 424us/sample - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 23/30
# 36602/36602 [==============================] - 16s 427us/sample - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 24/30
# 36602/36602 [==============================] - 15s 423us/sample - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 25/30
# 36602/36602 [==============================] - 15s 420us/sample - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 26/30
# 36602/36602 [==============================] - 15s 421us/sample - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 27/30
# 36602/36602 [==============================] - 15s 417us/sample - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 28/30
# 36602/36602 [==============================] - 16s 432us/sample - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 29/30
# 36602/36602 [==============================] - 15s 420us/sample - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 30/30
# 36602/36602 [==============================] - 15s 421us/sample - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
#
# MSE Loss: 0.004305862793874474
#
# learning rate: 7.9e-04
# num_GRU_layers: 2
# num_GRU_nodes: 240
# dropout: 0.14011175867380632
#
# Train on 36602 samples, validate on 4562 samples
# Epoch 1/30
# 36602/36602 [==============================] - 11s 296us/sample - loss: 0.0103 - mean_squared_error: 0.0103 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 2/30
# 36602/36602 [==============================] - 10s 278us/sample - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch
- val_loss: 0.0050 - val_mean_squared_error: 0.0050
#
# MSE Loss: 0.005008848150477551
#
# learning rate: 1.0e-05
# num_GRU_layers: 3
# num_GRU_nodes: 132
# dropout: 0.10200034029299039
#
# Train on 36602 samples, validate on 4562 samples
# Epoch 1/30
# 36602/36602 [==============================] - 17s 471us/sample - loss: 0.0364 - mean_squared_error: 0.0364 - val_loss: 0.0146 - val_mean_squared_error: 0.0146
# Epoch 2/30
# 36602/36602 [==============================] - 16s 437us/sample - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
# Epoch 3/30
# 36602/36602 [==============================] - 16s 441us/sample - loss: 0.0106 - mean_squared_error: 0.0106 - val_loss: 0.0066 - val_mean_squared_error: 0.0066
# Epoch 4/30
# 36602/36602 [==============================] - 16s 435us/sample - loss: 0.0097 - mean_squared_error: 0.0097 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 5/30
# 36602/36602 [==============================] - 16s 435us/sample - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 6/30
# 36602/36602 [==============================] - 16s 435us/sample - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 7/30
# 36602/36602 [==============================] - 16s 436us/sample - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 8/30
# 36602/36602 [==============================] - 16s 433us/sample - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 9/30
# 36602/36602 [==============================] - 16s 431us/sample - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 10/30
# 36602/36602 [==============================] - 16s 435us/sample - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 11/30
# 36602/36602 [==============================] - 16s 436us/sample - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 12/30
# 36602/36602 [==============================] - 16s 435us/sample - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 13/30
# 36602/36602 [==============================] - 16s 433us/sample - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 14/30
# 36602/36602 [==============================] - 16s 438us/sample - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 15/30
# 36602/36602 [==============================] - 16s 430us/sample - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 16/30
# 36602/36602 [==============================] - 16s 432us/sample - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 17/30
# 36602/36602 [==============================] - 16s 434us/sample - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 18/30
# 36602/36602 [==============================] - 16s 432us/sample - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 19/30
# 36602/36602 [==============================] - 16s 431us/sample - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 20/30
# 36602/36602 [==============================] - 16s 438us/sample - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 21/30
# 36602/36602 [==============================] - 16s 437us/sample - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 22/30
# 36602/36602 [==============================] - 16s 437us/sample - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 23/30
# 36602/36602 [==============================] - 16s 437us/sample - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 24/30
# 36602/36602 [==============================] - 16s 433us/sample - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 25/30
# 36602/36602 [==============================] - 16s 436us/sample - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 26/30
# 36602/36602 [==============================] - 16s 434us/sample - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 27/30
# 36602/36602 [==============================] - 16s 434us/sample - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 28/30
# 36602/36602 [==============================] - 16s 433us/sample - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 29/30
# 36602/36602 [==============================] - 16s 427us/sample - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 30/30
# 36602/36602 [==============================] - 16s 429us/sample - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
#
# MSE Loss: 0.0039784129323574184
#
# Optimization Run Time:  160.66594608624777

# %%
plot_convergence(search_result)

# %%
#best hyperparameters
print("Best Hyperparameters: ",search_result.x)

#corr. result
print(search_result.fun)
# Out:
# Best Hyperparameters:  [0.002158430322505504, 2, 237, 0.11261489902050296]
# 0.0027954895563786202

# %%
#All Results
sorted(zip(search_result.func_vals, search_result.x_iters))
# Out:
# [(0.0027954895563786202, [0.002158430322505504, 2, 237, 0.11261489902050296]),
#  (0.0031655439623157504, [0.004768608584613202, 3, 248, 0.21846471777248447]),
#  (0.003307541710961935, [8.467419969826964e-05, 2, 221, 0.20896998253763793]),
#  (0.0033308494742592273, [0.001, 2, 256, 0.2]),
#  (0.003361789436773256, [5.2628248285840596e-05, 3, 191, 0.24190048203618184]),
#  (0.0034218717908265426, [0.008579354427486682, 2, 128, 0.24842729792172336]),
#  (0.003442884844914405, [0.0007850355614705378, 2, 240, 0.14011175867380632]),
#  (0.0035609179806186343, [0.0069036741228892156, 3, 198, 0.11504296939226127]),
#  (0.003578030294013985, [0.008956061833260304, 3, 255, 0.2485426316834066]),
#  (0.0036236263553545383, [0.009896240448230445, 2, 134, 0.2471532701918738]),
#  (0.0036537292922150014, [0.006042893759363116, 2, 255, 0.24978664959873043]),
#  (0.003715969239766205, [3.130330745458543e-05, 2, 201, 0.17672456950202908]),
#  (0.0039784129323574184, [0.00855337744693081, 2, 252, 0.2482794740312657]),
#  (0.00414049206097422, [1.8027439685112838e-05, 2, 206, 0.10054226757612411]),
#  (0.004215095213017068, [0.008135071720698299, 2, 128, 0.10315242170583133]),
#  (0.004305862793874474, [2.0242775862527264e-05, 3, 215, 0.10922861728707717]),
#  (0.004505176571185967, [1.0497409709076117e-05, 3, 132, 0.10200034029299039]),
#  (0.004529966196393964, [2.0796389103472094e-05, 3, 206, 0.17318233790544713]),
#  (0.004536835710505405, [1.036212874201001e-05, 2, 254, 0.10288288625411621]),
#  (0.004797130075137587, [1.8501276192228665e-05, 2, 128, 0.24497577731897288]),
#  (0.004807668089693521, [1.0873621479027448e-05, 3, 131, 0.23976791416471374]),
#  (0.004830543729625659, [1.0586513239746131e-05, 3, 252, 0.24213826682014147]),
#  (0.005008848150477551, [1.109687994420726e-05, 2, 130, 0.24335156704891242]),
#  (0.006605600588495652, [0.00983932283892199, 3, 130, 0.10648698999627394]),
#  (0.007202828441187576, [0.00942340748909383, 3, 135, 0.10063460429952621])]

# %%
from skopt.plots import plot_objective_2D
fig = plot_objective_2D(result=search_result,
                        dimension_identifier1='learning_rate',
                        dimension_identifier2='num_nodes',
                        levels=50)

# %%
# create a list for plotting
dim_names = ['learning_rate', 'num_layers', 'num_nodes', 'dropout' ]

try:
  fig, ax = plot_objective(result=search_result, dimensions=dim_names)
except:
  print("ok")
# Out:
# ok

# %%
try:
  best_model= load_model(path_best_model)
except:
  print("ok")
# Out:
# ok

# %%
opt_par = search_result.x
# use hyper-parameters from optimization
learning_rate = opt_par[0]
num_layers = opt_par[1]
num_nodes = opt_par[2]
dropout_value = opt_par[3]

model = Sequential()
model.add(InputLayer(input_shape=(None, 13)))
for i in range(num_layers-1):
    name = 'layer_GRU_{0}'.format(i+1)
    model.add(GRU(units=num_nodes, return_sequences=True, activation='tanh', name=name))
    model.add(Dropout(dropout_value))
model.add(GRU(units=num_nodes, activation='tanh'))
model.add(Dropout(dropout_value))
model.add(Dense(units=1))
# Adam Optimizer
optimizer = Adam(lr=learning_rate)
model.summary()
model.compile(optimizer=optimizer, loss='MSE', metrics=[tf.keras.metrics.MeanSquaredError()])

monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=20, verbose=1, mode='auto', restore_best_weights=True)

histories = model.fit(x_train, y_train, validation_data=(x_val,y_val), callbacks=[monitor],verbose=2,epochs=100)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_GRU_1 (GRU)            (None, None, 237)         178461
# _________________________________________________________________
# dropout (Dropout)            (None, None, 237)         0
# _________________________________________________________________
# gru (GRU)                    (None, 237)               337725
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 237)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 238
# =================================================================
# Total params: 516,424
# Trainable params: 516,424
# Non-trainable params: 0
# _________________________________________________________________
# Train on 36602 samples, validate on 4562 samples
# Epoch 1/100
# 36602/36602 - 38s - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 2/100
# 36602/36602 - 38s - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 3/100
# 36602/36602 - 38s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 4/100
# 36602/36602 - 38s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 5/100
# 36602/36602 - 38s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 6/100
# 36602/36602 - 37s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 7/100
# 36602/36602 - 39s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 8/100
# 36602/36602 - 39s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 9/100
# 36602/36602 - 38s - loss: 8.1891e-04 - mean_squared_error: 8.1891e-04 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 10/100
# 36602/36602 - 38s - loss: 7.7745e-04 - mean_squared_error: 7.7745e-04 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 11/100
# 36602/36602 - 38s - loss: 7.1714e-04 - mean_squared_error: 7.1714e-04 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 12/100
# 36602/36602 - 38s - loss: 6.5147e-04 - mean_squared_error: 6.5147e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 13/100
# 36602/36602 - 38s - loss: 6.3023e-04 - mean_squared_error: 6.3023e-04 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 14/100
# 36602/36602 - 38s - loss: 6.1569e-04 - mean_squared_error: 6.1569e-04 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 15/100
# 36602/36602 - 38s - loss: 6.5877e-04 - mean_squared_error: 6.5877e-04 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 16/100
# 36602/36602 - 38s - loss: 4.8846e-04 - mean_squared_error: 4.8846e-04 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 17/100
# 36602/36602 - 38s - loss: 6.1149e-04 - mean_squared_error: 6.1150e-04 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 18/100
# 36602/36602 - 38s - loss: 4.5008e-04 - mean_squared_error: 4.5008e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 19/100
# 36602/36602 - 38s - loss: 4.8233e-04 - mean_squared_error: 4.8233e-04 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 20/100
# 36602/36602 - 38s - loss: 4.5998e-04 - mean_squared_error: 4.5998e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 21/100
# 36602/36602 - 38s - loss: 5.0076e-04 - mean_squared_error: 5.0076e-04 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 22/100
# 36602/36602 - 37s - loss: 5.2510e-04 - mean_squared_error: 5.2510e-04 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 23/100
# 36602/36602 - 38s - loss: 4.4296e-04 - mean_squared_error: 4.4296e-04 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 24/100
# Restoring model weights from the end of the best epoch.
# 36602/36602 - 38s - loss: 5.2236e-04 - mean_squared_error: 5.2236e-04 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 00024: early stopping

# %%
plt.plot(histories.history['loss'], 'b')
plt.plot(histories.history['val_loss'],'r' )
plt.title('Training and Validation')
plt.ylabel('MSE Loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.savefig('/content/gdrive/MyDrive/SoilMoisture/GRU_Images/MSE_c5_50.png', dpi=400)
plt.show()
