# %%
# !pip install tensorflow==1.15.0
# !pip install scikit-optimize

# %%
import numpy as np
import pandas as pd
import time

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Input
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM, Dropout
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping

import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.colors as colors
import matplotlib as mpl

# %%
import skopt
from skopt import gp_minimize, forest_minimize
from skopt.space import Real, Categorical, Integer
from skopt.plots import plot_convergence
from skopt.plots import plot_objective, plot_evaluations
from skopt.plots import plot_objective
from skopt.utils import use_named_args

# %%
randomState = 42
np.random.seed(randomState)
tf.set_random_seed(randomState)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
raw10 = pd.read_csv('/content/gdrive/MyDrive/SoilMoisture/Data/c_5_data_soil_20.csv')
df10 = raw10.copy()

df10 = df10.rename(columns={'In-Situ':'InSitu'})

def replace_missing(attribute):
    return attribute.interpolate(inplace=True)

replace_missing(df10['NDVI'])
replace_missing(df10['EVI'])
replace_missing(df10['LSTDay'])
replace_missing(df10['LSTNight'])

df10 = df10.dropna()
df10.isnull().sum()
# Out:
# Precip       0
# NDVI         0
# EVI          0
# GPP          0
# LSTDay       0
# LSTNight     0
# Elevation    0
# RZSM         0
# SURFSM       0
# Clay         0
# Sand         0
# Silt         0
# BD           0
# InSitu       0
# dtype: int64

# %%
df10['group'] = df10['Sand'].ne(df10['Sand'].shift()).cumsum()
df10 = df10.groupby('group')
dfs = []
for name, data in df10:
    dfs.append(data)

# %%
train_dataset = pd.DataFrame()
val_dataset = pd.DataFrame()
test_dataset = pd.DataFrame()

for df in dfs:
    df.pop('group')
    train_size = int(len(df)*0.8)
    val_size = int(len(df)*0.9)
    train, val, test = df.iloc[:train_size], df.iloc[train_size:val_size], df.iloc[val_size:]
    train_dataset = train_dataset.append(train)
    val_dataset = val_dataset.append(val)
    test_dataset = test_dataset.append(test)

# %%
# Split X
X_train = train_dataset.drop('InSitu', axis = 1)
X_val = val_dataset.drop('InSitu', axis = 1)
X_test = test_dataset.drop('InSitu', axis = 1)

# Split y
y_train = train_dataset.loc[:,['InSitu']]
y_val = val_dataset.loc[:,['InSitu']]
y_test = test_dataset.loc[:,['InSitu']]

# %%
# Fit the scaler using available training data
input_scaler = StandardScaler().fit(X_train)

# Apply the scaler to training data
x_train = input_scaler.transform(X_train)
x_val = input_scaler.transform(X_val)
x_test = input_scaler.transform(X_test)

x_train = np.array(x_train, np.float32)
y_train = np.array(y_train, np.float32)

x_val = np.array(x_val, np.float32)
y_val = np.array(y_val, np.float32)

x_test = np.array(x_test, np.float32)
y_test = np.array(y_test, np.float32)

y_train = y_train.reshape((y_train.size, 1))
y_val = y_val.reshape((y_val.size, 1))
y_test = y_test.reshape((y_test.size, 1))

# %%
dim_learning_rate = Real(low=1e-6, high=1e-2, prior='log-uniform', name='learning_rate')
dim_num_dense_layers = Integer(low=2, high=4, name='num_dense_layers')
dim_num_dense_nodes = Integer(low=128, high=512, name='num_dense_nodes')
dim_activation = Categorical(categories=['relu', 'sigmoid'], name='activation')

dimensions = [dim_learning_rate,
              dim_num_dense_layers,
              dim_num_dense_nodes,
              dim_activation]


default_parameters = [1e-3, 2, 256, 'relu']

# %%
# To log traning progress
def log_dir_name(learning_rate, num_dense_layers, num_dense_nodes, activation):
    # dir-name for TensorBoard log-dir.
    s = "/content/gdrive/MyDrive/SoilMoisture/DNNlogs/lr_{0:.0e}_layers_{1}_nodes_{2}_{3}"
    log_dir = s.format(learning_rate, num_dense_layers, num_dense_nodes, activation)

    return log_dir

# %%
#To create model with determined hyperparameters
def create_model(learning_rate, num_dense_layers, num_dense_nodes, activation):
    model = Sequential()
    model.add(InputLayer(input_shape=(x_train.shape[1])))
    for i in range(num_dense_layers):
        name = 'layer_dense_{0}'.format(i+1)
        # add dense layer
        model.add(Dense(num_dense_nodes, activation=activation, name=name))
    model.add(Dense(1, activation='linear'))
    # Adam optimizer
    optimizer = Adam(lr=learning_rate)  
    #compile the model
    model.compile(optimizer=optimizer, loss='MSE', metrics=[tf.keras.metrics.MeanSquaredError()])
    
    return model

path_best_model = '/content/gdrive/MyDrive/SoilMoisture/DNN_Models/DNN_20_best_model.h5'
validation_data = (x_val, y_val)
best_loss = 5.0

# %%
@use_named_args(dimensions=dimensions)
def fitness(learning_rate, num_dense_layers, num_dense_nodes, activation):
    """
    Hyper-parameters:
    learning_rate: Learning-rate for the optimizer.
    num_layers:    Number of LSTM layers.
    num_nodes:     Number of nodes in each LSTM layer.
    Activation:    Activation Type.
    """
    # Print the hyper-parameters
    print('learning rate: {0:.1e}'.format(learning_rate))
    print('num_dense_layers:', num_dense_layers)
    print('num_dense_nodes:', num_dense_nodes)
    print('activation:', activation)
    print()   
    # Create the LSTM
    model = create_model(learning_rate=learning_rate,
                         num_dense_layers=num_dense_layers,
                         num_dense_nodes=num_dense_nodes,
                         activation=activation)
    # Dir-name for TensorBoard log-files.
    log_dir = log_dir_name(learning_rate, num_dense_layers, num_dense_nodes, activation)
    #callback
    callback_log = TensorBoard(log_dir=log_dir, histogram_freq=0, write_graph=True, write_grads=False, write_images=False)
    # Use Keras to train the model.
    history = model.fit(x= x_train,
                        y= y_train,
                        epochs=30,
                        batch_size=128,
                        validation_data=validation_data,
                        callbacks=[callback_log])

    loss = history.history['val_loss'][-1]

    print()
    print("MSE Loss:", loss)
    print()

    global best_loss

    if loss < best_loss:
        # Save the new model
        model.save(path_best_model)
        best_loss = loss

    del model
    
    K.clear_session()
    
    return loss

# %%
start = time.time()
search_result = gp_minimize(func=fitness,
                            dimensions=dimensions,
                            acq_func='EI',          # Expected Improvement.
                            n_calls=75,
                            x0=default_parameters)
print("Optimization Run Time: ", (time.time()-start)/60)
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 17/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 7.6700e-04 - mean_squared_error: 7.6700e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 18/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 7.3807e-04 - mean_squared_error: 7.3807e-04 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 19/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 7.0950e-04 - mean_squared_error: 7.0950e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 20/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 6.7892e-04 - mean_squared_error: 6.7892e-04 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 21/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 6.7073e-04 - mean_squared_error: 6.7073e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 22/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 6.5767e-04 - mean_squared_error: 6.5767e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 23/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 6.2249e-04 - mean_squared_error: 6.2249e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 24/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 6.1360e-04 - mean_squared_error: 6.1360e-04 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 25/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 5.7113e-04 - mean_squared_error: 5.7113e-04 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 26/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 5.7253e-04 - mean_squared_error: 5.7253e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 27/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 5.4551e-04 - mean_squared_error: 5.4551e-04 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 28/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 5.2737e-04 - mean_squared_error: 5.2737e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 29/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 5.2476e-04 - mean_squared_error: 5.2476e-04 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 30/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 4.9960e-04 - mean_squared_error: 4.9960e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
#
# MSE Loss: 0.0033123222440662983
#
# learning rate: 5.0e-05
# num_dense_layers: 2
# num_dense_nodes: 337
# activation: relu
#
# Train on 39353 samples, validate on 4918 samples
# Epoch 1/30
# 39353/39353 [==============================] - 1s 17us/sample - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 2/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 3/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 4/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 5/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 6/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 7/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 8/30
# 39353/39353 [==============================] - 1s 13us/sample - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 9/30
# 39353/39353 [==============================] - 1s 13us/sample - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 10/30
# 39353/39353 [==============================] - 1s 13us/sample - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 11/30
# 39353/39353 [==============================] - 1s 13us/sample - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 12/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 13/30
# 39353/39353 [==============================] - 1s 13us/sample - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 14/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 15/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 16/30
# 39353/39353 [==============================] - 1s 13us/sample - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 17/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 18/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 19/30
# 39353/39353 [==============================] - 1s 13us/sample - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 20/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 21/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 22/30
# 39353/39353 [==============================] - 1s 13us/sample - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 23/30
# 39353/39353 [==============================] - 1s 13us/sample - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 24/30
# 39353/39353 [==============================] - 1s 13us/sample - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 25/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 26/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 27/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 28/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 29/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 30/30
# 39353/39353 [==============================] - 1s 13us/sample - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
#
# MSE Loss: 0.0034432328295155045
#
# learning rate: 7.6e-06
# num_dense_layers: 2
# num_dense_nodes: 223
# activation: sigmoid
#
# Train on 39353 samples, validate on 4918 samples
# Epoch 1/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.7559 - mean_squared_error: 0.7559 - val_loss: 0.1206 - val_mean_squared_error: 0.1206
# Epoch 2/30
# 39353/39353 [==============================] - 1s 13us/sample - loss: 0.0414 - mean_squared_error: 0.0414 - val_loss: 0.0104 - val_mean_squared_error: 0.0104
# Epoch 3/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0085 - val_mean_squared_error: 0.0085
# Epoch 4/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0077 - val_mean_squared_error: 0.0077
# Epoch 5/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0081 - mean_squared_error: 0.0081 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 6/30
# 39353/39353 [==============================] - 1s 13us/sample - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 7/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 8/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 9/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 10/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 11/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 12/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 13/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 14/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 15/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 16/30
# 39353/39353 [==============================] - 1s 13us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 17/30
# 39353/39353 [==============================] - 1s 13us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 18/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 19/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 20/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 21/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 22/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 23/30
# 39353/39353 [==============================] - 1s 13us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 24/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 25/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 26/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 27/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 28/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 29/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 30/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
#
# MSE Loss: 0.006195743399512761
#
# learning rate: 4.3e-04
# num_dense_layers: 3
# num_dense_nodes: 182
# activation: sigmoid
#
# Train on 39353 samples, validate on 4918 samples
# Epoch 1/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0508 - mean_squared_error: 0.0508 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 2/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 3/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 4/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 5/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 6/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 7/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 8/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 9/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 10/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 11/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 12/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 13/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 14/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 15/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 16/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 17/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 18/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 19/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0069 - val_mean_squared_error: 0.0069
# Epoch 20/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 21/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 22/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 23/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 24/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 25/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 26/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 27/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 28/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 29/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 30/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
#
# MSE Loss: 0.004979151827724436
#
# learning rate: 7.2e-05
# num_dense_layers: 3
# num_dense_nodes: 341
# activation: sigmoid
#
# Train on 39353 samples, validate on 4918 samples
# Epoch 1/30
# 39353/39353 [==============================] - 1s 17us/sample - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 2/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 3/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0066 - val_mean_squared_error: 0.0066
# Epoch 4/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 5/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0072 - val_mean_squared_error: 0.0072
# Epoch 6/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 7/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 8/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 9/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0068 - val_mean_squared_error: 0.0068
# Epoch 10/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 11/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 12/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 13/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 14/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 15/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 16/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 17/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 18/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 19/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0068 - val_mean_squared_error: 0.0068
# Epoch 20/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 21/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0066 - val_mean_squared_error: 0.0066
# Epoch 22/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0066 - val_mean_squared_error: 0.0066
# Epoch 23/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 24/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 25/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 26/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 27/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 28/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 29/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 30/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
#
# MSE Loss: 0.006091459853489039
#
# learning rate: 3.4e-06
# num_dense_layers: 4
# num_dense_nodes: 381
# activation: relu
#
# Train on 39353 samples, validate on 4918 samples
# Epoch 1/30
# 39353/39353 [==============================] - 1s 18us/sample - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0077 - val_mean_squared_error: 0.0077
# Epoch 2/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0066 - val_mean_squared_error: 0.0066
# Epoch 3/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 4/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 5/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 6/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 7/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 8/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 9/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 10/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 11/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 12/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 13/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 14/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 15/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 16/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 17/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 18/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 19/30
# 39353/39353 [==============================] - 1s 17us/sample - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 20/30
# 39353/39353 [==============================] - 1s 17us/sample - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 21/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 22/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 23/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 24/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 25/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 26/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 27/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 28/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 29/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 30/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
#
# MSE Loss: 0.0039215567489558
#
# learning rate: 1.6e-06
# num_dense_layers: 4
# num_dense_nodes: 198
# activation: sigmoid
#
# Train on 39353 samples, validate on 4918 samples
# Epoch 1/30
# 39353/39353 [==============================] - 1s 17us/sample - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0087 - val_mean_squared_error: 0.0087
# Epoch 2/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0105 - mean_squared_error: 0.0105 - val_loss: 0.0086 - val_mean_squared_error: 0.0086
# Epoch 3/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0104 - mean_squared_error: 0.0104 - val_loss: 0.0086 - val_mean_squared_error: 0.0086
# Epoch 4/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0104 - mean_squared_error: 0.0104 - val_loss: 0.0085 - val_mean_squared_error: 0.0085
# Epoch 5/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0102 - mean_squared_error: 0.0102 - val_loss: 0.0085 - val_mean_squared_error: 0.0085
# Epoch 6/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0101 - mean_squared_error: 0.0101 - val_loss: 0.0084 - val_mean_squared_error: 0.0084
# Epoch 7/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0100 - mean_squared_error: 0.0100 - val_loss: 0.0083 - val_mean_squared_error: 0.0083
# Epoch 8/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0099 - mean_squared_error: 0.0099 - val_loss: 0.0082 - val_mean_squared_error: 0.0082
# Epoch 9/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0098 - mean_squared_error: 0.0098 - val_loss: 0.0082 - val_mean_squared_error: 0.0082
# Epoch 10/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0096 - mean_squared_error: 0.0096 - val_loss: 0.0081 - val_mean_squared_error: 0.0081
# Epoch 11/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0095 - mean_squared_error: 0.0095 - val_loss: 0.0080 - val_mean_squared_error: 0.0080
# Epoch 12/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0079 - val_mean_squared_error: 0.0079
# Epoch 13/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0079 - val_mean_squared_error: 0.0079
# Epoch 14/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0078 - val_mean_squared_error: 0.0078
# Epoch 15/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0077 - val_mean_squared_error: 0.0077
# Epoch 16/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0076 - val_mean_squared_error: 0.0076
# Epoch 17/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 0.0075 - val_mean_squared_error: 0.0075
# Epoch 18/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
# Epoch 19/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0073 - val_mean_squared_error: 0.0073
# Epoch 20/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0073 - val_mean_squared_error: 0.0073
# Epoch 21/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0072 - val_mean_squared_error: 0.0072
# Epoch 22/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0071 - val_mean_squared_error: 0.0071
# Epoch 23/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 24/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 25/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0069 - val_mean_squared_error: 0.0069
# Epoch 26/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0068 - val_mean_squared_error: 0.0068
# Epoch 27/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 28/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 29/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 30/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
#
# MSE Loss: 0.006685228066745389
#
# learning rate: 3.3e-05
# num_dense_layers: 2
# num_dense_nodes: 365
# activation: sigmoid
#
# Train on 39353 samples, validate on 4918 samples
# Epoch 1/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0310 - mean_squared_error: 0.0310 - val_loss: 0.0068 - val_mean_squared_error: 0.0068
# Epoch 2/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 3/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 4/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 5/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 6/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 7/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 8/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 9/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 10/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 11/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 12/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 13/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 14/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0066 - val_mean_squared_error: 0.0066
# Epoch 15/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 16/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 17/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 18/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 19/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 20/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0068 - val_mean_squared_error: 0.0068
# Epoch 21/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 22/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 23/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 24/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 25/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 26/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 27/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 28/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 29/30
# 39353/39353 [==============================] - 1s 13us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 30/30
# 39353/39353 [==============================] - 1s 14us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
#
# MSE Loss: 0.006184462354120417
#
# learning rate: 4.5e-05
# num_dense_layers: 4
# num_dense_nodes: 271
# activation: sigmoid
#
# Train on 39353 samples, validate on 4918 samples
# Epoch 1/30
# 39353/39353 [==============================] - 1s 18us/sample - loss: 0.1167 - mean_squared_error: 0.1167 - val_loss: 0.0083 - val_mean_squared_error: 0.0083
# Epoch 2/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0097 - mean_squared_error: 0.0097 - val_loss: 0.0079 - val_mean_squared_error: 0.0079
# Epoch 3/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0073 - val_mean_squared_error: 0.0073
# Epoch 4/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0068 - val_mean_squared_error: 0.0068
# Epoch 5/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 6/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 7/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 8/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 9/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 10/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 11/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 12/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 13/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 14/30
# 39353/39353 [==============================] - 1s 18us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 15/30
# 39353/39353 [==============================] - 1s 17us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 16/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 17/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 18/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 19/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 20/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 21/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 22/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 23/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 24/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 25/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 26/30
# 39353/39353 [==============================] - 1s 17us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 27/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0066 - val_mean_squared_error: 0.0066
# Epoch 28/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 29/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 30/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
#
# MSE Loss: 0.006293246288484265
#
# learning rate: 8.5e-03
# num_dense_layers: 4
# num_dense_nodes: 494
# activation: relu
#
# Train on 39353 samples, validate on 4918 samples
# Epoch 1/30
# 39353/39353 [==============================] - 1s 18us/sample - loss: 2.0460 - mean_squared_error: 2.0460 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 2/30
# 39353/39353 [==============================] - 1s 17us/sample - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 3/30
# 39353/39353 [==============================] - 1s 17us/sample - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 4/30
# 39353/39353 [==============================] - 1s 17us/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 5/30
# 39353/39353 [==============================] - 1s 17us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 6/30
# 39353/39353 [==============================] - 1s 17us/sample - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 7/30
# 39353/39353 [==============================] - 1s 17us/sample - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 8/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 9/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 10/30
# 39353/39353 [==============================] - 1s 17us/sample - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 11/30
# 39353/39353 [==============================] - 1s 17us/sample - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 12/30
# 39353/39353 [==============================] - 1s 17us/sample - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 13/30
# 39353/39353 [==============================] - 1s 18us/sample - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 14/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 15/30
# 39353/39353 [==============================] - 1s 17us/sample - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 16/30
# 39353/39353 [==============================] - 1s 17us/sample - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 17/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 18/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 19/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 20/30
# ...
#
# MSE Loss: 0.0031280371848298382
#
# learning rate: 1.0e-06
# num_dense_layers: 2
# num_dense_nodes: 130
# activation: sigmoid
#
# Train on 39353 samples, validate on 4918 samples
# Epoch 1/30
# 39353/39353 [==============================] - 1s 18us/sample - loss: 0.0478 - mean_squared_error: 0.0478 - val_loss: 0.0341 - val_mean_squared_error: 0.0341
# Epoch 2/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0241 - mean_squared_error: 0.0241 - val_loss: 0.0175 - val_mean_squared_error: 0.0175
# Epoch 3/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0110 - val_mean_squared_error: 0.0110
# Epoch 4/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0104 - mean_squared_error: 0.0104 - val_loss: 0.0089 - val_mean_squared_error: 0.0089
# Epoch 5/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0083 - val_mean_squared_error: 0.0083
# Epoch 6/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0080 - val_mean_squared_error: 0.0080
# Epoch 7/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0079 - val_mean_squared_error: 0.0079
# Epoch 8/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0085 - mean_squared_error: 0.0085 - val_loss: 0.0078 - val_mean_squared_error: 0.0078
# Epoch 9/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0076 - val_mean_squared_error: 0.0076
# Epoch 10/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0075 - val_mean_squared_error: 0.0075
# Epoch 11/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
# Epoch 12/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0073 - val_mean_squared_error: 0.0073
# Epoch 13/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0072 - val_mean_squared_error: 0.0072
# Epoch 14/30
# 39353/39353 [==============================] - 1s 17us/sample - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0071 - val_mean_squared_error: 0.0071
# Epoch 15/30
# 39353/39353 [==============================] - 1s 17us/sample - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0071 - val_mean_squared_error: 0.0071
# Epoch 16/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 17/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0069 - val_mean_squared_error: 0.0069
# Epoch 18/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0069 - val_mean_squared_error: 0.0069
# Epoch 19/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0069 - val_mean_squared_error: 0.0069
# Epoch 20/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0068 - val_mean_squared_error: 0.0068
# Epoch 21/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0068 - val_mean_squared_error: 0.0068
# Epoch 22/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0068 - val_mean_squared_error: 0.0068
# Epoch 23/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0068 - val_mean_squared_error: 0.0068
# Epoch 24/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0068 - val_mean_squared_error: 0.0068
# Epoch 25/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 26/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 27/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 28/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 29/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 30/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0066 - val_mean_squared_error: 0.0066
#
# MSE Loss: 0.00662961885792852
#
# learning rate: 9.7e-03
# num_dense_layers: 2
# num_dense_nodes: 510
# activation: sigmoid
#
# Train on 39353 samples, validate on 4918 samples
# Epoch 1/30
# 39353/39353 [==============================] - 1s 18us/sample - loss: 1.1413 - mean_squared_error: 1.1413 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 2/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0066 - val_mean_squared_error: 0.0066
# Epoch 3/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 4/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 5/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 6/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 7/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 8/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 9/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 10/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 11/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 12/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 13/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 14/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 15/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 16/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 17/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 18/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 19/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 20/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 21/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 22/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 23/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 24/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 25/30
# 39353/39353 [==============================] - 1s 17us/sample - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 26/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 27/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 28/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 29/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 30/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
#
# MSE Loss: 0.003146864509610698
#
# learning rate: 1.2e-06
# num_dense_layers: 2
# num_dense_nodes: 512
# activation: relu
#
# Train on 39353 samples, validate on 4918 samples
# Epoch 1/30
# 39353/39353 [==============================] - 1s 18us/sample - loss: 0.0619 - mean_squared_error: 0.0619 - val_loss: 0.0257 - val_mean_squared_error: 0.0257
# Epoch 2/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0204 - mean_squared_error: 0.0204 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
# Epoch 3/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0109 - val_mean_squared_error: 0.0109
# Epoch 4/30
# 39353/39353 [==============================] - 1s 18us/sample - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0096 - val_mean_squared_error: 0.0096
# Epoch 5/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0088 - val_mean_squared_error: 0.0088
# Epoch 6/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0081 - val_mean_squared_error: 0.0081
# Epoch 7/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0077 - val_mean_squared_error: 0.0077
# Epoch 8/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
# Epoch 9/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0071 - val_mean_squared_error: 0.0071
# Epoch 10/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0069 - val_mean_squared_error: 0.0069
# Epoch 11/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0066 - val_mean_squared_error: 0.0066
# Epoch 12/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 13/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 14/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 15/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 16/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 17/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 18/30
# 39353/39353 [==============================] - 1s 17us/sample - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 19/30
# 39353/39353 [==============================] - 1s 18us/sample - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 20/30
# 39353/39353 [==============================] - 1s 17us/sample - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 21/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 22/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 23/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 24/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 25/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 26/30
# 39353/39353 [==============================] - 1s 16us/sample - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 27/30
# 39353/39353 [==============================] - 1s 17us/sample - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 28/30
# 39353/39353 [==============================] - 1s 18us/sample - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 29/30
# 39353/39353 [==============================] - 1s 17us/sample - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 30/30
# 39353/39353 [==============================] - 1s 15us/sample - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# MSE Loss: 0.004782028109760862
#
# Optimization Run Time:  24.303405435880027

# %%
plot_convergence(search_result)

# %%
#best hyperparameters
print("Best Hyperparameters: ",search_result.x)

#corr. result
print(search_result.fun)
# Out:
# Best Hyperparameters:  [0.00837268150852779, 2, 131, 'relu']
# 0.002597447332478045

# %%
#All Results
sorted(zip(search_result.func_vals, search_result.x_iters))
# Out:
# [(0.002597447332478045, [0.00837268150852779, 2, 131, 'relu']),
#  (0.002612233673415142, [0.008140584974795015, 2, 129, 'sigmoid']),
#  (0.00275283309218412, [0.009403202643938135, 4, 128, 'relu']),
#  (0.0027670093844051995, [0.009540252449070967, 2, 132, 'sigmoid']),
#  (0.0027804014448344636, [0.009816889390364434, 2, 140, 'relu']),
#  (0.0027964006917760983, [0.009622754098713328, 4, 131, 'relu']),
#  (0.0028012911963339816, [0.007572604238370995, 2, 134, 'relu']),
#  (0.0028132159396780307, [0.001, 2, 256, 'relu']),
#  (0.0028652605601033818, [0.009894293238093894, 4, 129, 'relu']),
#  (0.0028928749500188693, [0.009915156668485463, 4, 130, 'relu']),
#  (0.00289302226856666, [0.009600643757731266, 2, 509, 'relu']),
#  (0.002911521224119451, [0.00984667663595044, 2, 130, 'relu']),
#  (0.0029194756887660745, [0.009688061220135779, 2, 135, 'relu']),
#  (0.0029411864250704447, [0.009717624569993701, 4, 130, 'relu']),
#  (0.0029442120082494613, [0.008933497208339447, 4, 133, 'relu']),
#  (0.002955718946140585, [0.007749971752401539, 2, 128, 'relu']),
#  (0.0029736566550472177, [0.009964113734563022, 2, 132, 'relu']),
#  (0.0029841618407510095, [0.009580772976857723, 2, 135, 'sigmoid']),
#  (0.0030075058908379383, [0.00898084394012287, 2, 501, 'relu']),
#  (0.0030157537229477316, [0.009730575843107787, 2, 131, 'relu']),
#  (0.0031177159549343474, [0.009952310784582807, 4, 131, 'relu']),
#  (0.0031280371848298382, [0.009643616411665272, 2, 504, 'relu']),
#  (0.003146864509610698, [0.009652920492224494, 2, 510, 'sigmoid']),
#  (0.0031752770972271888, [0.009512964875115293, 4, 504, 'relu']),
#  (0.0031833888627869015, [0.008351852838092443, 4, 132, 'relu']),
#  (0.0031928034665365257, [0.008623812025871735, 2, 130, 'relu']),
#  (0.0032624125753534295, [0.009031308104903135, 4, 507, 'sigmoid']),
#  (0.0032920937998627093, [0.00925654032255168, 2, 510, 'relu']),
#  (0.0033123222440662983, [0.0004541801539532396, 3, 364, 'relu']),
#  (0.003325259944915638, [0.009568203806011, 2, 505, 'relu']),
#  (0.0033499436110603514, [0.009242853547536813, 2, 509, 'relu']),
#  (0.00336987527591813, [0.008230337486435198, 4, 129, 'relu']),
#  (0.003375538031905041, [0.008510822277864889, 4, 494, 'relu']),
#  (0.0034432328295155045, [5.0040519644558776e-05, 2, 337, 'relu']),
#  (0.0034676164093428497, [0.008635999475226268, 4, 506, 'relu']),
#  (0.003502176215852474, [0.009867205637977267, 2, 498, 'relu']),
#  (0.0036320352715513192, [0.0013472151968409523, 4, 177, 'sigmoid']),
#  (0.003824896866174649, [0.009707927240861084, 2, 510, 'sigmoid']),
#  (0.0039215567489558, [3.362682211512513e-06, 4, 381, 'relu']),
#  (0.004089500374437566, [0.009985897607037619, 2, 136, 'sigmoid']),
#  (0.0040992314774079466, [1.0847017972050409e-06, 4, 504, 'relu']),
#  (0.004134760316818855, [1.2254409500045143e-06, 4, 504, 'relu']),
#  (0.004198190270975723, [1.026948692468755e-06, 4, 508, 'relu']),
#  (0.00439136863495638, [0.00869191864589363, 2, 508, 'relu']),
#  (0.00464190854779973, [1.00686232661097e-06, 2, 507, 'relu']),
#  (0.004698997245470517, [1.1116483613895158e-06, 2, 508, 'relu']),
#  (0.00477707100702255, [1.2132508439193672e-06, 2, 510, 'relu']),
#  (0.0047809353517538865, [1.1843180107357681e-06, 2, 511, 'relu']),
#  (0.004782028109760862, [1.2378047618355578e-06, 2, 512, 'relu']),
#  (0.004813233928451176, [1.1646863541890873e-06, 2, 508, 'relu']),
#  (0.004979151827724436, [0.00043435663827296573, 3, 182, 'sigmoid']),
#  (0.005057918603580116, [1.0550373227059237e-06, 2, 500, 'relu']),
#  (0.005172491976525445, [0.009682027625840405, 2, 500, 'sigmoid']),
#  (0.005544246451822407, [1.001714381885134e-06, 4, 134, 'relu']),
#  (0.00560528512467676, [1.099128175163045e-06, 4, 134, 'relu']),
#  (0.005905438869571955, [1.0620244030053338e-06, 4, 129, 'relu']),
#  (0.006073170702680248, [1.0172843567554386e-06, 4, 131, 'relu']),
#  (0.006091459853489039, [7.238902337735882e-05, 3, 341, 'sigmoid']),
#  (0.006184462354120417, [3.27795704559012e-05, 2, 365, 'sigmoid']),
#  (0.006195743399512761, [7.612490423399856e-06, 2, 223, 'sigmoid']),
#  (0.006293246288484265, [4.5431208155283665e-05, 4, 271, 'sigmoid']),
#  (0.006436562820460046, [1.0525511707347687e-06, 4, 135, 'relu']),
#  (0.0066248911342781675, [1.0662876352135548e-06, 2, 130, 'sigmoid']),
#  (0.00662961885792852, [1.019385954447038e-06, 2, 130, 'sigmoid']),
#  (0.006681126149635627, [1.0419306133571634e-06, 2, 130, 'sigmoid']),
#  (0.006685228066745389, [1.6373588388788288e-06, 4, 198, 'sigmoid']),
#  (0.006809764171656238, [1.004166962141241e-06, 2, 129, 'sigmoid']),
#  (0.007056883772991934, [1.2792158938373407e-06, 2, 135, 'sigmoid']),
#  (0.008658128576947815, [0.008884073374152352, 4, 510, 'sigmoid']),
#  (0.008736931818494616, [0.0098554002082044, 4, 503, 'sigmoid']),
#  (0.008759897805586754, [1.11117478518632e-06, 2, 137, 'relu']),
#  (0.008906970258488578, [0.00884187686413427, 4, 511, 'sigmoid']),
#  (0.00897929891141002, [1.3166034964334935e-06, 2, 128, 'relu']),
#  (0.009102673386839068, [0.009457637485725937, 4, 504, 'sigmoid']),
#  (0.01162081670459934, [0.008302516822145462, 4, 507, 'sigmoid'])]

# %%
from skopt.plots import plot_objective_2D
fig = plot_objective_2D(result=search_result,
                        dimension_identifier1='learning_rate',
                        dimension_identifier2='num_dense_nodes',
                        levels=50)

# %%
# create a list for plotting
dim_names = ['learning_rate', 'num_dense_layers', 'num_dense_nodes', 'activation' ]

try:
  fig, ax = plot_objective(result=search_result, dimensions=dim_names)
except:
  print("ok")
# Out:
# ok

# %%
try:
  best_model= load_model(path_best_model)
except:
  print("ok")
# Out:
# ok

# %%
opt_par = search_result.x

# use hyper-parameters from optimization
learning_rate = opt_par[0]
num_dense_layers = opt_par[1]
num_dense_nodes = opt_par[2]
activation = opt_par[3]

model = Sequential()
model.add(InputLayer(input_shape=(x_train.shape[1])))
for i in range(num_dense_layers):
    name = 'layer_dense_{0}'.format(i+1)
    # add dense layer
    model.add(Dense(num_dense_nodes, activation=activation, name=name))
model.add(Dense(1, activation='linear'))

optimizer = Adam(lr=learning_rate)
model.summary()
model.compile(optimizer=optimizer, loss='MSE', metrics=[tf.keras.metrics.MeanSquaredError()])

monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=20, verbose=1, mode='auto', restore_best_weights=True)

histories = model.fit(x_train, y_train, validation_data=(x_val,y_val), callbacks=[monitor],verbose=2,epochs=100)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_dense_1 (Dense)        (None, 131)               1834
# _________________________________________________________________
# layer_dense_2 (Dense)        (None, 131)               17292
# _________________________________________________________________
# dense (Dense)                (None, 1)                 132
# =================================================================
# Total params: 19,258
# Trainable params: 19,258
# Non-trainable params: 0
# _________________________________________________________________
# Train on 39353 samples, validate on 4918 samples
# Epoch 1/100
# 39353/39353 - 2s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 2/100
# 39353/39353 - 2s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 3/100
# 39353/39353 - 2s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 4/100
# 39353/39353 - 2s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 5/100
# 39353/39353 - 2s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 6/100
# 39353/39353 - 2s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 7/100
# 39353/39353 - 2s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 8/100
# 39353/39353 - 2s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 9/100
# 39353/39353 - 2s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 10/100
# 39353/39353 - 2s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 11/100
# 39353/39353 - 2s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 12/100
# 39353/39353 - 2s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 13/100
# 39353/39353 - 2s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 14/100
# 39353/39353 - 2s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 15/100
# 39353/39353 - 2s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 16/100
# 39353/39353 - 2s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 17/100
# 39353/39353 - 2s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 18/100
# 39353/39353 - 2s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 19/100
# 39353/39353 - 2s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 20/100
# 39353/39353 - 2s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 21/100
# 39353/39353 - 2s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 22/100
# 39353/39353 - 2s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 23/100
# 39353/39353 - 2s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 24/100
# Restoring model weights from the end of the best epoch.
# 39353/39353 - 2s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 00024: early stopping

# %%
plt.plot(histories.history['loss'], 'b')
plt.plot(histories.history['val_loss'],'r' )
plt.title('Training and Validation')
plt.ylabel('MSE Loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.savefig('/content/gdrive/MyDrive/SoilMoisture/DNN_Images/MSE_c5_20.png', dpi=400)
plt.show()
